# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
#os.remove('/kaggle/working/datasets/cityscapes.pth')
# for dirname, _, filenames in os.walk('/kaggle/input'):
#    for filename in filenames:
#       print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
import torchvision.transforms.functional as functional
from torch.utils.data import DataLoader
from torch.utils.data import Dataset
from glob import glob

# %%
train_path = glob('/kaggle/input/cityscapes-image-pairs/cityscapes_data/train/*')
valid_path = glob('/kaggle/input/cityscapes-image-pairs/cityscapes_data/val/*')

# %%
class Cityscapes(Dataset):
    def __init__(self, data_path, transform=None, target_transform=None):
        super(Cityscapes, self).__init__()
        self.data_path = data_path
        #self.datasets = np.array(data)
        #self.images, self.targets = np.array_split(self.datasets, 2, axis=2)
        self.transform = transform
        self.target_transform = target_transform

    def __getitem__(self, item):
        image_pair = plt.imread(self.data_path[item])
        image, target = image_pair[:, :int(image_pair.shape[1] / 2)], image_pair[:, int(image_pair.shape[1] / 2):]
        #image = self.images[item]
        #target = self.targets[item]
        if self.transform is not None:
            image = self.transform(image)
        if self.target_transform is not None:
            target = self.target_transform(target)
        return image, target

    def __len__(self):
        return len(self.data_path)

# %%
import torch
import torch.nn as nn
from torch import Tensor


class UNet(nn.Module):
    def __init__(self, image_channel=3, mid_channel=64):
        super(UNet, self).__init__()
        self.two_conv_block = nn.Sequential(
            nn.Conv2d(image_channel, mid_channel, kernel_size=3, padding=1),
            nn.BatchNorm2d(mid_channel),
            nn.ReLU(inplace=True),
            nn.Conv2d(mid_channel, mid_channel, kernel_size=3, padding=1),
            nn.BatchNorm2d(mid_channel),
            nn.ReLU(inplace=True)
        )
        self.down_sample_1 = DownSampleConvBlock(mid_channel, mid_channel * 2, mid_channel * 2)
        self.down_sample_2 = DownSampleConvBlock(mid_channel * 2, mid_channel * 4, mid_channel * 4)
        self.down_sample_3 = DownSampleConvBlock(mid_channel * 4, mid_channel * 8, mid_channel * 8)
        self.down_sample_4 = DownSampleConvBlock(mid_channel * 8, mid_channel * 16, mid_channel * 16)
        self.up_sample_1 = UpSampleConvBlock(mid_channel * 16, mid_channel * 8, mid_channel * 8)
        self.up_sample_2 = UpSampleConvBlock(mid_channel * 8, mid_channel * 4, mid_channel * 4)
        self.up_sample_3 = UpSampleConvBlock(mid_channel * 4, mid_channel * 2, mid_channel * 2)
        self.up_sample_4 = UpSampleConvBlock(mid_channel * 2, mid_channel, mid_channel)
        # 降维
        self.conv1x1 = nn.Conv2d(mid_channel, image_channel, kernel_size=1)
        self.bn = nn.BatchNorm2d(image_channel)

    def forward(self, x):
        x1 = self.two_conv_block(x)
        x2 = self.down_sample_1(x1)
        x3 = self.down_sample_2(x2)
        x4 = self.down_sample_3(x3)
        x5 = self.down_sample_4(x4)
        x_u1 = self.up_sample_1(x5, x4)
        x_u2 = self.up_sample_2(x_u1, x3)
        x_u3 = self.up_sample_3(x_u2, x2)
        x_u4 = self.up_sample_4(x_u3, x1)
        return self.bn(self.conv1x1(x_u4))


class BasicConvBlock(nn.Module):
    def __init__(self, in_channels, mid_channels, out_channels, kernel_size=3, stride=1, padding=1, dilation=1):
        super(BasicConvBlock, self).__init__()
        self.layers = nn.Sequential(
            # the first conv block
            nn.Conv2d(in_channels, mid_channels, kernel_size, stride, padding, dilation),
            nn.BatchNorm2d(mid_channels),
            nn.ReLU(inplace=True),
            # the second conv block
            nn.Conv2d(mid_channels, out_channels, kernel_size, stride, padding, dilation),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True)
        )

    def forward(self, x):
        return self.layers(x)


class DownSampleConvBlock(nn.Module):
    def __init__(self, in_channels, mid_channels, out_channels, pool_size=2, kernel_size=3, stride=1, padding=1,
                 dilation=1):
        super(DownSampleConvBlock, self).__init__()
        self.down_sample = nn.MaxPool2d(kernel_size=pool_size)
        self.basic_conv_block = BasicConvBlock(in_channels, mid_channels, out_channels, kernel_size, stride, padding,
                                               dilation)

    def forward(self, x):
        # down sample
        x = self.down_sample(x)
        # two conv block
        x = self.basic_conv_block(x)
        return x


class UpSampleConvBlock(nn.Module):
    def __init__(self, in_channels, mid_channels, out_channels, up_size=2, kernel_size=3, stride=1, padding=1,
                 dilation=1):
        super(UpSampleConvBlock, self).__init__()
        self.up_sample = nn.ConvTranspose2d(in_channels, mid_channels, kernel_size=up_size, stride=up_size,
                                            dilation=dilation)
        self.basic_conv_block = BasicConvBlock(in_channels, mid_channels, out_channels, kernel_size, stride, padding,
                                               dilation)

    def forward(self, x, skip_x):
        # up sample
        x = self.up_sample(x)
        # concat x and skip_x in the dimension of channel
        x = torch.cat([x, skip_x], dim=1)
        # two conv block
        x = self.basic_conv_block(x)
        return x


class AdaptiveFeatureFusionModule(nn.Module):
    """Adaptive Feature Fusion Module(AFFM)

    Fusion multiple-scale feature maps, the count of feature maps is not fixed,
    the value of counts must equal the size of feature_maps, the number of layers
    in AFFM is determined by the parameter of counts.

    """

    def __init__(self, counts):
        super(AdaptiveFeatureFusionModule, self).__init__()
        self.counts = counts
        pass

    def forward(self, feature_maps: tuple = None):
        pass

# %%
def dice_coeff(predict, target, reduce_batch_first=False, epsilon=1e-6):
    # Average of Dice coefficient for all batches, or for a single mask
    assert predict.size() == target.size()
    if predict.dim() == 2 and reduce_batch_first:
        raise ValueError(f'Dice: asked to reduce batch but got tensor without batch dimension (shape {predict.shape})')

    if predict.dim() == 2 or reduce_batch_first:
        inter = torch.dot(predict.reshape(-1), target.reshape(-1))
        sets_sum = torch.sum(predict) + torch.sum(target)
        if sets_sum.item() == 0:
            sets_sum = 2 * inter
        return (2 * inter + epsilon) / (sets_sum + epsilon)
    else:
        # compute and average metric for each batch element
        dice = 0
        for i in range(predict.shape[0]):
            dice += dice_coeff(predict[i, ...], target[i, ...])
        # return average dice loss value of a batch
        return dice / predict.shape[0]


def multiclass_dice_coeff(predict, target, reduce_batch_first=False, epsilon=1e-6):
    # Average of Dice coefficient for all classes
    assert predict.size() == target.size()
    dice = 0
    for channel in range(predict.shape[1]):
        dice += dice_coeff(predict[:, channel, ...], target[:, channel, ...], reduce_batch_first, epsilon)
    return dice / predict.shape[1]


def dice_loss(predict, target, multiclass=True, epsilon=1e-6):
    # Dice loss (objective to minimize) between 0 and 1
    assert predict.size() == target.size()
    fn = multiclass_dice_coeff if multiclass else dice_coeff
    return 1 - fn(predict, target, reduce_batch_first=True, epsilon=epsilon)


class DiceLoss(nn.Module):
    def __init__(self, ep=1e-8):
        super(DiceLoss, self).__init__()
        self.ep = ep

    def forward(self, predict, target):
        # the shape of predict must equal to the shape of target
        value = dice_loss(predict, target, True, self.ep)
        return value

# %%
def validate(network_model, valid_loader, loss, device):
    network_model.eval()
    v_loss_total = 0.0
    with torch.no_grad():
        for j, (v_x, v_l) in enumerate(valid_loader):
            v_x = v_x.to(device)
            v_l = v_l.to(device)
            v_predict = network_model(v_x)
            loss_value = loss(v_predict, v_l)
            v_loss_total += loss_value.item()
    val_avg_loss = v_loss_total / len(valid_loader)
    return val_avg_loss


class SearchBestModel(object):
    def __init__(self, min_delta=0, verbose=True):
        super(SearchBestModel, self).__init__()
        self.verbose = verbose
        self.min_delta = min_delta
        self.counter = 0
        self.best_score = None

    def __call__(self, val_loss):
        if self.best_score is None:
            self.best_score = val_loss
        elif self.best_score - val_loss >= self.min_delta:
            self.best_score = val_loss
            self.counter = 0
        else:
            self.counter += 1
            if self.verbose:
                print('performance reducing: counter {}'.format(self.counter))

# %%
def train(train_loader, valid_loader, model, optimizer, loss, epoch, device):
    loss_change_list = []
    valid_loss_change = []
    save_best = {}
    save_last = {}
    search_best_model = SearchBestModel()
    for i in range(epoch):
        model.train()
        total_loss = 0.0
        for index, (image, label) in enumerate(train_loader):
            image = image.to(device)
            label = label.to(device).to(torch.float32)

            segment_mask = model(image)
            loss_value = loss(segment_mask, label)

            optimizer.zero_grad()
            loss_value.backward()
            optimizer.step()

            total_loss = total_loss + loss_value.item()

            print('epoch {} batch {}/{} loss = {:.4f}'.format(i + 1, index + 1, len(train_loader), loss_value.item()))
        # save train loss change history used for model analyse
        loss_change_list.append(total_loss / len(train_loader))
        # use the dataset for validation to validate the trained model
        valid_avg_loss = validate(model, valid_loader, loss, device)
        # save valid loss change history used for model analyse
        valid_loss_change.append(valid_avg_loss)

        print('epoch {} train loss = {:.4f} valid loss = {:.4f}'.format(i + 1, total_loss / len(train_loader), valid_avg_loss))

        # see if satisfy the conditions of early stopping
        search_best_model(valid_avg_loss)
        # if satisfy the conditions of early stopping, break the training process
        if search_best_model.counter > 0:
            continue
        # if not satisfy the conditions of early stopping, it shows that
        # the model in this epoch is the best, save the params of current model.
        save_best['model_state_dict'] = model.state_dict()
        # save optimizer used for re-train
        save_best['optimizer_state_dict'] = optimizer.state_dict()
        # save the epoch of current best model
        save_best['epoch'] = i
    # save loss change history of training and validation
    save_last['train_loss_change'] = loss_change_list
    save_last['valid_loss_change'] = valid_loss_change
    save_last['model_state_dict'] = model.state_dict()
    save_last['optimizer_state_dict'] = optimizer.state_dict()
    save_last['trained_epoch'] = epoch
    torch.save(save_best, './unet-best.pth')
    torch.save(save_last, './unet-last.pth')

# %%
if __name__ == '__main__':
    current_device = 'cuda' if torch.cuda.is_available() else 'cpu'

    train_image_path = glob('../input/cityscapes-image-pairs/cityscapes_data/train/*')
    valid_image_path = glob('../input/cityscapes-image-pairs/cityscapes_data/val/*')

    image_transforms = transforms.Compose([
#         transforms.ToPILImage(mode='RGB'),
        transforms.ToTensor(),
        transforms.Resize(256),
#         transforms.PILToTensor(),
#         transforms.ColorJitter(),
#         transforms.GaussianBlur((5,), (5, 15)),
#         transforms.Normalize((0.5,), (0.5,)),
    ])
    target_transforms = transforms.Compose([
#         transforms.ToPILImage(mode='RGB'),
#         transforms.Grayscale(),
#         transforms.PILToTensor(),
        transforms.ToTensor(),
#         transforms.Resize(256),
#         transforms.Normalize((0.5,), (0.5,)),
    ])
    valid_transforms = transforms.Compose([
        transforms.ToTensor(),
#         transforms.Resize(256),
#         transforms.Normalize((0.5,), (0.5,)),
#         transforms.ToPILImage(mode='RGB'),
        transforms.Resize(256),
#         transforms.PILToTensor(),
#         transforms.Normalize((0.5,), (0.5,)),
    ])

    train_cityscapes = Cityscapes(train_image_path, image_transforms, target_transforms)
    valid_cityscapes = Cityscapes(valid_image_path, valid_transforms, target_transforms)

    train_loader = DataLoader(train_cityscapes, batch_size=16, shuffle=True, drop_last=True)
    valid_loader = DataLoader(valid_cityscapes, batch_size=16, shuffle=True, drop_last=True)

    unet = UNet().to(current_device)
    ce_loss = nn.MSELoss().to(current_device)
    optimizer_adam = optim.Adam(unet.parameters(), lr=0.0001)
    continue_train = True
    if continue_train:
        trained_model_params = torch.load('../input/cityscapes-unet/unet-last.pth')
        unet.load_state_dict(trained_model_params['model_state_dict'])
        optimizer_adam.load_state_dict(trained_model_params['optimizer_state_dict'])
    train(train_loader, valid_loader, unet, optimizer_adam, ce_loss, epoch=50, device=current_device)
# Out:
# epoch 1 batch 1/185 loss = 0.0063
# epoch 1 batch 2/185 loss = 0.0059
# epoch 1 batch 3/185 loss = 0.0063
# epoch 1 batch 4/185 loss = 0.0056
# epoch 1 batch 5/185 loss = 0.0051
# epoch 1 batch 6/185 loss = 0.0064
# epoch 1 batch 7/185 loss = 0.0063
# epoch 1 batch 8/185 loss = 0.0069
# epoch 1 batch 9/185 loss = 0.0063
# epoch 1 batch 10/185 loss = 0.0063
# epoch 1 batch 11/185 loss = 0.0056
# epoch 1 batch 12/185 loss = 0.0055
# epoch 1 batch 13/185 loss = 0.0058
# epoch 1 batch 14/185 loss = 0.0064
# epoch 1 batch 15/185 loss = 0.0068
# epoch 1 batch 16/185 loss = 0.0059
# epoch 1 batch 17/185 loss = 0.0061
# epoch 1 batch 18/185 loss = 0.0067
# epoch 1 batch 19/185 loss = 0.0065
# epoch 1 batch 20/185 loss = 0.0063
# epoch 1 batch 21/185 loss = 0.0059
# epoch 1 batch 22/185 loss = 0.0072
# epoch 1 batch 23/185 loss = 0.0056
# epoch 1 batch 24/185 loss = 0.0052
# epoch 1 batch 25/185 loss = 0.0065
# epoch 1 batch 26/185 loss = 0.0055
# epoch 1 batch 27/185 loss = 0.0077
# epoch 1 batch 28/185 loss = 0.0064
# epoch 1 batch 29/185 loss = 0.0065
# epoch 1 batch 30/185 loss = 0.0052
# epoch 1 batch 31/185 loss = 0.0061
# epoch 1 batch 32/185 loss = 0.0057
# epoch 1 batch 33/185 loss = 0.0058
# epoch 1 batch 34/185 loss = 0.0051
# epoch 1 batch 35/185 loss = 0.0058
# epoch 1 batch 36/185 loss = 0.0059
# epoch 1 batch 37/185 loss = 0.0063
# epoch 1 batch 38/185 loss = 0.0052
# epoch 1 batch 39/185 loss = 0.0051
# epoch 1 batch 40/185 loss = 0.0045
# epoch 1 batch 41/185 loss = 0.0067
# epoch 1 batch 42/185 loss = 0.0068
# epoch 1 batch 43/185 loss = 0.0062
# epoch 1 batch 44/185 loss = 0.0064
# epoch 1 batch 45/185 loss = 0.0059
# epoch 1 batch 46/185 loss = 0.0064
# epoch 1 batch 47/185 loss = 0.0057
# epoch 1 batch 48/185 loss = 0.0073
# epoch 1 batch 49/185 loss = 0.0060
# epoch 1 batch 50/185 loss = 0.0058
# epoch 1 batch 51/185 loss = 0.0052
# epoch 1 batch 52/185 loss = 0.0065
# epoch 1 batch 53/185 loss = 0.0050
# epoch 1 batch 54/185 loss = 0.0059
# epoch 1 batch 55/185 loss = 0.0053
# epoch 1 batch 56/185 loss = 0.0058
# epoch 1 batch 57/185 loss = 0.0059
# epoch 1 batch 58/185 loss = 0.0069
# epoch 1 batch 59/185 loss = 0.0061
# epoch 1 batch 60/185 loss = 0.0060
# epoch 1 batch 61/185 loss = 0.0063
# epoch 1 batch 62/185 loss = 0.0060
# epoch 1 batch 63/185 loss = 0.0057
# epoch 1 batch 64/185 loss = 0.0048
# epoch 1 batch 65/185 loss = 0.0059
# epoch 1 batch 66/185 loss = 0.0059
# epoch 1 batch 67/185 loss = 0.0072
# epoch 1 batch 68/185 loss = 0.0063
# epoch 1 batch 69/185 loss = 0.0059
# epoch 1 batch 70/185 loss = 0.0060
# epoch 1 batch 71/185 loss = 0.0057
# epoch 1 batch 72/185 loss = 0.0057
# epoch 1 batch 73/185 loss = 0.0058
# epoch 1 batch 74/185 loss = 0.0062
# epoch 1 batch 75/185 loss = 0.0059
# epoch 1 batch 76/185 loss = 0.0050
# epoch 1 batch 77/185 loss = 0.0081
# epoch 1 batch 78/185 loss = 0.0074
# epoch 1 batch 79/185 loss = 0.0056
# epoch 1 batch 80/185 loss = 0.0040
# epoch 1 batch 81/185 loss = 0.0061
# epoch 1 batch 82/185 loss = 0.0059
# epoch 1 batch 83/185 loss = 0.0061
# epoch 1 batch 84/185 loss = 0.0073
# epoch 1 batch 85/185 loss = 0.0057
# epoch 1 batch 86/185 loss = 0.0053
# epoch 1 batch 87/185 loss = 0.0055
# epoch 1 batch 88/185 loss = 0.0082
# epoch 1 batch 89/185 loss = 0.0051
# epoch 1 batch 90/185 loss = 0.0070
# epoch 1 batch 91/185 loss = 0.0072
# epoch 1 batch 92/185 loss = 0.0058
# epoch 1 batch 93/185 loss = 0.0051
# epoch 1 batch 94/185 loss = 0.0052
# epoch 1 batch 95/185 loss = 0.0063
# epoch 1 batch 96/185 loss = 0.0055
# epoch 1 batch 97/185 loss = 0.0055
# epoch 1 batch 98/185 loss = 0.0062
# epoch 1 batch 99/185 loss = 0.0059
# epoch 1 batch 100/185 loss = 0.0056
# epoch 1 batch 101/185 loss = 0.0052
# epoch 1 batch 102/185 loss = 0.0059
# epoch 1 batch 103/185 loss = 0.0050
# epoch 1 batch 104/185 loss = 0.0067
# epoch 1 batch 105/185 loss = 0.0059
# epoch 1 batch 106/185 loss = 0.0078
# epoch 1 batch 107/185 loss = 0.0051
# epoch 1 batch 108/185 loss = 0.0059
# epoch 1 batch 109/185 loss = 0.0068
# epoch 1 batch 110/185 loss = 0.0052
# epoch 1 batch 111/185 loss = 0.0053
# epoch 1 batch 112/185 loss = 0.0063
# epoch 1 batch 113/185 loss = 0.0058
# epoch 1 batch 114/185 loss = 0.0048
# epoch 1 batch 115/185 loss = 0.0051
# epoch 1 batch 116/185 loss = 0.0058
# epoch 1 batch 117/185 loss = 0.0067
# epoch 1 batch 118/185 loss = 0.0067
# epoch 1 batch 119/185 loss = 0.0045
# epoch 1 batch 120/185 loss = 0.0055
# epoch 1 batch 121/185 loss = 0.0054
# epoch 1 batch 122/185 loss = 0.0052
# epoch 1 batch 123/185 loss = 0.0050
# epoch 1 batch 124/185 loss = 0.0063
# epoch 1 batch 125/185 loss = 0.0060
# epoch 1 batch 126/185 loss = 0.0042
# epoch 1 batch 127/185 loss = 0.0055
# epoch 1 batch 128/185 loss = 0.0053
# epoch 1 batch 129/185 loss = 0.0043
# epoch 1 batch 130/185 loss = 0.0054
# epoch 1 batch 131/185 loss = 0.0044
# epoch 1 batch 132/185 loss = 0.0058
# epoch 1 batch 133/185 loss = 0.0044
# epoch 1 batch 134/185 loss = 0.0055
# epoch 1 batch 135/185 loss = 0.0063
# epoch 1 batch 136/185 loss = 0.0059
# epoch 1 batch 137/185 loss = 0.0056
# epoch 1 batch 138/185 loss = 0.0062
# epoch 1 batch 139/185 loss = 0.0048
# epoch 1 batch 140/185 loss = 0.0062
# epoch 1 batch 141/185 loss = 0.0058
# epoch 1 batch 142/185 loss = 0.0058
# epoch 1 batch 143/185 loss = 0.0045
# epoch 1 batch 144/185 loss = 0.0052
# epoch 1 batch 145/185 loss = 0.0062
# epoch 1 batch 146/185 loss = 0.0051
# epoch 1 batch 147/185 loss = 0.0053
# epoch 1 batch 148/185 loss = 0.0061
# epoch 1 batch 149/185 loss = 0.0080
# epoch 1 batch 150/185 loss = 0.0049
# epoch 1 batch 151/185 loss = 0.0054
# epoch 1 batch 152/185 loss = 0.0057
# epoch 1 batch 153/185 loss = 0.0043
# epoch 1 batch 154/185 loss = 0.0062
# epoch 1 batch 155/185 loss = 0.0056
# epoch 1 batch 156/185 loss = 0.0051
# epoch 1 batch 157/185 loss = 0.0056
# epoch 1 batch 158/185 loss = 0.0056
# epoch 1 batch 159/185 loss = 0.0053
# epoch 1 batch 160/185 loss = 0.0058
# epoch 1 batch 161/185 loss = 0.0052
# epoch 1 batch 162/185 loss = 0.0052
# epoch 1 batch 163/185 loss = 0.0059
# epoch 1 batch 164/185 loss = 0.0048
# epoch 1 batch 165/185 loss = 0.0042
# epoch 1 batch 166/185 loss = 0.0049
# epoch 1 batch 167/185 loss = 0.0060
# epoch 1 batch 168/185 loss = 0.0050
# epoch 1 batch 169/185 loss = 0.0060
# epoch 1 batch 170/185 loss = 0.0051
# epoch 1 batch 171/185 loss = 0.0068
# epoch 1 batch 172/185 loss = 0.0049
# epoch 1 batch 173/185 loss = 0.0048
# epoch 1 batch 174/185 loss = 0.0047
# epoch 1 batch 175/185 loss = 0.0050
# epoch 1 batch 176/185 loss = 0.0045
# epoch 1 batch 177/185 loss = 0.0043
# epoch 1 batch 178/185 loss = 0.0053
# epoch 1 batch 179/185 loss = 0.0051
# epoch 1 batch 180/185 loss = 0.0054
# epoch 1 batch 181/185 loss = 0.0051
# epoch 1 batch 182/185 loss = 0.0055
# epoch 1 batch 183/185 loss = 0.0060
# epoch 1 batch 184/185 loss = 0.0047
# epoch 1 batch 185/185 loss = 0.0042
# epoch 1 train loss = 0.0058 valid loss = 0.0147
# epoch 2 batch 1/185 loss = 0.0062
# epoch 2 batch 2/185 loss = 0.0048
# epoch 2 batch 3/185 loss = 0.0046
# epoch 2 batch 4/185 loss = 0.0047
# epoch 2 batch 5/185 loss = 0.0056
# epoch 2 batch 6/185 loss = 0.0055
# epoch 2 batch 7/185 loss = 0.0059
# epoch 2 batch 8/185 loss = 0.0058
# epoch 2 batch 9/185 loss = 0.0041
# epoch 2 batch 10/185 loss = 0.0050
# epoch 2 batch 11/185 loss = 0.0044
# epoch 2 batch 12/185 loss = 0.0048
# epoch 2 batch 13/185 loss = 0.0044
# epoch 2 batch 14/185 loss = 0.0052
# epoch 2 batch 15/185 loss = 0.0046
# epoch 2 batch 16/185 loss = 0.0058
# epoch 2 batch 17/185 loss = 0.0046
# epoch 2 batch 18/185 loss = 0.0044
# epoch 2 batch 19/185 loss = 0.0055
# epoch 2 batch 20/185 loss = 0.0045
# epoch 2 batch 21/185 loss = 0.0044
# epoch 2 batch 22/185 loss = 0.0041
# epoch 2 batch 23/185 loss = 0.0042
# epoch 2 batch 24/185 loss = 0.0054
# epoch 2 batch 25/185 loss = 0.0058
# epoch 2 batch 26/185 loss = 0.0051
# epoch 2 batch 27/185 loss = 0.0057
# epoch 2 batch 28/185 loss = 0.0057
# epoch 2 batch 29/185 loss = 0.0053
# epoch 2 batch 30/185 loss = 0.0048
# epoch 2 batch 31/185 loss = 0.0052
# epoch 2 batch 32/185 loss = 0.0054
# epoch 2 batch 33/185 loss = 0.0048
# epoch 2 batch 34/185 loss = 0.0045
# epoch 2 batch 35/185 loss = 0.0056
# epoch 2 batch 36/185 loss = 0.0049
# epoch 2 batch 37/185 loss = 0.0059
# epoch 2 batch 38/185 loss = 0.0046
# epoch 2 batch 39/185 loss = 0.0048
# epoch 2 batch 40/185 loss = 0.0054
# epoch 2 batch 41/185 loss = 0.0058
# epoch 2 batch 42/185 loss = 0.0046
# epoch 2 batch 43/185 loss = 0.0040
# epoch 2 batch 44/185 loss = 0.0062
# epoch 2 batch 45/185 loss = 0.0048
# epoch 2 batch 46/185 loss = 0.0049
# epoch 2 batch 47/185 loss = 0.0058
# epoch 2 batch 48/185 loss = 0.0047
# epoch 2 batch 49/185 loss = 0.0046
# epoch 2 batch 50/185 loss = 0.0046
# epoch 2 batch 51/185 loss = 0.0064
# epoch 2 batch 52/185 loss = 0.0045
# epoch 2 batch 53/185 loss = 0.0053
# epoch 2 batch 54/185 loss = 0.0044
# epoch 2 batch 55/185 loss = 0.0054
# epoch 2 batch 56/185 loss = 0.0059
# epoch 2 batch 57/185 loss = 0.0050
# epoch 2 batch 58/185 loss = 0.0043
# epoch 2 batch 59/185 loss = 0.0048
# epoch 2 batch 60/185 loss = 0.0047
# epoch 2 batch 61/185 loss = 0.0051
# epoch 2 batch 62/185 loss = 0.0065
# epoch 2 batch 63/185 loss = 0.0041
# epoch 2 batch 64/185 loss = 0.0043
# epoch 2 batch 65/185 loss = 0.0049
# epoch 2 batch 66/185 loss = 0.0043
# epoch 2 batch 67/185 loss = 0.0059
# epoch 2 batch 68/185 loss = 0.0045
# epoch 2 batch 69/185 loss = 0.0047
# epoch 2 batch 70/185 loss = 0.0045
# epoch 2 batch 71/185 loss = 0.0051
# epoch 2 batch 72/185 loss = 0.0040
# epoch 2 batch 73/185 loss = 0.0048
# epoch 2 batch 74/185 loss = 0.0058
# epoch 2 batch 75/185 loss = 0.0059
# epoch 2 batch 76/185 loss = 0.0043
# epoch 2 batch 77/185 loss = 0.0045
# epoch 2 batch 78/185 loss = 0.0046
# epoch 2 batch 79/185 loss = 0.0049
# epoch 2 batch 80/185 loss = 0.0043
# epoch 2 batch 81/185 loss = 0.0042
# epoch 2 batch 82/185 loss = 0.0052
# epoch 2 batch 83/185 loss = 0.0045
# epoch 2 batch 84/185 loss = 0.0053
# epoch 2 batch 85/185 loss = 0.0041
# epoch 2 batch 86/185 loss = 0.0040
# epoch 2 batch 87/185 loss = 0.0063
# epoch 2 batch 88/185 loss = 0.0049
# epoch 2 batch 89/185 loss = 0.0043
# epoch 2 batch 90/185 loss = 0.0041
# epoch 2 batch 91/185 loss = 0.0054
# epoch 2 batch 92/185 loss = 0.0055
# epoch 2 batch 93/185 loss = 0.0052
# epoch 2 batch 94/185 loss = 0.0049
# epoch 2 batch 95/185 loss = 0.0046
# epoch 2 batch 96/185 loss = 0.0048
# epoch 2 batch 97/185 loss = 0.0044
# epoch 2 batch 98/185 loss = 0.0048
# epoch 2 batch 99/185 loss = 0.0042
# epoch 2 batch 100/185 loss = 0.0055
# epoch 2 batch 101/185 loss = 0.0045
# epoch 2 batch 102/185 loss = 0.0059
# epoch 2 batch 103/185 loss = 0.0045
# epoch 2 batch 104/185 loss = 0.0039
# epoch 2 batch 105/185 loss = 0.0052
# epoch 2 batch 106/185 loss = 0.0057
# epoch 2 batch 107/185 loss = 0.0039
# epoch 2 batch 108/185 loss = 0.0050
# epoch 2 batch 109/185 loss = 0.0042
# epoch 2 batch 110/185 loss = 0.0056
# epoch 2 batch 111/185 loss = 0.0052
# epoch 2 batch 112/185 loss = 0.0054
# epoch 2 batch 113/185 loss = 0.0048
# epoch 2 batch 114/185 loss = 0.0041
# epoch 2 batch 115/185 loss = 0.0044
# epoch 2 batch 116/185 loss = 0.0050
# epoch 2 batch 117/185 loss = 0.0046
# epoch 2 batch 118/185 loss = 0.0043
# epoch 2 batch 119/185 loss = 0.0059
# epoch 2 batch 120/185 loss = 0.0049
# epoch 2 batch 121/185 loss = 0.0048
# epoch 2 batch 122/185 loss = 0.0048
# epoch 2 batch 123/185 loss = 0.0049
# epoch 2 batch 124/185 loss = 0.0048
# epoch 2 batch 125/185 loss = 0.0032
# epoch 2 batch 126/185 loss = 0.0047
# epoch 2 batch 127/185 loss = 0.0045
# epoch 2 batch 128/185 loss = 0.0032
# epoch 2 batch 129/185 loss = 0.0046
# epoch 2 batch 130/185 loss = 0.0051
# epoch 2 batch 131/185 loss = 0.0034
# epoch 2 batch 132/185 loss = 0.0036
# epoch 2 batch 133/185 loss = 0.0046
# epoch 2 batch 134/185 loss = 0.0036
# epoch 2 batch 135/185 loss = 0.0044
# epoch 2 batch 136/185 loss = 0.0050
# epoch 2 batch 137/185 loss = 0.0051
# epoch 2 batch 138/185 loss = 0.0047
# epoch 2 batch 139/185 loss = 0.0042
# epoch 2 batch 140/185 loss = 0.0045
# epoch 2 batch 141/185 loss = 0.0040
# epoch 2 batch 142/185 loss = 0.0046
# epoch 2 batch 143/185 loss = 0.0042
# epoch 2 batch 144/185 loss = 0.0036
# epoch 2 batch 145/185 loss = 0.0053
# epoch 2 batch 146/185 loss = 0.0041
# epoch 2 batch 147/185 loss = 0.0051
# epoch 2 batch 148/185 loss = 0.0037
# epoch 2 batch 149/185 loss = 0.0039
# epoch 2 batch 150/185 loss = 0.0048
# epoch 2 batch 151/185 loss = 0.0053
# epoch 2 batch 152/185 loss = 0.0043
# epoch 2 batch 153/185 loss = 0.0050
# epoch 2 batch 154/185 loss = 0.0053
# epoch 2 batch 155/185 loss = 0.0044
# epoch 2 batch 156/185 loss = 0.0038
# epoch 2 batch 157/185 loss = 0.0052
# epoch 2 batch 158/185 loss = 0.0036
# epoch 2 batch 159/185 loss = 0.0037
# epoch 2 batch 160/185 loss = 0.0043
# epoch 2 batch 161/185 loss = 0.0041
# epoch 2 batch 162/185 loss = 0.0046
# epoch 2 batch 163/185 loss = 0.0054
# epoch 2 batch 164/185 loss = 0.0051
# epoch 2 batch 165/185 loss = 0.0048
# epoch 2 batch 166/185 loss = 0.0039
# epoch 2 batch 167/185 loss = 0.0047
# epoch 2 batch 168/185 loss = 0.0047
# epoch 2 batch 169/185 loss = 0.0043
# epoch 2 batch 170/185 loss = 0.0048
# epoch 2 batch 171/185 loss = 0.0037
# epoch 2 batch 172/185 loss = 0.0048
# epoch 2 batch 173/185 loss = 0.0038
# epoch 2 batch 174/185 loss = 0.0052
# epoch 2 batch 175/185 loss = 0.0034
# epoch 2 batch 176/185 loss = 0.0046
# epoch 2 batch 177/185 loss = 0.0043
# epoch 2 batch 178/185 loss = 0.0041
# epoch 2 batch 179/185 loss = 0.0050
# epoch 2 batch 180/185 loss = 0.0047
# epoch 2 batch 181/185 loss = 0.0039
# epoch 2 batch 182/185 loss = 0.0054
# epoch 2 batch 183/185 loss = 0.0049
# epoch 2 batch 184/185 loss = 0.0050
# epoch 2 batch 185/185 loss = 0.0045
# epoch 2 train loss = 0.0048 valid loss = 0.0145
# epoch 3 batch 1/185 loss = 0.0048
# epoch 3 batch 2/185 loss = 0.0039
# epoch 3 batch 3/185 loss = 0.0046
# epoch 3 batch 4/185 loss = 0.0054
# epoch 3 batch 5/185 loss = 0.0036
# epoch 3 batch 6/185 loss = 0.0043
# epoch 3 batch 7/185 loss = 0.0046
# epoch 3 batch 8/185 loss = 0.0043
# epoch 3 batch 9/185 loss = 0.0045
# epoch 3 batch 10/185 loss = 0.0053
# epoch 3 batch 11/185 loss = 0.0042
# epoch 3 batch 12/185 loss = 0.0039
# epoch 3 batch 13/185 loss = 0.0042
# epoch 3 batch 14/185 loss = 0.0042
# epoch 3 batch 15/185 loss = 0.0036
# epoch 3 batch 16/185 loss = 0.0042
# epoch 3 batch 17/185 loss = 0.0044
# epoch 3 batch 18/185 loss = 0.0048
# epoch 3 batch 19/185 loss = 0.0037
# epoch 3 batch 20/185 loss = 0.0058
# epoch 3 batch 21/185 loss = 0.0046
# epoch 3 batch 22/185 loss = 0.0047
# epoch 3 batch 23/185 loss = 0.0049
# epoch 3 batch 24/185 loss = 0.0045
# epoch 3 batch 25/185 loss = 0.0034
# epoch 3 batch 26/185 loss = 0.0036
# epoch 3 batch 27/185 loss = 0.0041
# epoch 3 batch 28/185 loss = 0.0043
# epoch 3 batch 29/185 loss = 0.0048
# epoch 3 batch 30/185 loss = 0.0038
# epoch 3 batch 31/185 loss = 0.0038
# epoch 3 batch 32/185 loss = 0.0041
# epoch 3 batch 33/185 loss = 0.0043
# epoch 3 batch 34/185 loss = 0.0042
# epoch 3 batch 35/185 loss = 0.0032
# epoch 3 batch 36/185 loss = 0.0045
# epoch 3 batch 37/185 loss = 0.0049
# epoch 3 batch 38/185 loss = 0.0037
# epoch 3 batch 39/185 loss = 0.0042
# epoch 3 batch 40/185 loss = 0.0039
# epoch 3 batch 41/185 loss = 0.0037
# epoch 3 batch 42/185 loss = 0.0046
# epoch 3 batch 43/185 loss = 0.0039
# epoch 3 batch 44/185 loss = 0.0039
# epoch 3 batch 45/185 loss = 0.0049
# epoch 3 batch 46/185 loss = 0.0053
# epoch 3 batch 47/185 loss = 0.0035
# epoch 3 batch 48/185 loss = 0.0037
# epoch 3 batch 49/185 loss = 0.0040
# epoch 3 batch 50/185 loss = 0.0035
# epoch 3 batch 51/185 loss = 0.0048
# epoch 3 batch 52/185 loss = 0.0047
# epoch 3 batch 53/185 loss = 0.0042
# epoch 3 batch 54/185 loss = 0.0044
# epoch 3 batch 55/185 loss = 0.0036
# epoch 3 batch 56/185 loss = 0.0043
# epoch 3 batch 57/185 loss = 0.0033
# epoch 3 batch 58/185 loss = 0.0044
# epoch 3 batch 59/185 loss = 0.0043
# epoch 3 batch 60/185 loss = 0.0044
# epoch 3 batch 61/185 loss = 0.0045
# epoch 3 batch 62/185 loss = 0.0036
# epoch 3 batch 63/185 loss = 0.0037
# epoch 3 batch 64/185 loss = 0.0029
# epoch 3 batch 65/185 loss = 0.0036
# epoch 3 batch 66/185 loss = 0.0053
# epoch 3 batch 67/185 loss = 0.0038
# epoch 3 batch 68/185 loss = 0.0029
# epoch 3 batch 69/185 loss = 0.0039
# epoch 3 batch 70/185 loss = 0.0044
# epoch 3 batch 71/185 loss = 0.0047
# epoch 3 batch 72/185 loss = 0.0042
# epoch 3 batch 73/185 loss = 0.0040
# epoch 3 batch 74/185 loss = 0.0038
# epoch 3 batch 75/185 loss = 0.0042
# epoch 3 batch 76/185 loss = 0.0054
# epoch 3 batch 77/185 loss = 0.0035
# epoch 3 batch 78/185 loss = 0.0037
# epoch 3 batch 79/185 loss = 0.0034
# epoch 3 batch 80/185 loss = 0.0048
# epoch 3 batch 81/185 loss = 0.0035
# epoch 3 batch 82/185 loss = 0.0036
# epoch 3 batch 83/185 loss = 0.0038
# epoch 3 batch 84/185 loss = 0.0041
# epoch 3 batch 85/185 loss = 0.0031
# epoch 3 batch 86/185 loss = 0.0044
# epoch 3 batch 87/185 loss = 0.0031
# epoch 3 batch 88/185 loss = 0.0032
# epoch 3 batch 89/185 loss = 0.0034
# epoch 3 batch 90/185 loss = 0.0042
# epoch 3 batch 91/185 loss = 0.0042
# epoch 3 batch 92/185 loss = 0.0049
# epoch 3 batch 93/185 loss = 0.0043
# epoch 3 batch 94/185 loss = 0.0046
# epoch 3 batch 95/185 loss = 0.0036
# epoch 3 batch 96/185 loss = 0.0050
# epoch 3 batch 97/185 loss = 0.0042
# epoch 3 batch 98/185 loss = 0.0044
# epoch 3 batch 99/185 loss = 0.0037
# epoch 3 batch 100/185 loss = 0.0040
# epoch 3 batch 101/185 loss = 0.0037
# epoch 3 batch 102/185 loss = 0.0042
# epoch 3 batch 103/185 loss = 0.0041
# epoch 3 batch 104/185 loss = 0.0041
# epoch 3 batch 105/185 loss = 0.0046
# epoch 3 batch 106/185 loss = 0.0049
# epoch 3 batch 107/185 loss = 0.0034
# epoch 3 batch 108/185 loss = 0.0043
# epoch 3 batch 109/185 loss = 0.0039
# epoch 3 batch 110/185 loss = 0.0040
# epoch 3 batch 111/185 loss = 0.0035
# epoch 3 batch 112/185 loss = 0.0044
# epoch 3 batch 113/185 loss = 0.0044
# epoch 3 batch 114/185 loss = 0.0031
# epoch 3 batch 115/185 loss = 0.0044
# epoch 3 batch 116/185 loss = 0.0036
# epoch 3 batch 117/185 loss = 0.0041
# epoch 3 batch 118/185 loss = 0.0039
# epoch 3 batch 119/185 loss = 0.0035
# epoch 3 batch 120/185 loss = 0.0036
# epoch 3 batch 121/185 loss = 0.0036
# epoch 3 batch 122/185 loss = 0.0035
# epoch 3 batch 123/185 loss = 0.0038
# epoch 3 batch 124/185 loss = 0.0040
# epoch 3 batch 125/185 loss = 0.0038
# epoch 3 batch 126/185 loss = 0.0040
# epoch 3 batch 127/185 loss = 0.0036
# epoch 3 batch 128/185 loss = 0.0043
# epoch 3 batch 129/185 loss = 0.0038
# epoch 3 batch 130/185 loss = 0.0042
# epoch 3 batch 131/185 loss = 0.0040
# epoch 3 batch 132/185 loss = 0.0050
# epoch 3 batch 133/185 loss = 0.0036
# epoch 3 batch 134/185 loss = 0.0045
# epoch 3 batch 135/185 loss = 0.0036
# epoch 3 batch 136/185 loss = 0.0032
# epoch 3 batch 137/185 loss = 0.0041
# epoch 3 batch 138/185 loss = 0.0035
# epoch 3 batch 139/185 loss = 0.0033
# epoch 3 batch 140/185 loss = 0.0031
# epoch 3 batch 141/185 loss = 0.0032
# epoch 3 batch 142/185 loss = 0.0033
# epoch 3 batch 143/185 loss = 0.0037
# epoch 3 batch 144/185 loss = 0.0044
# epoch 3 batch 145/185 loss = 0.0034
# epoch 3 batch 146/185 loss = 0.0038
# epoch 3 batch 147/185 loss = 0.0035
# epoch 3 batch 148/185 loss = 0.0031
# epoch 3 batch 149/185 loss = 0.0038
# epoch 3 batch 150/185 loss = 0.0037
# epoch 3 batch 151/185 loss = 0.0038
# epoch 3 batch 152/185 loss = 0.0037
# epoch 3 batch 153/185 loss = 0.0029
# epoch 3 batch 154/185 loss = 0.0038
# epoch 3 batch 155/185 loss = 0.0040
# epoch 3 batch 156/185 loss = 0.0035
# epoch 3 batch 157/185 loss = 0.0030
# epoch 3 batch 158/185 loss = 0.0034
# epoch 3 batch 159/185 loss = 0.0040
# epoch 3 batch 160/185 loss = 0.0037
# epoch 3 batch 161/185 loss = 0.0038
# epoch 3 batch 162/185 loss = 0.0039
# epoch 3 batch 163/185 loss = 0.0042
# epoch 3 batch 164/185 loss = 0.0033
# epoch 3 batch 165/185 loss = 0.0043
# epoch 3 batch 166/185 loss = 0.0036
# epoch 3 batch 167/185 loss = 0.0043
# epoch 3 batch 168/185 loss = 0.0033
# epoch 3 batch 169/185 loss = 0.0036
# epoch 3 batch 170/185 loss = 0.0041
# epoch 3 batch 171/185 loss = 0.0032
# epoch 3 batch 172/185 loss = 0.0034
# epoch 3 batch 173/185 loss = 0.0031
# epoch 3 batch 174/185 loss = 0.0043
# epoch 3 batch 175/185 loss = 0.0032
# epoch 3 batch 176/185 loss = 0.0045
# epoch 3 batch 177/185 loss = 0.0032
# epoch 3 batch 178/185 loss = 0.0032
# epoch 3 batch 179/185 loss = 0.0035
# epoch 3 batch 180/185 loss = 0.0052
# epoch 3 batch 181/185 loss = 0.0038
# epoch 3 batch 182/185 loss = 0.0041
# epoch 3 batch 183/185 loss = 0.0033
# epoch 3 batch 184/185 loss = 0.0034
# epoch 3 batch 185/185 loss = 0.0039
# epoch 3 train loss = 0.0040 valid loss = 0.0136
# epoch 4 batch 1/185 loss = 0.0034
# epoch 4 batch 2/185 loss = 0.0034
# epoch 4 batch 3/185 loss = 0.0028
# epoch 4 batch 4/185 loss = 0.0038
# epoch 4 batch 5/185 loss = 0.0039
# epoch 4 batch 6/185 loss = 0.0039
# epoch 4 batch 7/185 loss = 0.0034
# epoch 4 batch 8/185 loss = 0.0039
# epoch 4 batch 9/185 loss = 0.0039
# epoch 4 batch 10/185 loss = 0.0034
# epoch 4 batch 11/185 loss = 0.0035
# epoch 4 batch 12/185 loss = 0.0040
# epoch 4 batch 13/185 loss = 0.0030
# epoch 4 batch 14/185 loss = 0.0037
# epoch 4 batch 15/185 loss = 0.0037
# epoch 4 batch 16/185 loss = 0.0034
# epoch 4 batch 17/185 loss = 0.0039
# epoch 4 batch 18/185 loss = 0.0037
# epoch 4 batch 19/185 loss = 0.0038
# epoch 4 batch 20/185 loss = 0.0028
# epoch 4 batch 21/185 loss = 0.0043
# epoch 4 batch 22/185 loss = 0.0032
# epoch 4 batch 23/185 loss = 0.0031
# epoch 4 batch 24/185 loss = 0.0038
# epoch 4 batch 25/185 loss = 0.0030
# epoch 4 batch 26/185 loss = 0.0035
# epoch 4 batch 27/185 loss = 0.0035
# epoch 4 batch 28/185 loss = 0.0037
# epoch 4 batch 29/185 loss = 0.0034
# epoch 4 batch 30/185 loss = 0.0035
# epoch 4 batch 31/185 loss = 0.0032
# epoch 4 batch 32/185 loss = 0.0037
# epoch 4 batch 33/185 loss = 0.0023
# epoch 4 batch 34/185 loss = 0.0038
# epoch 4 batch 35/185 loss = 0.0034
# epoch 4 batch 36/185 loss = 0.0038
# epoch 4 batch 37/185 loss = 0.0040
# epoch 4 batch 38/185 loss = 0.0030
# epoch 4 batch 39/185 loss = 0.0041
# epoch 4 batch 40/185 loss = 0.0034
# epoch 4 batch 41/185 loss = 0.0037
# epoch 4 batch 42/185 loss = 0.0043
# epoch 4 batch 43/185 loss = 0.0029
# epoch 4 batch 44/185 loss = 0.0029
# epoch 4 batch 45/185 loss = 0.0031
# epoch 4 batch 46/185 loss = 0.0030
# epoch 4 batch 47/185 loss = 0.0047
# epoch 4 batch 48/185 loss = 0.0027
# epoch 4 batch 49/185 loss = 0.0035
# epoch 4 batch 50/185 loss = 0.0039
# epoch 4 batch 51/185 loss = 0.0035
# epoch 4 batch 52/185 loss = 0.0034
# epoch 4 batch 53/185 loss = 0.0036
# epoch 4 batch 54/185 loss = 0.0036
# epoch 4 batch 55/185 loss = 0.0034
# epoch 4 batch 56/185 loss = 0.0035
# epoch 4 batch 57/185 loss = 0.0034
# epoch 4 batch 58/185 loss = 0.0036
# epoch 4 batch 59/185 loss = 0.0031
# epoch 4 batch 60/185 loss = 0.0036
# epoch 4 batch 61/185 loss = 0.0039
# epoch 4 batch 62/185 loss = 0.0039
# epoch 4 batch 63/185 loss = 0.0040
# epoch 4 batch 64/185 loss = 0.0034
# epoch 4 batch 65/185 loss = 0.0047
# epoch 4 batch 66/185 loss = 0.0032
# epoch 4 batch 67/185 loss = 0.0030
# epoch 4 batch 68/185 loss = 0.0031
# epoch 4 batch 69/185 loss = 0.0029
# epoch 4 batch 70/185 loss = 0.0042
# epoch 4 batch 71/185 loss = 0.0035
# epoch 4 batch 72/185 loss = 0.0028
# epoch 4 batch 73/185 loss = 0.0040
# epoch 4 batch 74/185 loss = 0.0030
# epoch 4 batch 75/185 loss = 0.0026
# epoch 4 batch 76/185 loss = 0.0033
# epoch 4 batch 77/185 loss = 0.0033
# epoch 4 batch 78/185 loss = 0.0038
# epoch 4 batch 79/185 loss = 0.0033
# epoch 4 batch 80/185 loss = 0.0038
# epoch 4 batch 81/185 loss = 0.0033
# epoch 4 batch 82/185 loss = 0.0039
# epoch 4 batch 83/185 loss = 0.0036
# epoch 4 batch 84/185 loss = 0.0036
# epoch 4 batch 85/185 loss = 0.0033
# epoch 4 batch 86/185 loss = 0.0043
# epoch 4 batch 87/185 loss = 0.0038
# epoch 4 batch 88/185 loss = 0.0034
# epoch 4 batch 89/185 loss = 0.0040
# epoch 4 batch 90/185 loss = 0.0030
# epoch 4 batch 91/185 loss = 0.0037
# epoch 4 batch 92/185 loss = 0.0035
# epoch 4 batch 93/185 loss = 0.0033
# epoch 4 batch 94/185 loss = 0.0031
# epoch 4 batch 95/185 loss = 0.0035
# epoch 4 batch 96/185 loss = 0.0036
# epoch 4 batch 97/185 loss = 0.0038
# epoch 4 batch 98/185 loss = 0.0030
# epoch 4 batch 99/185 loss = 0.0035
# epoch 4 batch 100/185 loss = 0.0024
# epoch 4 batch 101/185 loss = 0.0029
# epoch 4 batch 102/185 loss = 0.0031
# epoch 4 batch 103/185 loss = 0.0032
# epoch 4 batch 104/185 loss = 0.0033
# epoch 4 batch 105/185 loss = 0.0033
# epoch 4 batch 106/185 loss = 0.0029
# epoch 4 batch 107/185 loss = 0.0034
# epoch 4 batch 108/185 loss = 0.0032
# epoch 4 batch 109/185 loss = 0.0030
# epoch 4 batch 110/185 loss = 0.0034
# epoch 4 batch 111/185 loss = 0.0038
# epoch 4 batch 112/185 loss = 0.0035
# epoch 4 batch 113/185 loss = 0.0035
# epoch 4 batch 114/185 loss = 0.0039
# epoch 4 batch 115/185 loss = 0.0029
# epoch 4 batch 116/185 loss = 0.0043
# epoch 4 batch 117/185 loss = 0.0029
# epoch 4 batch 118/185 loss = 0.0040
# epoch 4 batch 119/185 loss = 0.0034
# epoch 4 batch 120/185 loss = 0.0034
# epoch 4 batch 121/185 loss = 0.0025
# epoch 4 batch 122/185 loss = 0.0041
# epoch 4 batch 123/185 loss = 0.0029
# epoch 4 batch 124/185 loss = 0.0036
# epoch 4 batch 125/185 loss = 0.0031
# epoch 4 batch 126/185 loss = 0.0034
# epoch 4 batch 127/185 loss = 0.0033
# epoch 4 batch 128/185 loss = 0.0027
# epoch 4 batch 129/185 loss = 0.0032
# epoch 4 batch 130/185 loss = 0.0031
# epoch 4 batch 131/185 loss = 0.0033
# epoch 4 batch 132/185 loss = 0.0031
# epoch 4 batch 133/185 loss = 0.0031
# epoch 4 batch 134/185 loss = 0.0029
# epoch 4 batch 135/185 loss = 0.0038
# epoch 4 batch 136/185 loss = 0.0028
# epoch 4 batch 137/185 loss = 0.0041
# epoch 4 batch 138/185 loss = 0.0024
# epoch 4 batch 139/185 loss = 0.0029
# epoch 4 batch 140/185 loss = 0.0038
# epoch 4 batch 141/185 loss = 0.0034
# epoch 4 batch 142/185 loss = 0.0026
# epoch 4 batch 143/185 loss = 0.0032
# epoch 4 batch 144/185 loss = 0.0030
# epoch 4 batch 145/185 loss = 0.0035
# epoch 4 batch 146/185 loss = 0.0032
# epoch 4 batch 147/185 loss = 0.0044
# epoch 4 batch 148/185 loss = 0.0038
# epoch 4 batch 149/185 loss = 0.0028
# epoch 4 batch 150/185 loss = 0.0035
# epoch 4 batch 151/185 loss = 0.0029
# epoch 4 batch 152/185 loss = 0.0044
# epoch 4 batch 153/185 loss = 0.0029
# epoch 4 batch 154/185 loss = 0.0029
# epoch 4 batch 155/185 loss = 0.0031
# epoch 4 batch 156/185 loss = 0.0033
# epoch 4 batch 157/185 loss = 0.0040
# epoch 4 batch 158/185 loss = 0.0031
# epoch 4 batch 159/185 loss = 0.0032
# epoch 4 batch 160/185 loss = 0.0039
# epoch 4 batch 161/185 loss = 0.0037
# epoch 4 batch 162/185 loss = 0.0028
# epoch 4 batch 163/185 loss = 0.0036
# epoch 4 batch 164/185 loss = 0.0033
# epoch 4 batch 165/185 loss = 0.0042
# epoch 4 batch 166/185 loss = 0.0036
# epoch 4 batch 167/185 loss = 0.0028
# epoch 4 batch 168/185 loss = 0.0032
# epoch 4 batch 169/185 loss = 0.0036
# epoch 4 batch 170/185 loss = 0.0025
# epoch 4 batch 171/185 loss = 0.0034
# epoch 4 batch 172/185 loss = 0.0032
# epoch 4 batch 173/185 loss = 0.0031
# epoch 4 batch 174/185 loss = 0.0035
# epoch 4 batch 175/185 loss = 0.0031
# epoch 4 batch 176/185 loss = 0.0032
# epoch 4 batch 177/185 loss = 0.0037
# epoch 4 batch 178/185 loss = 0.0029
# epoch 4 batch 179/185 loss = 0.0040
# epoch 4 batch 180/185 loss = 0.0038
# epoch 4 batch 181/185 loss = 0.0034
# epoch 4 batch 182/185 loss = 0.0033
# epoch 4 batch 183/185 loss = 0.0033
# epoch 4 batch 184/185 loss = 0.0032
# epoch 4 batch 185/185 loss = 0.0038
# epoch 4 train loss = 0.0034 valid loss = 0.0131
# epoch 5 batch 1/185 loss = 0.0027
# epoch 5 batch 2/185 loss = 0.0038
# epoch 5 batch 3/185 loss = 0.0028
# epoch 5 batch 4/185 loss = 0.0032
# epoch 5 batch 5/185 loss = 0.0028
# epoch 5 batch 6/185 loss = 0.0033
# epoch 5 batch 7/185 loss = 0.0023
# epoch 5 batch 8/185 loss = 0.0028
# epoch 5 batch 9/185 loss = 0.0032
# epoch 5 batch 10/185 loss = 0.0032
# epoch 5 batch 11/185 loss = 0.0033
# epoch 5 batch 12/185 loss = 0.0032
# epoch 5 batch 13/185 loss = 0.0031
# epoch 5 batch 14/185 loss = 0.0037
# epoch 5 batch 15/185 loss = 0.0028
# epoch 5 batch 16/185 loss = 0.0027
# epoch 5 batch 17/185 loss = 0.0025
# epoch 5 batch 18/185 loss = 0.0025
# epoch 5 batch 19/185 loss = 0.0030
# epoch 5 batch 20/185 loss = 0.0031
# epoch 5 batch 21/185 loss = 0.0026
# epoch 5 batch 22/185 loss = 0.0031
# epoch 5 batch 23/185 loss = 0.0034
# epoch 5 batch 24/185 loss = 0.0031
# epoch 5 batch 25/185 loss = 0.0028
# epoch 5 batch 26/185 loss = 0.0032
# epoch 5 batch 27/185 loss = 0.0033
# epoch 5 batch 28/185 loss = 0.0038
# epoch 5 batch 29/185 loss = 0.0028
# epoch 5 batch 30/185 loss = 0.0033
# epoch 5 batch 31/185 loss = 0.0049
# epoch 5 batch 32/185 loss = 0.0030
# epoch 5 batch 33/185 loss = 0.0030
# epoch 5 batch 34/185 loss = 0.0040
# epoch 5 batch 35/185 loss = 0.0034
# epoch 5 batch 36/185 loss = 0.0038
# epoch 5 batch 37/185 loss = 0.0028
# epoch 5 batch 38/185 loss = 0.0042
# epoch 5 batch 39/185 loss = 0.0030
# epoch 5 batch 40/185 loss = 0.0032
# epoch 5 batch 41/185 loss = 0.0024
# epoch 5 batch 42/185 loss = 0.0027
# epoch 5 batch 43/185 loss = 0.0026
# epoch 5 batch 44/185 loss = 0.0040
# epoch 5 batch 45/185 loss = 0.0030
# epoch 5 batch 46/185 loss = 0.0038
# epoch 5 batch 47/185 loss = 0.0028
# epoch 5 batch 48/185 loss = 0.0033
# epoch 5 batch 49/185 loss = 0.0042
# epoch 5 batch 50/185 loss = 0.0034
# epoch 5 batch 51/185 loss = 0.0034
# epoch 5 batch 52/185 loss = 0.0025
# epoch 5 batch 53/185 loss = 0.0033
# epoch 5 batch 54/185 loss = 0.0026
# epoch 5 batch 55/185 loss = 0.0035
# epoch 5 batch 56/185 loss = 0.0030
# epoch 5 batch 57/185 loss = 0.0027
# epoch 5 batch 58/185 loss = 0.0033
# epoch 5 batch 59/185 loss = 0.0035
# epoch 5 batch 60/185 loss = 0.0027
# epoch 5 batch 61/185 loss = 0.0032
# epoch 5 batch 62/185 loss = 0.0037
# epoch 5 batch 63/185 loss = 0.0038
# epoch 5 batch 64/185 loss = 0.0027
# epoch 5 batch 65/185 loss = 0.0025
# epoch 5 batch 66/185 loss = 0.0031
# epoch 5 batch 67/185 loss = 0.0031
# epoch 5 batch 68/185 loss = 0.0037
# epoch 5 batch 69/185 loss = 0.0028
# epoch 5 batch 70/185 loss = 0.0039
# epoch 5 batch 71/185 loss = 0.0028
# epoch 5 batch 72/185 loss = 0.0029
# epoch 5 batch 73/185 loss = 0.0034
# epoch 5 batch 74/185 loss = 0.0025
# epoch 5 batch 75/185 loss = 0.0027
# epoch 5 batch 76/185 loss = 0.0027
# epoch 5 batch 77/185 loss = 0.0026
# epoch 5 batch 78/185 loss = 0.0029
# epoch 5 batch 79/185 loss = 0.0030
# epoch 5 batch 80/185 loss = 0.0031
# epoch 5 batch 81/185 loss = 0.0032
# epoch 5 batch 82/185 loss = 0.0027
# epoch 5 batch 83/185 loss = 0.0035
# epoch 5 batch 84/185 loss = 0.0031
# epoch 5 batch 85/185 loss = 0.0029
# epoch 5 batch 86/185 loss = 0.0027
# epoch 5 batch 87/185 loss = 0.0026
# epoch 5 batch 88/185 loss = 0.0025
# epoch 5 batch 89/185 loss = 0.0030
# epoch 5 batch 90/185 loss = 0.0031
# epoch 5 batch 91/185 loss = 0.0028
# epoch 5 batch 92/185 loss = 0.0034
# epoch 5 batch 93/185 loss = 0.0030
# epoch 5 batch 94/185 loss = 0.0028
# epoch 5 batch 95/185 loss = 0.0024
# epoch 5 batch 96/185 loss = 0.0028
# epoch 5 batch 97/185 loss = 0.0023
# epoch 5 batch 98/185 loss = 0.0023
# epoch 5 batch 99/185 loss = 0.0034
# epoch 5 batch 100/185 loss = 0.0027
# epoch 5 batch 101/185 loss = 0.0029
# epoch 5 batch 102/185 loss = 0.0031
# epoch 5 batch 103/185 loss = 0.0028
# epoch 5 batch 104/185 loss = 0.0030
# epoch 5 batch 105/185 loss = 0.0026
# epoch 5 batch 106/185 loss = 0.0029
# epoch 5 batch 107/185 loss = 0.0032
# epoch 5 batch 108/185 loss = 0.0035
# epoch 5 batch 109/185 loss = 0.0029
# epoch 5 batch 110/185 loss = 0.0028
# epoch 5 batch 111/185 loss = 0.0029
# epoch 5 batch 112/185 loss = 0.0032
# epoch 5 batch 113/185 loss = 0.0028
# epoch 5 batch 114/185 loss = 0.0030
# epoch 5 batch 115/185 loss = 0.0030
# epoch 5 batch 116/185 loss = 0.0029
# epoch 5 batch 117/185 loss = 0.0030
# epoch 5 batch 118/185 loss = 0.0025
# epoch 5 batch 119/185 loss = 0.0029
# epoch 5 batch 120/185 loss = 0.0026
# epoch 5 batch 121/185 loss = 0.0026
# epoch 5 batch 122/185 loss = 0.0034
# epoch 5 batch 123/185 loss = 0.0024
# epoch 5 batch 124/185 loss = 0.0029
# epoch 5 batch 125/185 loss = 0.0027
# epoch 5 batch 126/185 loss = 0.0025
# epoch 5 batch 127/185 loss = 0.0022
# epoch 5 batch 128/185 loss = 0.0030
# epoch 5 batch 129/185 loss = 0.0029
# epoch 5 batch 130/185 loss = 0.0024
# epoch 5 batch 131/185 loss = 0.0025
# epoch 5 batch 132/185 loss = 0.0030
# epoch 5 batch 133/185 loss = 0.0041
# epoch 5 batch 134/185 loss = 0.0023
# epoch 5 batch 135/185 loss = 0.0029
# epoch 5 batch 136/185 loss = 0.0038
# epoch 5 batch 137/185 loss = 0.0029
# epoch 5 batch 138/185 loss = 0.0027
# epoch 5 batch 139/185 loss = 0.0026
# epoch 5 batch 140/185 loss = 0.0025
# epoch 5 batch 141/185 loss = 0.0024
# epoch 5 batch 142/185 loss = 0.0029
# epoch 5 batch 143/185 loss = 0.0034
# epoch 5 batch 144/185 loss = 0.0026
# epoch 5 batch 145/185 loss = 0.0032
# epoch 5 batch 146/185 loss = 0.0029
# epoch 5 batch 147/185 loss = 0.0025
# epoch 5 batch 148/185 loss = 0.0026
# epoch 5 batch 149/185 loss = 0.0029
# epoch 5 batch 150/185 loss = 0.0021
# epoch 5 batch 151/185 loss = 0.0029
# epoch 5 batch 152/185 loss = 0.0024
# epoch 5 batch 153/185 loss = 0.0032
# epoch 5 batch 154/185 loss = 0.0022
# epoch 5 batch 155/185 loss = 0.0020
# epoch 5 batch 156/185 loss = 0.0037
# epoch 5 batch 157/185 loss = 0.0025
# epoch 5 batch 158/185 loss = 0.0029
# epoch 5 batch 159/185 loss = 0.0027
# epoch 5 batch 160/185 loss = 0.0031
# epoch 5 batch 161/185 loss = 0.0037
# epoch 5 batch 162/185 loss = 0.0032
# epoch 5 batch 163/185 loss = 0.0024
# epoch 5 batch 164/185 loss = 0.0027
# epoch 5 batch 165/185 loss = 0.0023
# epoch 5 batch 166/185 loss = 0.0024
# epoch 5 batch 167/185 loss = 0.0028
# epoch 5 batch 168/185 loss = 0.0022
# epoch 5 batch 169/185 loss = 0.0027
# epoch 5 batch 170/185 loss = 0.0030
# epoch 5 batch 171/185 loss = 0.0037
# epoch 5 batch 172/185 loss = 0.0034
# epoch 5 batch 173/185 loss = 0.0031
# epoch 5 batch 174/185 loss = 0.0026
# epoch 5 batch 175/185 loss = 0.0026
# epoch 5 batch 176/185 loss = 0.0029
# epoch 5 batch 177/185 loss = 0.0031
# epoch 5 batch 178/185 loss = 0.0022
# epoch 5 batch 179/185 loss = 0.0031
# epoch 5 batch 180/185 loss = 0.0029
# epoch 5 batch 181/185 loss = 0.0023
# epoch 5 batch 182/185 loss = 0.0031
# epoch 5 batch 183/185 loss = 0.0026
# epoch 5 batch 184/185 loss = 0.0029
# epoch 5 batch 185/185 loss = 0.0023
# epoch 5 train loss = 0.0030 valid loss = 0.0126
# epoch 6 batch 1/185 loss = 0.0023
# epoch 6 batch 2/185 loss = 0.0029
# epoch 6 batch 3/185 loss = 0.0028
# epoch 6 batch 4/185 loss = 0.0026
# epoch 6 batch 5/185 loss = 0.0025
# epoch 6 batch 6/185 loss = 0.0024
# epoch 6 batch 7/185 loss = 0.0028
# epoch 6 batch 8/185 loss = 0.0022
# epoch 6 batch 9/185 loss = 0.0031
# epoch 6 batch 10/185 loss = 0.0025
# epoch 6 batch 11/185 loss = 0.0031
# epoch 6 batch 12/185 loss = 0.0023
# epoch 6 batch 13/185 loss = 0.0032
# epoch 6 batch 14/185 loss = 0.0024
# epoch 6 batch 15/185 loss = 0.0029
# epoch 6 batch 16/185 loss = 0.0034
# epoch 6 batch 17/185 loss = 0.0022
# epoch 6 batch 18/185 loss = 0.0028
# epoch 6 batch 19/185 loss = 0.0035
# epoch 6 batch 20/185 loss = 0.0027
# epoch 6 batch 21/185 loss = 0.0027
# epoch 6 batch 22/185 loss = 0.0028
# epoch 6 batch 23/185 loss = 0.0025
# epoch 6 batch 24/185 loss = 0.0032
# epoch 6 batch 25/185 loss = 0.0026
# epoch 6 batch 26/185 loss = 0.0029
# epoch 6 batch 27/185 loss = 0.0029
# epoch 6 batch 28/185 loss = 0.0023
# epoch 6 batch 29/185 loss = 0.0033
# epoch 6 batch 30/185 loss = 0.0033
# epoch 6 batch 31/185 loss = 0.0030
# epoch 6 batch 32/185 loss = 0.0025
# epoch 6 batch 33/185 loss = 0.0026
# epoch 6 batch 34/185 loss = 0.0023
# epoch 6 batch 35/185 loss = 0.0025
# epoch 6 batch 36/185 loss = 0.0029
# epoch 6 batch 37/185 loss = 0.0028
# epoch 6 batch 38/185 loss = 0.0025
# epoch 6 batch 39/185 loss = 0.0027
# epoch 6 batch 40/185 loss = 0.0024
# epoch 6 batch 41/185 loss = 0.0031
# epoch 6 batch 42/185 loss = 0.0026
# epoch 6 batch 43/185 loss = 0.0025
# epoch 6 batch 44/185 loss = 0.0029
# epoch 6 batch 45/185 loss = 0.0035
# epoch 6 batch 46/185 loss = 0.0023
# epoch 6 batch 47/185 loss = 0.0034
# epoch 6 batch 48/185 loss = 0.0022
# epoch 6 batch 49/185 loss = 0.0019
# epoch 6 batch 50/185 loss = 0.0026
# epoch 6 batch 51/185 loss = 0.0020
# epoch 6 batch 52/185 loss = 0.0033
# epoch 6 batch 53/185 loss = 0.0029
# epoch 6 batch 54/185 loss = 0.0024
# epoch 6 batch 55/185 loss = 0.0027
# epoch 6 batch 56/185 loss = 0.0020
# epoch 6 batch 57/185 loss = 0.0029
# epoch 6 batch 58/185 loss = 0.0029
# epoch 6 batch 59/185 loss = 0.0020
# epoch 6 batch 60/185 loss = 0.0021
# epoch 6 batch 61/185 loss = 0.0022
# epoch 6 batch 62/185 loss = 0.0023
# epoch 6 batch 63/185 loss = 0.0025
# epoch 6 batch 64/185 loss = 0.0025
# epoch 6 batch 65/185 loss = 0.0028
# epoch 6 batch 66/185 loss = 0.0026
# epoch 6 batch 67/185 loss = 0.0029
# epoch 6 batch 68/185 loss = 0.0021
# epoch 6 batch 69/185 loss = 0.0028
# epoch 6 batch 70/185 loss = 0.0036
# epoch 6 batch 71/185 loss = 0.0029
# epoch 6 batch 72/185 loss = 0.0019
# epoch 6 batch 73/185 loss = 0.0028
# epoch 6 batch 74/185 loss = 0.0020
# epoch 6 batch 75/185 loss = 0.0030
# epoch 6 batch 76/185 loss = 0.0032
# epoch 6 batch 77/185 loss = 0.0024
# epoch 6 batch 78/185 loss = 0.0028
# epoch 6 batch 79/185 loss = 0.0019
# epoch 6 batch 80/185 loss = 0.0022
# epoch 6 batch 81/185 loss = 0.0026
# epoch 6 batch 82/185 loss = 0.0032
# epoch 6 batch 83/185 loss = 0.0026
# epoch 6 batch 84/185 loss = 0.0022
# epoch 6 batch 85/185 loss = 0.0026
# epoch 6 batch 86/185 loss = 0.0017
# epoch 6 batch 87/185 loss = 0.0028
# epoch 6 batch 88/185 loss = 0.0028
# epoch 6 batch 89/185 loss = 0.0027
# epoch 6 batch 90/185 loss = 0.0029
# epoch 6 batch 91/185 loss = 0.0027
# epoch 6 batch 92/185 loss = 0.0022
# epoch 6 batch 93/185 loss = 0.0025
# epoch 6 batch 94/185 loss = 0.0028
# epoch 6 batch 95/185 loss = 0.0025
# epoch 6 batch 96/185 loss = 0.0024
# epoch 6 batch 97/185 loss = 0.0029
# epoch 6 batch 98/185 loss = 0.0023
# epoch 6 batch 99/185 loss = 0.0025
# epoch 6 batch 100/185 loss = 0.0023
# epoch 6 batch 101/185 loss = 0.0024
# epoch 6 batch 102/185 loss = 0.0022
# epoch 6 batch 103/185 loss = 0.0025
# epoch 6 batch 104/185 loss = 0.0028
# epoch 6 batch 105/185 loss = 0.0019
# epoch 6 batch 106/185 loss = 0.0026
# epoch 6 batch 107/185 loss = 0.0024
# epoch 6 batch 108/185 loss = 0.0026
# epoch 6 batch 109/185 loss = 0.0024
# epoch 6 batch 110/185 loss = 0.0027
# epoch 6 batch 111/185 loss = 0.0027
# epoch 6 batch 112/185 loss = 0.0022
# epoch 6 batch 113/185 loss = 0.0024
# epoch 6 batch 114/185 loss = 0.0025
# epoch 6 batch 115/185 loss = 0.0023
# epoch 6 batch 116/185 loss = 0.0022
# epoch 6 batch 117/185 loss = 0.0026
# epoch 6 batch 118/185 loss = 0.0021
# epoch 6 batch 119/185 loss = 0.0024
# epoch 6 batch 120/185 loss = 0.0024
# epoch 6 batch 121/185 loss = 0.0023
# epoch 6 batch 122/185 loss = 0.0024
# epoch 6 batch 123/185 loss = 0.0029
# epoch 6 batch 124/185 loss = 0.0021
# epoch 6 batch 125/185 loss = 0.0022
# epoch 6 batch 126/185 loss = 0.0021
# epoch 6 batch 127/185 loss = 0.0026
# epoch 6 batch 128/185 loss = 0.0024
# epoch 6 batch 129/185 loss = 0.0022
# epoch 6 batch 130/185 loss = 0.0030
# epoch 6 batch 131/185 loss = 0.0029
# epoch 6 batch 132/185 loss = 0.0020
# epoch 6 batch 133/185 loss = 0.0032
# epoch 6 batch 134/185 loss = 0.0032
# epoch 6 batch 135/185 loss = 0.0024
# epoch 6 batch 136/185 loss = 0.0026
# epoch 6 batch 137/185 loss = 0.0025
# epoch 6 batch 138/185 loss = 0.0028
# epoch 6 batch 139/185 loss = 0.0020
# epoch 6 batch 140/185 loss = 0.0026
# epoch 6 batch 141/185 loss = 0.0030
# epoch 6 batch 142/185 loss = 0.0026
# epoch 6 batch 143/185 loss = 0.0027
# epoch 6 batch 144/185 loss = 0.0021
# epoch 6 batch 145/185 loss = 0.0029
# epoch 6 batch 146/185 loss = 0.0027
# epoch 6 batch 147/185 loss = 0.0025
# epoch 6 batch 148/185 loss = 0.0024
# epoch 6 batch 149/185 loss = 0.0024
# epoch 6 batch 150/185 loss = 0.0025
# epoch 6 batch 151/185 loss = 0.0027
# epoch 6 batch 152/185 loss = 0.0029
# epoch 6 batch 153/185 loss = 0.0021
# epoch 6 batch 154/185 loss = 0.0028
# epoch 6 batch 155/185 loss = 0.0025
# epoch 6 batch 156/185 loss = 0.0021
# epoch 6 batch 157/185 loss = 0.0030
# epoch 6 batch 158/185 loss = 0.0028
# epoch 6 batch 159/185 loss = 0.0037
# epoch 6 batch 160/185 loss = 0.0025
# epoch 6 batch 161/185 loss = 0.0023
# epoch 6 batch 162/185 loss = 0.0025
# epoch 6 batch 163/185 loss = 0.0025
# epoch 6 batch 164/185 loss = 0.0022
# epoch 6 batch 165/185 loss = 0.0023
# epoch 6 batch 166/185 loss = 0.0022
# epoch 6 batch 167/185 loss = 0.0021
# epoch 6 batch 168/185 loss = 0.0030
# epoch 6 batch 169/185 loss = 0.0020
# epoch 6 batch 170/185 loss = 0.0026
# epoch 6 batch 171/185 loss = 0.0021
# epoch 6 batch 172/185 loss = 0.0022
# epoch 6 batch 173/185 loss = 0.0024
# epoch 6 batch 174/185 loss = 0.0023
# epoch 6 batch 175/185 loss = 0.0026
# epoch 6 batch 176/185 loss = 0.0032
# epoch 6 batch 177/185 loss = 0.0026
# epoch 6 batch 178/185 loss = 0.0022
# epoch 6 batch 179/185 loss = 0.0027
# epoch 6 batch 180/185 loss = 0.0022
# epoch 6 batch 181/185 loss = 0.0022
# epoch 6 batch 182/185 loss = 0.0022
# epoch 6 batch 183/185 loss = 0.0028
# epoch 6 batch 184/185 loss = 0.0026
# epoch 6 batch 185/185 loss = 0.0024
# epoch 6 train loss = 0.0026 valid loss = 0.0122
# epoch 7 batch 1/185 loss = 0.0024
# epoch 7 batch 2/185 loss = 0.0022
# epoch 7 batch 3/185 loss = 0.0029
# epoch 7 batch 4/185 loss = 0.0020
# epoch 7 batch 5/185 loss = 0.0023
# epoch 7 batch 6/185 loss = 0.0024
# epoch 7 batch 7/185 loss = 0.0026
# epoch 7 batch 8/185 loss = 0.0024
# epoch 7 batch 9/185 loss = 0.0023
# epoch 7 batch 10/185 loss = 0.0026
# epoch 7 batch 11/185 loss = 0.0021
# epoch 7 batch 12/185 loss = 0.0021
# epoch 7 batch 13/185 loss = 0.0024
# epoch 7 batch 14/185 loss = 0.0024
# epoch 7 batch 15/185 loss = 0.0022
# epoch 7 batch 16/185 loss = 0.0022
# epoch 7 batch 17/185 loss = 0.0022
# epoch 7 batch 18/185 loss = 0.0019
# epoch 7 batch 19/185 loss = 0.0024
# epoch 7 batch 20/185 loss = 0.0025
# epoch 7 batch 21/185 loss = 0.0021
# epoch 7 batch 22/185 loss = 0.0024
# epoch 7 batch 23/185 loss = 0.0022
# epoch 7 batch 24/185 loss = 0.0024
# epoch 7 batch 25/185 loss = 0.0021
# epoch 7 batch 26/185 loss = 0.0029
# epoch 7 batch 27/185 loss = 0.0022
# epoch 7 batch 28/185 loss = 0.0026
# epoch 7 batch 29/185 loss = 0.0023
# epoch 7 batch 30/185 loss = 0.0025
# epoch 7 batch 31/185 loss = 0.0021
# epoch 7 batch 32/185 loss = 0.0020
# epoch 7 batch 33/185 loss = 0.0022
# epoch 7 batch 34/185 loss = 0.0024
# epoch 7 batch 35/185 loss = 0.0026
# epoch 7 batch 36/185 loss = 0.0023
# epoch 7 batch 37/185 loss = 0.0023
# epoch 7 batch 38/185 loss = 0.0019
# epoch 7 batch 39/185 loss = 0.0028
# epoch 7 batch 40/185 loss = 0.0022
# epoch 7 batch 41/185 loss = 0.0023
# epoch 7 batch 42/185 loss = 0.0024
# epoch 7 batch 43/185 loss = 0.0029
# epoch 7 batch 44/185 loss = 0.0021
# epoch 7 batch 45/185 loss = 0.0021
# epoch 7 batch 46/185 loss = 0.0023
# epoch 7 batch 47/185 loss = 0.0029
# epoch 7 batch 48/185 loss = 0.0031
# epoch 7 batch 49/185 loss = 0.0020
# epoch 7 batch 50/185 loss = 0.0026
# epoch 7 batch 51/185 loss = 0.0032
# epoch 7 batch 52/185 loss = 0.0026
# epoch 7 batch 53/185 loss = 0.0019
# epoch 7 batch 54/185 loss = 0.0021
# epoch 7 batch 55/185 loss = 0.0030
# epoch 7 batch 56/185 loss = 0.0022
# epoch 7 batch 57/185 loss = 0.0032
# epoch 7 batch 58/185 loss = 0.0020
# epoch 7 batch 59/185 loss = 0.0022
# epoch 7 batch 60/185 loss = 0.0025
# epoch 7 batch 61/185 loss = 0.0030
# epoch 7 batch 62/185 loss = 0.0022
# epoch 7 batch 63/185 loss = 0.0025
# epoch 7 batch 64/185 loss = 0.0027
# epoch 7 batch 65/185 loss = 0.0027
# epoch 7 batch 66/185 loss = 0.0023
# epoch 7 batch 67/185 loss = 0.0022
# epoch 7 batch 68/185 loss = 0.0022
# epoch 7 batch 69/185 loss = 0.0024
# epoch 7 batch 70/185 loss = 0.0020
# epoch 7 batch 71/185 loss = 0.0021
# epoch 7 batch 72/185 loss = 0.0023
# epoch 7 batch 73/185 loss = 0.0023
# epoch 7 batch 74/185 loss = 0.0021
# epoch 7 batch 75/185 loss = 0.0022
# epoch 7 batch 76/185 loss = 0.0024
# epoch 7 batch 77/185 loss = 0.0024
# epoch 7 batch 78/185 loss = 0.0021
# epoch 7 batch 79/185 loss = 0.0022
# epoch 7 batch 80/185 loss = 0.0023
# epoch 7 batch 81/185 loss = 0.0031
# epoch 7 batch 82/185 loss = 0.0019
# epoch 7 batch 83/185 loss = 0.0026
# epoch 7 batch 84/185 loss = 0.0024
# epoch 7 batch 85/185 loss = 0.0023
# epoch 7 batch 86/185 loss = 0.0023
# epoch 7 batch 87/185 loss = 0.0025
# epoch 7 batch 88/185 loss = 0.0029
# epoch 7 batch 89/185 loss = 0.0022
# epoch 7 batch 90/185 loss = 0.0020
# epoch 7 batch 91/185 loss = 0.0022
# epoch 7 batch 92/185 loss = 0.0027
# epoch 7 batch 93/185 loss = 0.0021
# epoch 7 batch 94/185 loss = 0.0024
# epoch 7 batch 95/185 loss = 0.0023
# epoch 7 batch 96/185 loss = 0.0019
# epoch 7 batch 97/185 loss = 0.0022
# epoch 7 batch 98/185 loss = 0.0020
# epoch 7 batch 99/185 loss = 0.0024
# epoch 7 batch 100/185 loss = 0.0021
# epoch 7 batch 101/185 loss = 0.0022
# epoch 7 batch 102/185 loss = 0.0024
# epoch 7 batch 103/185 loss = 0.0025
# epoch 7 batch 104/185 loss = 0.0022
# epoch 7 batch 105/185 loss = 0.0022
# epoch 7 batch 106/185 loss = 0.0023
# epoch 7 batch 107/185 loss = 0.0018
# epoch 7 batch 108/185 loss = 0.0022
# epoch 7 batch 109/185 loss = 0.0021
# epoch 7 batch 110/185 loss = 0.0022
# epoch 7 batch 111/185 loss = 0.0021
# epoch 7 batch 112/185 loss = 0.0020
# epoch 7 batch 113/185 loss = 0.0028
# epoch 7 batch 114/185 loss = 0.0026
# epoch 7 batch 115/185 loss = 0.0021
# epoch 7 batch 116/185 loss = 0.0019
# epoch 7 batch 117/185 loss = 0.0026
# epoch 7 batch 118/185 loss = 0.0024
# epoch 7 batch 119/185 loss = 0.0029
# epoch 7 batch 120/185 loss = 0.0023
# epoch 7 batch 121/185 loss = 0.0021
# epoch 7 batch 122/185 loss = 0.0022
# epoch 7 batch 123/185 loss = 0.0022
# epoch 7 batch 124/185 loss = 0.0018
# epoch 7 batch 125/185 loss = 0.0025
# epoch 7 batch 126/185 loss = 0.0028
# epoch 7 batch 127/185 loss = 0.0021
# epoch 7 batch 128/185 loss = 0.0022
# epoch 7 batch 129/185 loss = 0.0022
# epoch 7 batch 130/185 loss = 0.0023
# epoch 7 batch 131/185 loss = 0.0021
# epoch 7 batch 132/185 loss = 0.0023
# epoch 7 batch 133/185 loss = 0.0023
# epoch 7 batch 134/185 loss = 0.0018
# epoch 7 batch 135/185 loss = 0.0021
# epoch 7 batch 136/185 loss = 0.0023
# epoch 7 batch 137/185 loss = 0.0026
# epoch 7 batch 138/185 loss = 0.0020
# epoch 7 batch 139/185 loss = 0.0024
# epoch 7 batch 140/185 loss = 0.0020
# epoch 7 batch 141/185 loss = 0.0020
# epoch 7 batch 142/185 loss = 0.0018
# epoch 7 batch 143/185 loss = 0.0023
# epoch 7 batch 144/185 loss = 0.0022
# epoch 7 batch 145/185 loss = 0.0020
# epoch 7 batch 146/185 loss = 0.0021
# epoch 7 batch 147/185 loss = 0.0021
# epoch 7 batch 148/185 loss = 0.0023
# epoch 7 batch 149/185 loss = 0.0018
# epoch 7 batch 150/185 loss = 0.0024
# epoch 7 batch 151/185 loss = 0.0018
# epoch 7 batch 152/185 loss = 0.0023
# epoch 7 batch 153/185 loss = 0.0017
# epoch 7 batch 154/185 loss = 0.0029
# epoch 7 batch 155/185 loss = 0.0021
# epoch 7 batch 156/185 loss = 0.0023
# epoch 7 batch 157/185 loss = 0.0021
# epoch 7 batch 158/185 loss = 0.0022
# epoch 7 batch 159/185 loss = 0.0022
# epoch 7 batch 160/185 loss = 0.0021
# epoch 7 batch 161/185 loss = 0.0020
# epoch 7 batch 162/185 loss = 0.0024
# epoch 7 batch 163/185 loss = 0.0026
# epoch 7 batch 164/185 loss = 0.0021
# epoch 7 batch 165/185 loss = 0.0024
# epoch 7 batch 166/185 loss = 0.0019
# epoch 7 batch 167/185 loss = 0.0023
# epoch 7 batch 168/185 loss = 0.0028
# epoch 7 batch 169/185 loss = 0.0019
# epoch 7 batch 170/185 loss = 0.0023
# epoch 7 batch 171/185 loss = 0.0019
# epoch 7 batch 172/185 loss = 0.0020
# epoch 7 batch 173/185 loss = 0.0024
# epoch 7 batch 174/185 loss = 0.0023
# epoch 7 batch 175/185 loss = 0.0023
# epoch 7 batch 176/185 loss = 0.0026
# epoch 7 batch 177/185 loss = 0.0032
# epoch 7 batch 178/185 loss = 0.0023
# epoch 7 batch 179/185 loss = 0.0022
# epoch 7 batch 180/185 loss = 0.0022
# epoch 7 batch 181/185 loss = 0.0022
# epoch 7 batch 182/185 loss = 0.0023
# epoch 7 batch 183/185 loss = 0.0026
# epoch 7 batch 184/185 loss = 0.0022
# epoch 7 batch 185/185 loss = 0.0021
# epoch 7 train loss = 0.0023 valid loss = 0.0120
# epoch 8 batch 1/185 loss = 0.0018
# epoch 8 batch 2/185 loss = 0.0023
# epoch 8 batch 3/185 loss = 0.0020
# epoch 8 batch 4/185 loss = 0.0026
# epoch 8 batch 5/185 loss = 0.0019
# epoch 8 batch 6/185 loss = 0.0028
# epoch 8 batch 7/185 loss = 0.0020
# epoch 8 batch 8/185 loss = 0.0023
# epoch 8 batch 9/185 loss = 0.0024
# epoch 8 batch 10/185 loss = 0.0019
# epoch 8 batch 11/185 loss = 0.0019
# epoch 8 batch 12/185 loss = 0.0020
# epoch 8 batch 13/185 loss = 0.0020
# epoch 8 batch 14/185 loss = 0.0023
# epoch 8 batch 15/185 loss = 0.0023
# epoch 8 batch 16/185 loss = 0.0025
# epoch 8 batch 17/185 loss = 0.0025
# epoch 8 batch 18/185 loss = 0.0021
# epoch 8 batch 19/185 loss = 0.0020
# epoch 8 batch 20/185 loss = 0.0028
# epoch 8 batch 21/185 loss = 0.0025
# epoch 8 batch 22/185 loss = 0.0022
# epoch 8 batch 23/185 loss = 0.0025
# epoch 8 batch 24/185 loss = 0.0022
# epoch 8 batch 25/185 loss = 0.0020
# epoch 8 batch 26/185 loss = 0.0020
# epoch 8 batch 27/185 loss = 0.0021
# epoch 8 batch 28/185 loss = 0.0019
# epoch 8 batch 29/185 loss = 0.0025
# epoch 8 batch 30/185 loss = 0.0020
# epoch 8 batch 31/185 loss = 0.0022
# epoch 8 batch 32/185 loss = 0.0019
# epoch 8 batch 33/185 loss = 0.0026
# epoch 8 batch 34/185 loss = 0.0017
# epoch 8 batch 35/185 loss = 0.0020
# epoch 8 batch 36/185 loss = 0.0020
# epoch 8 batch 37/185 loss = 0.0018
# epoch 8 batch 38/185 loss = 0.0022
# epoch 8 batch 39/185 loss = 0.0020
# epoch 8 batch 40/185 loss = 0.0025
# epoch 8 batch 41/185 loss = 0.0019
# epoch 8 batch 42/185 loss = 0.0021
# epoch 8 batch 43/185 loss = 0.0020
# epoch 8 batch 44/185 loss = 0.0027
# epoch 8 batch 45/185 loss = 0.0021
# epoch 8 batch 46/185 loss = 0.0016
# epoch 8 batch 47/185 loss = 0.0021
# epoch 8 batch 48/185 loss = 0.0020
# epoch 8 batch 49/185 loss = 0.0020
# epoch 8 batch 50/185 loss = 0.0020
# epoch 8 batch 51/185 loss = 0.0023
# ...
# epoch 48 batch 125/185 loss = 0.0024
# epoch 48 batch 126/185 loss = 0.0015
# epoch 48 batch 127/185 loss = 0.0011
# epoch 48 batch 128/185 loss = 0.0010
# epoch 48 batch 129/185 loss = 0.0014
# epoch 48 batch 130/185 loss = 0.0011
# epoch 48 batch 131/185 loss = 0.0012
# epoch 48 batch 132/185 loss = 0.0013
# epoch 48 batch 133/185 loss = 0.0014
# epoch 48 batch 134/185 loss = 0.0024
# epoch 48 batch 135/185 loss = 0.0017
# epoch 48 batch 136/185 loss = 0.0011
# epoch 48 batch 137/185 loss = 0.0014
# epoch 48 batch 138/185 loss = 0.0011
# epoch 48 batch 139/185 loss = 0.0013
# epoch 48 batch 140/185 loss = 0.0014
# epoch 48 batch 141/185 loss = 0.0012
# epoch 48 batch 142/185 loss = 0.0013
# epoch 48 batch 143/185 loss = 0.0016
# epoch 48 batch 144/185 loss = 0.0010
# epoch 48 batch 145/185 loss = 0.0011
# epoch 48 batch 146/185 loss = 0.0014
# epoch 48 batch 147/185 loss = 0.0013
# epoch 48 batch 148/185 loss = 0.0013
# epoch 48 batch 149/185 loss = 0.0012
# epoch 48 batch 150/185 loss = 0.0011
# epoch 48 batch 151/185 loss = 0.0010
# epoch 48 batch 152/185 loss = 0.0014
# epoch 48 batch 153/185 loss = 0.0012
# epoch 48 batch 154/185 loss = 0.0013
# epoch 48 batch 155/185 loss = 0.0013
# epoch 48 batch 156/185 loss = 0.0011
# epoch 48 batch 157/185 loss = 0.0012
# epoch 48 batch 158/185 loss = 0.0011
# epoch 48 batch 159/185 loss = 0.0011
# epoch 48 batch 160/185 loss = 0.0012
# epoch 48 batch 161/185 loss = 0.0013
# epoch 48 batch 162/185 loss = 0.0015
# epoch 48 batch 163/185 loss = 0.0012
# epoch 48 batch 164/185 loss = 0.0010
# epoch 48 batch 165/185 loss = 0.0012
# epoch 48 batch 166/185 loss = 0.0012
# epoch 48 batch 167/185 loss = 0.0012
# epoch 48 batch 168/185 loss = 0.0015
# epoch 48 batch 169/185 loss = 0.0012
# epoch 48 batch 170/185 loss = 0.0014
# epoch 48 batch 171/185 loss = 0.0016
# epoch 48 batch 172/185 loss = 0.0011
# epoch 48 batch 173/185 loss = 0.0013
# epoch 48 batch 174/185 loss = 0.0014
# epoch 48 batch 175/185 loss = 0.0012
# epoch 48 batch 176/185 loss = 0.0014
# epoch 48 batch 177/185 loss = 0.0014
# epoch 48 batch 178/185 loss = 0.0012
# epoch 48 batch 179/185 loss = 0.0011
# epoch 48 batch 180/185 loss = 0.0014
# epoch 48 batch 181/185 loss = 0.0013
# epoch 48 batch 182/185 loss = 0.0011
# epoch 48 batch 183/185 loss = 0.0012
# epoch 48 batch 184/185 loss = 0.0011
# epoch 48 batch 185/185 loss = 0.0010
# epoch 48 train loss = 0.0012 valid loss = 0.0112
# performance reducing: counter 29
# epoch 49 batch 1/185 loss = 0.0011
# epoch 49 batch 2/185 loss = 0.0021
# epoch 49 batch 3/185 loss = 0.0011
# epoch 49 batch 4/185 loss = 0.0015
# epoch 49 batch 5/185 loss = 0.0012
# epoch 49 batch 6/185 loss = 0.0015
# epoch 49 batch 7/185 loss = 0.0011
# epoch 49 batch 8/185 loss = 0.0019
# epoch 49 batch 9/185 loss = 0.0010
# epoch 49 batch 10/185 loss = 0.0011
# epoch 49 batch 11/185 loss = 0.0012
# epoch 49 batch 12/185 loss = 0.0012
# epoch 49 batch 13/185 loss = 0.0011
# epoch 49 batch 14/185 loss = 0.0012
# epoch 49 batch 15/185 loss = 0.0011
# epoch 49 batch 16/185 loss = 0.0011
# epoch 49 batch 17/185 loss = 0.0013
# epoch 49 batch 18/185 loss = 0.0014
# epoch 49 batch 19/185 loss = 0.0017
# epoch 49 batch 20/185 loss = 0.0013
# epoch 49 batch 21/185 loss = 0.0010
# epoch 49 batch 22/185 loss = 0.0013
# epoch 49 batch 23/185 loss = 0.0011
# epoch 49 batch 24/185 loss = 0.0011
# epoch 49 batch 25/185 loss = 0.0012
# epoch 49 batch 26/185 loss = 0.0012
# epoch 49 batch 27/185 loss = 0.0011
# epoch 49 batch 28/185 loss = 0.0012
# epoch 49 batch 29/185 loss = 0.0012
# epoch 49 batch 30/185 loss = 0.0014
# epoch 49 batch 31/185 loss = 0.0012
# epoch 49 batch 32/185 loss = 0.0014
# epoch 49 batch 33/185 loss = 0.0015
# epoch 49 batch 34/185 loss = 0.0011
# epoch 49 batch 35/185 loss = 0.0011
# epoch 49 batch 36/185 loss = 0.0018
# epoch 49 batch 37/185 loss = 0.0013
# epoch 49 batch 38/185 loss = 0.0015
# epoch 49 batch 39/185 loss = 0.0015
# epoch 49 batch 40/185 loss = 0.0013
# epoch 49 batch 41/185 loss = 0.0012
# epoch 49 batch 42/185 loss = 0.0011
# epoch 49 batch 43/185 loss = 0.0012
# epoch 49 batch 44/185 loss = 0.0012
# epoch 49 batch 45/185 loss = 0.0011
# epoch 49 batch 46/185 loss = 0.0009
# epoch 49 batch 47/185 loss = 0.0014
# epoch 49 batch 48/185 loss = 0.0011
# epoch 49 batch 49/185 loss = 0.0014
# epoch 49 batch 50/185 loss = 0.0013
# epoch 49 batch 51/185 loss = 0.0011
# epoch 49 batch 52/185 loss = 0.0011
# epoch 49 batch 53/185 loss = 0.0012
# epoch 49 batch 54/185 loss = 0.0013
# epoch 49 batch 55/185 loss = 0.0010
# epoch 49 batch 56/185 loss = 0.0012
# epoch 49 batch 57/185 loss = 0.0012
# epoch 49 batch 58/185 loss = 0.0014
# epoch 49 batch 59/185 loss = 0.0011
# epoch 49 batch 60/185 loss = 0.0013
# epoch 49 batch 61/185 loss = 0.0010
# epoch 49 batch 62/185 loss = 0.0017
# epoch 49 batch 63/185 loss = 0.0011
# epoch 49 batch 64/185 loss = 0.0013
# epoch 49 batch 65/185 loss = 0.0012
# epoch 49 batch 66/185 loss = 0.0011
# epoch 49 batch 67/185 loss = 0.0013
# epoch 49 batch 68/185 loss = 0.0014
# epoch 49 batch 69/185 loss = 0.0013
# epoch 49 batch 70/185 loss = 0.0012
# epoch 49 batch 71/185 loss = 0.0010
# epoch 49 batch 72/185 loss = 0.0011
# epoch 49 batch 73/185 loss = 0.0011
# epoch 49 batch 74/185 loss = 0.0011
# epoch 49 batch 75/185 loss = 0.0012
# epoch 49 batch 76/185 loss = 0.0012
# epoch 49 batch 77/185 loss = 0.0012
# epoch 49 batch 78/185 loss = 0.0012
# epoch 49 batch 79/185 loss = 0.0011
# epoch 49 batch 80/185 loss = 0.0012
# epoch 49 batch 81/185 loss = 0.0018
# epoch 49 batch 82/185 loss = 0.0013
# epoch 49 batch 83/185 loss = 0.0010
# epoch 49 batch 84/185 loss = 0.0015
# epoch 49 batch 85/185 loss = 0.0011
# epoch 49 batch 86/185 loss = 0.0014
# epoch 49 batch 87/185 loss = 0.0013
# epoch 49 batch 88/185 loss = 0.0013
# epoch 49 batch 89/185 loss = 0.0013
# epoch 49 batch 90/185 loss = 0.0012
# epoch 49 batch 91/185 loss = 0.0012
# epoch 49 batch 92/185 loss = 0.0014
# epoch 49 batch 93/185 loss = 0.0010
# epoch 49 batch 94/185 loss = 0.0009
# epoch 49 batch 95/185 loss = 0.0014
# epoch 49 batch 96/185 loss = 0.0014
# epoch 49 batch 97/185 loss = 0.0014
# epoch 49 batch 98/185 loss = 0.0011
# epoch 49 batch 99/185 loss = 0.0012
# epoch 49 batch 100/185 loss = 0.0010
# epoch 49 batch 101/185 loss = 0.0013
# epoch 49 batch 102/185 loss = 0.0014
# epoch 49 batch 103/185 loss = 0.0010
# epoch 49 batch 104/185 loss = 0.0010
# epoch 49 batch 105/185 loss = 0.0010
# epoch 49 batch 106/185 loss = 0.0013
# epoch 49 batch 107/185 loss = 0.0011
# epoch 49 batch 108/185 loss = 0.0011
# epoch 49 batch 109/185 loss = 0.0013
# epoch 49 batch 110/185 loss = 0.0014
# epoch 49 batch 111/185 loss = 0.0011
# epoch 49 batch 112/185 loss = 0.0012
# epoch 49 batch 113/185 loss = 0.0010
# epoch 49 batch 114/185 loss = 0.0010
# epoch 49 batch 115/185 loss = 0.0014
# epoch 49 batch 116/185 loss = 0.0014
# epoch 49 batch 117/185 loss = 0.0011
# epoch 49 batch 118/185 loss = 0.0012
# epoch 49 batch 119/185 loss = 0.0013
# epoch 49 batch 120/185 loss = 0.0010
# epoch 49 batch 121/185 loss = 0.0010
# epoch 49 batch 122/185 loss = 0.0010
# epoch 49 batch 123/185 loss = 0.0012
# epoch 49 batch 124/185 loss = 0.0012
# epoch 49 batch 125/185 loss = 0.0012
# epoch 49 batch 126/185 loss = 0.0011
# epoch 49 batch 127/185 loss = 0.0013
# epoch 49 batch 128/185 loss = 0.0012
# epoch 49 batch 129/185 loss = 0.0010
# epoch 49 batch 130/185 loss = 0.0011
# epoch 49 batch 131/185 loss = 0.0020
# epoch 49 batch 132/185 loss = 0.0017
# epoch 49 batch 133/185 loss = 0.0012
# epoch 49 batch 134/185 loss = 0.0012
# epoch 49 batch 135/185 loss = 0.0013
# epoch 49 batch 136/185 loss = 0.0011
# epoch 49 batch 137/185 loss = 0.0012
# epoch 49 batch 138/185 loss = 0.0013
# epoch 49 batch 139/185 loss = 0.0011
# epoch 49 batch 140/185 loss = 0.0013
# epoch 49 batch 141/185 loss = 0.0012
# epoch 49 batch 142/185 loss = 0.0014
# epoch 49 batch 143/185 loss = 0.0010
# epoch 49 batch 144/185 loss = 0.0009
# epoch 49 batch 145/185 loss = 0.0014
# epoch 49 batch 146/185 loss = 0.0014
# epoch 49 batch 147/185 loss = 0.0010
# epoch 49 batch 148/185 loss = 0.0012
# epoch 49 batch 149/185 loss = 0.0012
# epoch 49 batch 150/185 loss = 0.0011
# epoch 49 batch 151/185 loss = 0.0015
# epoch 49 batch 152/185 loss = 0.0011
# epoch 49 batch 153/185 loss = 0.0011
# epoch 49 batch 154/185 loss = 0.0012
# epoch 49 batch 155/185 loss = 0.0010
# epoch 49 batch 156/185 loss = 0.0011
# epoch 49 batch 157/185 loss = 0.0012
# epoch 49 batch 158/185 loss = 0.0013
# epoch 49 batch 159/185 loss = 0.0014
# epoch 49 batch 160/185 loss = 0.0010
# epoch 49 batch 161/185 loss = 0.0009
# epoch 49 batch 162/185 loss = 0.0013
# epoch 49 batch 163/185 loss = 0.0011
# epoch 49 batch 164/185 loss = 0.0012
# epoch 49 batch 165/185 loss = 0.0010
# epoch 49 batch 166/185 loss = 0.0012
# epoch 49 batch 167/185 loss = 0.0012
# epoch 49 batch 168/185 loss = 0.0011
# epoch 49 batch 169/185 loss = 0.0013
# epoch 49 batch 170/185 loss = 0.0010
# epoch 49 batch 171/185 loss = 0.0018
# epoch 49 batch 172/185 loss = 0.0011
# epoch 49 batch 173/185 loss = 0.0014
# epoch 49 batch 174/185 loss = 0.0013
# epoch 49 batch 175/185 loss = 0.0011
# epoch 49 batch 176/185 loss = 0.0012
# epoch 49 batch 177/185 loss = 0.0009
# epoch 49 batch 178/185 loss = 0.0018
# epoch 49 batch 179/185 loss = 0.0011
# epoch 49 batch 180/185 loss = 0.0015
# epoch 49 batch 181/185 loss = 0.0011
# epoch 49 batch 182/185 loss = 0.0013
# epoch 49 batch 183/185 loss = 0.0010
# epoch 49 batch 184/185 loss = 0.0012
# epoch 49 batch 185/185 loss = 0.0011
# epoch 49 train loss = 0.0012 valid loss = 0.0111
# performance reducing: counter 30
# epoch 50 batch 1/185 loss = 0.0012
# epoch 50 batch 2/185 loss = 0.0012
# epoch 50 batch 3/185 loss = 0.0011
# epoch 50 batch 4/185 loss = 0.0012
# epoch 50 batch 5/185 loss = 0.0012
# epoch 50 batch 6/185 loss = 0.0012
# epoch 50 batch 7/185 loss = 0.0012
# epoch 50 batch 8/185 loss = 0.0022
# epoch 50 batch 9/185 loss = 0.0012
# epoch 50 batch 10/185 loss = 0.0013
# epoch 50 batch 11/185 loss = 0.0012
# epoch 50 batch 12/185 loss = 0.0012
# epoch 50 batch 13/185 loss = 0.0013
# epoch 50 batch 14/185 loss = 0.0014
# epoch 50 batch 15/185 loss = 0.0011
# epoch 50 batch 16/185 loss = 0.0015
# epoch 50 batch 17/185 loss = 0.0013
# epoch 50 batch 18/185 loss = 0.0015
# epoch 50 batch 19/185 loss = 0.0015
# epoch 50 batch 20/185 loss = 0.0013
# epoch 50 batch 21/185 loss = 0.0019
# epoch 50 batch 22/185 loss = 0.0017
# epoch 50 batch 23/185 loss = 0.0014
# epoch 50 batch 24/185 loss = 0.0012
# epoch 50 batch 25/185 loss = 0.0013
# epoch 50 batch 26/185 loss = 0.0013
# epoch 50 batch 27/185 loss = 0.0013
# epoch 50 batch 28/185 loss = 0.0013
# epoch 50 batch 29/185 loss = 0.0014
# epoch 50 batch 30/185 loss = 0.0013
# epoch 50 batch 31/185 loss = 0.0014
# epoch 50 batch 32/185 loss = 0.0012
# epoch 50 batch 33/185 loss = 0.0014
# epoch 50 batch 34/185 loss = 0.0014
# epoch 50 batch 35/185 loss = 0.0014
# epoch 50 batch 36/185 loss = 0.0012
# epoch 50 batch 37/185 loss = 0.0012
# epoch 50 batch 38/185 loss = 0.0012
# epoch 50 batch 39/185 loss = 0.0016
# epoch 50 batch 40/185 loss = 0.0012
# epoch 50 batch 41/185 loss = 0.0013
# epoch 50 batch 42/185 loss = 0.0014
# epoch 50 batch 43/185 loss = 0.0011
# epoch 50 batch 44/185 loss = 0.0012
# epoch 50 batch 45/185 loss = 0.0012
# epoch 50 batch 46/185 loss = 0.0015
# epoch 50 batch 47/185 loss = 0.0013
# epoch 50 batch 48/185 loss = 0.0012
# epoch 50 batch 49/185 loss = 0.0012
# epoch 50 batch 50/185 loss = 0.0014
# epoch 50 batch 51/185 loss = 0.0015
# epoch 50 batch 52/185 loss = 0.0011
# epoch 50 batch 53/185 loss = 0.0010
# epoch 50 batch 54/185 loss = 0.0011
# epoch 50 batch 55/185 loss = 0.0013
# epoch 50 batch 56/185 loss = 0.0011
# epoch 50 batch 57/185 loss = 0.0015
# epoch 50 batch 58/185 loss = 0.0010
# epoch 50 batch 59/185 loss = 0.0015
# epoch 50 batch 60/185 loss = 0.0011
# epoch 50 batch 61/185 loss = 0.0013
# epoch 50 batch 62/185 loss = 0.0011
# epoch 50 batch 63/185 loss = 0.0012
# epoch 50 batch 64/185 loss = 0.0013
# epoch 50 batch 65/185 loss = 0.0011
# epoch 50 batch 66/185 loss = 0.0010
# epoch 50 batch 67/185 loss = 0.0013
# epoch 50 batch 68/185 loss = 0.0014
# epoch 50 batch 69/185 loss = 0.0010
# epoch 50 batch 70/185 loss = 0.0013
# epoch 50 batch 71/185 loss = 0.0014
# epoch 50 batch 72/185 loss = 0.0015
# epoch 50 batch 73/185 loss = 0.0009
# epoch 50 batch 74/185 loss = 0.0015
# epoch 50 batch 75/185 loss = 0.0012
# epoch 50 batch 76/185 loss = 0.0012
# epoch 50 batch 77/185 loss = 0.0010
# epoch 50 batch 78/185 loss = 0.0009
# epoch 50 batch 79/185 loss = 0.0017
# epoch 50 batch 80/185 loss = 0.0011
# epoch 50 batch 81/185 loss = 0.0011
# epoch 50 batch 82/185 loss = 0.0011
# epoch 50 batch 83/185 loss = 0.0013
# epoch 50 batch 84/185 loss = 0.0012
# epoch 50 batch 85/185 loss = 0.0010
# epoch 50 batch 86/185 loss = 0.0014
# epoch 50 batch 87/185 loss = 0.0014
# epoch 50 batch 88/185 loss = 0.0013
# epoch 50 batch 89/185 loss = 0.0011
# epoch 50 batch 90/185 loss = 0.0019
# epoch 50 batch 91/185 loss = 0.0012
# epoch 50 batch 92/185 loss = 0.0011
# epoch 50 batch 93/185 loss = 0.0011
# epoch 50 batch 94/185 loss = 0.0019
# epoch 50 batch 95/185 loss = 0.0013
# epoch 50 batch 96/185 loss = 0.0014
# epoch 50 batch 97/185 loss = 0.0012
# epoch 50 batch 98/185 loss = 0.0012
# epoch 50 batch 99/185 loss = 0.0013
# epoch 50 batch 100/185 loss = 0.0012
# epoch 50 batch 101/185 loss = 0.0014
# epoch 50 batch 102/185 loss = 0.0015
# epoch 50 batch 103/185 loss = 0.0013
# epoch 50 batch 104/185 loss = 0.0014
# epoch 50 batch 105/185 loss = 0.0011
# epoch 50 batch 106/185 loss = 0.0012
# epoch 50 batch 107/185 loss = 0.0011
# epoch 50 batch 108/185 loss = 0.0012
# epoch 50 batch 109/185 loss = 0.0011
# epoch 50 batch 110/185 loss = 0.0011
# epoch 50 batch 111/185 loss = 0.0014
# epoch 50 batch 112/185 loss = 0.0012
# epoch 50 batch 113/185 loss = 0.0011
# epoch 50 batch 114/185 loss = 0.0011
# epoch 50 batch 115/185 loss = 0.0012
# epoch 50 batch 116/185 loss = 0.0013
# epoch 50 batch 117/185 loss = 0.0012
# epoch 50 batch 118/185 loss = 0.0009
# epoch 50 batch 119/185 loss = 0.0014
# epoch 50 batch 120/185 loss = 0.0013
# epoch 50 batch 121/185 loss = 0.0018
# epoch 50 batch 122/185 loss = 0.0013
# epoch 50 batch 123/185 loss = 0.0012
# epoch 50 batch 124/185 loss = 0.0011
# epoch 50 batch 125/185 loss = 0.0013
# epoch 50 batch 126/185 loss = 0.0011
# epoch 50 batch 127/185 loss = 0.0011
# epoch 50 batch 128/185 loss = 0.0015
# epoch 50 batch 129/185 loss = 0.0011
# epoch 50 batch 130/185 loss = 0.0013
# epoch 50 batch 131/185 loss = 0.0013
# epoch 50 batch 132/185 loss = 0.0012
# epoch 50 batch 133/185 loss = 0.0012
# epoch 50 batch 134/185 loss = 0.0017
# epoch 50 batch 135/185 loss = 0.0012
# epoch 50 batch 136/185 loss = 0.0014
# epoch 50 batch 137/185 loss = 0.0011
# epoch 50 batch 138/185 loss = 0.0011
# epoch 50 batch 139/185 loss = 0.0015
# epoch 50 batch 140/185 loss = 0.0015
# epoch 50 batch 141/185 loss = 0.0012
# epoch 50 batch 142/185 loss = 0.0011
# epoch 50 batch 143/185 loss = 0.0017
# epoch 50 batch 144/185 loss = 0.0011
# epoch 50 batch 145/185 loss = 0.0013
# epoch 50 batch 146/185 loss = 0.0010
# epoch 50 batch 147/185 loss = 0.0012
# epoch 50 batch 148/185 loss = 0.0011
# epoch 50 batch 149/185 loss = 0.0010
# epoch 50 batch 150/185 loss = 0.0012
# epoch 50 batch 151/185 loss = 0.0011
# epoch 50 batch 152/185 loss = 0.0012
# epoch 50 batch 153/185 loss = 0.0013
# epoch 50 batch 154/185 loss = 0.0014
# epoch 50 batch 155/185 loss = 0.0010
# epoch 50 batch 156/185 loss = 0.0010
# epoch 50 batch 157/185 loss = 0.0011
# epoch 50 batch 158/185 loss = 0.0011
# epoch 50 batch 159/185 loss = 0.0012
# epoch 50 batch 160/185 loss = 0.0011
# epoch 50 batch 161/185 loss = 0.0010
# epoch 50 batch 162/185 loss = 0.0017
# epoch 50 batch 163/185 loss = 0.0012
# epoch 50 batch 164/185 loss = 0.0010
# epoch 50 batch 165/185 loss = 0.0010
# epoch 50 batch 166/185 loss = 0.0011
# epoch 50 batch 167/185 loss = 0.0011
# epoch 50 batch 168/185 loss = 0.0014
# epoch 50 batch 169/185 loss = 0.0009
# epoch 50 batch 170/185 loss = 0.0010
# epoch 50 batch 171/185 loss = 0.0012
# epoch 50 batch 172/185 loss = 0.0010
# epoch 50 batch 173/185 loss = 0.0011
# epoch 50 batch 174/185 loss = 0.0013
# epoch 50 batch 175/185 loss = 0.0010
# epoch 50 batch 176/185 loss = 0.0011
# epoch 50 batch 177/185 loss = 0.0011
# epoch 50 batch 178/185 loss = 0.0017
# epoch 50 batch 179/185 loss = 0.0015
# epoch 50 batch 180/185 loss = 0.0013
# epoch 50 batch 181/185 loss = 0.0011
# epoch 50 batch 182/185 loss = 0.0011
# epoch 50 batch 183/185 loss = 0.0011
# epoch 50 batch 184/185 loss = 0.0010
# epoch 50 batch 185/185 loss = 0.0011
# epoch 50 train loss = 0.0013 valid loss = 0.0110
# performance reducing: counter 31
