# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
#os.remove('/kaggle/working/datasets/cityscapes.pth')
# for dirname, _, filenames in os.walk('/kaggle/input'):
#    for filename in filenames:
#       print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
import torchvision.transforms.functional as functional
from torch.utils.data import DataLoader
from torch.utils.data import Dataset
from glob import glob

# %%
train_path = glob('/kaggle/input/cityscapes-image-pairs/cityscapes_data/train/*')
valid_path = glob('/kaggle/input/cityscapes-image-pairs/cityscapes_data/val/*')

# %%
class Cityscapes(Dataset):
    def __init__(self, data_path, transform=None, target_transform=None):
        super(Cityscapes, self).__init__()
        self.data_path = data_path
        #self.datasets = np.array(data)
        #self.images, self.targets = np.array_split(self.datasets, 2, axis=2)
        self.transform = transform
        self.target_transform = target_transform

    def __getitem__(self, item):
        image_pair = plt.imread(self.data_path[item])
        image, target = image_pair[:, :int(image_pair.shape[1] / 2)], image_pair[:, int(image_pair.shape[1] / 2):]
        #image = self.images[item]
        #target = self.targets[item]
        if self.transform is not None:
            image = self.transform(image)
        if self.target_transform is not None:
            target = self.target_transform(target)
        return image, target

    def __len__(self):
        return len(self.data_path)

# %%
import torch
import torch.nn as nn
from torch import Tensor


class UNet(nn.Module):
    def __init__(self, image_channel=3, mid_channel=64):
        super(UNet, self).__init__()
        self.two_conv_block = nn.Sequential(
            nn.Conv2d(image_channel, mid_channel, kernel_size=3, padding=1),
            nn.BatchNorm2d(mid_channel),
            nn.ReLU(inplace=True),
            nn.Conv2d(mid_channel, mid_channel, kernel_size=3, padding=1),
            nn.BatchNorm2d(mid_channel),
            nn.ReLU(inplace=True)
        )
        self.down_sample_1 = DownSampleConvBlock(mid_channel, mid_channel * 2, mid_channel * 2)
        self.down_sample_2 = DownSampleConvBlock(mid_channel * 2, mid_channel * 4, mid_channel * 4)
        self.down_sample_3 = DownSampleConvBlock(mid_channel * 4, mid_channel * 8, mid_channel * 8)
        self.down_sample_4 = DownSampleConvBlock(mid_channel * 8, mid_channel * 16, mid_channel * 16)
        self.up_sample_1 = UpSampleConvBlock(mid_channel * 16, mid_channel * 8, mid_channel * 8)
        self.up_sample_2 = UpSampleConvBlock(mid_channel * 8, mid_channel * 4, mid_channel * 4)
        self.up_sample_3 = UpSampleConvBlock(mid_channel * 4, mid_channel * 2, mid_channel * 2)
        self.up_sample_4 = UpSampleConvBlock(mid_channel * 2, mid_channel, mid_channel)
        # 降维
        self.conv1x1 = nn.Conv2d(mid_channel, image_channel, kernel_size=1)
        self.bn = nn.BatchNorm2d(image_channel)

    def forward(self, x):
        x1 = self.two_conv_block(x)
        x2 = self.down_sample_1(x1)
        x3 = self.down_sample_2(x2)
        x4 = self.down_sample_3(x3)
        x5 = self.down_sample_4(x4)
        x_u1 = self.up_sample_1(x5, x4)
        x_u2 = self.up_sample_2(x_u1, x3)
        x_u3 = self.up_sample_3(x_u2, x2)
        x_u4 = self.up_sample_4(x_u3, x1)
        return self.bn(self.conv1x1(x_u4))


class BasicConvBlock(nn.Module):
    def __init__(self, in_channels, mid_channels, out_channels, kernel_size=3, stride=1, padding=1, dilation=1):
        super(BasicConvBlock, self).__init__()
        self.layers = nn.Sequential(
            # the first conv block
            nn.Conv2d(in_channels, mid_channels, kernel_size, stride, padding, dilation),
            nn.BatchNorm2d(mid_channels),
            nn.ReLU(inplace=True),
            # the second conv block
            nn.Conv2d(mid_channels, out_channels, kernel_size, stride, padding, dilation),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True)
        )

    def forward(self, x):
        return self.layers(x)


class DownSampleConvBlock(nn.Module):
    def __init__(self, in_channels, mid_channels, out_channels, pool_size=2, kernel_size=3, stride=1, padding=1,
                 dilation=1):
        super(DownSampleConvBlock, self).__init__()
        self.down_sample = nn.MaxPool2d(kernel_size=pool_size)
        self.basic_conv_block = BasicConvBlock(in_channels, mid_channels, out_channels, kernel_size, stride, padding,
                                               dilation)

    def forward(self, x):
        # down sample
        x = self.down_sample(x)
        # two conv block
        x = self.basic_conv_block(x)
        return x


class UpSampleConvBlock(nn.Module):
    def __init__(self, in_channels, mid_channels, out_channels, up_size=2, kernel_size=3, stride=1, padding=1,
                 dilation=1):
        super(UpSampleConvBlock, self).__init__()
        self.up_sample = nn.ConvTranspose2d(in_channels, mid_channels, kernel_size=up_size, stride=up_size,
                                            dilation=dilation)
        self.basic_conv_block = BasicConvBlock(in_channels, mid_channels, out_channels, kernel_size, stride, padding,
                                               dilation)

    def forward(self, x, skip_x):
        # up sample
        x = self.up_sample(x)
        # concat x and skip_x in the dimension of channel
        x = torch.cat([x, skip_x], dim=1)
        # two conv block
        x = self.basic_conv_block(x)
        return x


class AdaptiveFeatureFusionModule(nn.Module):
    """Adaptive Feature Fusion Module(AFFM)

    Fusion multiple-scale feature maps, the count of feature maps is not fixed,
    the value of counts must equal the size of feature_maps, the number of layers
    in AFFM is determined by the parameter of counts.

    """

    def __init__(self, counts):
        super(AdaptiveFeatureFusionModule, self).__init__()
        self.counts = counts
        pass

    def forward(self, feature_maps: tuple = None):
        pass

# %%
def dice_coeff(predict, target, reduce_batch_first=False, epsilon=1e-6):
    # Average of Dice coefficient for all batches, or for a single mask
    assert predict.size() == target.size()
    if predict.dim() == 2 and reduce_batch_first:
        raise ValueError(f'Dice: asked to reduce batch but got tensor without batch dimension (shape {predict.shape})')

    if predict.dim() == 2 or reduce_batch_first:
        inter = torch.dot(predict.reshape(-1), target.reshape(-1))
        sets_sum = torch.sum(predict) + torch.sum(target)
        if sets_sum.item() == 0:
            sets_sum = 2 * inter
        return (2 * inter + epsilon) / (sets_sum + epsilon)
    else:
        # compute and average metric for each batch element
        dice = 0
        for i in range(predict.shape[0]):
            dice += dice_coeff(predict[i, ...], target[i, ...])
        # return average dice loss value of a batch
        return dice / predict.shape[0]


def multiclass_dice_coeff(predict, target, reduce_batch_first=False, epsilon=1e-6):
    # Average of Dice coefficient for all classes
    assert predict.size() == target.size()
    dice = 0
    for channel in range(predict.shape[1]):
        dice += dice_coeff(predict[:, channel, ...], target[:, channel, ...], reduce_batch_first, epsilon)
    return dice / predict.shape[1]


def dice_loss(predict, target, multiclass=True, epsilon=1e-6):
    # Dice loss (objective to minimize) between 0 and 1
    assert predict.size() == target.size()
    fn = multiclass_dice_coeff if multiclass else dice_coeff
    return 1 - fn(predict, target, reduce_batch_first=True, epsilon=epsilon)


class DiceLoss(nn.Module):
    def __init__(self, ep=1e-8):
        super(DiceLoss, self).__init__()
        self.ep = ep

    def forward(self, predict, target):
        # the shape of predict must equal to the shape of target
        value = dice_loss(predict, target, True, self.ep)
        return value

# %%
def validate(network_model, valid_loader, loss, device):
    network_model.eval()
    v_loss_total = 0.0
    with torch.no_grad():
        for j, (v_x, v_l) in enumerate(valid_loader):
            v_x = v_x.to(device)
            v_l = v_l.to(device)
            v_predict = network_model(v_x)
            loss_value = loss(v_predict, v_l)
            v_loss_total += loss_value.item()
    val_avg_loss = v_loss_total / len(valid_loader)
    return val_avg_loss


class SearchBestModel(object):
    def __init__(self, min_delta=0, verbose=True):
        super(SearchBestModel, self).__init__()
        self.verbose = verbose
        self.min_delta = min_delta
        self.counter = 0
        self.best_score = None

    def __call__(self, val_loss):
        if self.best_score is None:
            self.best_score = val_loss
        elif self.best_score - val_loss >= self.min_delta:
            self.best_score = val_loss
            self.counter = 0
        else:
            self.counter += 1
            if self.verbose:
                print('performance reducing: counter {}'.format(self.counter))

# %%
def train(train_loader, valid_loader, model, optimizer, loss, epoch, device):
    loss_change_list = []
    valid_loss_change = []
    save_best = {}
    save_last = {}
    search_best_model = SearchBestModel()
    for i in range(epoch):
        model.train()
        total_loss = 0.0
        for index, (image, label) in enumerate(train_loader):
            image = image.to(device)
            label = label.to(device).to(torch.float32)

            segment_mask = model(image)
            loss_value = loss(segment_mask, label)

            optimizer.zero_grad()
            loss_value.backward()
            optimizer.step()

            total_loss = total_loss + loss_value.item()

            print('epoch {} batch {}/{} loss = {:.4f}'.format(i + 1, index + 1, len(train_loader), loss_value.item()))
        # save train loss change history used for model analyse
        loss_change_list.append(total_loss / len(train_loader))
        # use the dataset for validation to validate the trained model
        valid_avg_loss = validate(model, valid_loader, loss, device)
        # save valid loss change history used for model analyse
        valid_loss_change.append(valid_avg_loss)

        print('epoch {} train loss = {:.4f} valid loss = {:.4f}'.format(i + 1, total_loss / len(train_loader), valid_avg_loss))

        # see if satisfy the conditions of early stopping
        search_best_model(valid_avg_loss)
        # if satisfy the conditions of early stopping, break the training process
        if search_best_model.counter > 0:
            continue
        # if not satisfy the conditions of early stopping, it shows that
        # the model in this epoch is the best, save the params of current model.
        save_best['model_state_dict'] = model.state_dict()
        # save optimizer used for re-train
        save_best['optimizer_state_dict'] = optimizer.state_dict()
        # save the epoch of current best model
        save_best['epoch'] = i
    # save loss change history of training and validation
    save_last['train_loss_change'] = loss_change_list
    save_last['valid_loss_change'] = valid_loss_change
    save_last['model_state_dict'] = model.state_dict()
    save_last['optimizer_state_dict'] = optimizer.state_dict()
    save_last['trained_epoch'] = epoch
    torch.save(save_best, './unet-best.pth')
    torch.save(save_last, './unet-last.pth')

# %%
if __name__ == '__main__':
    current_device = 'cuda' if torch.cuda.is_available() else 'cpu'

    train_image_path = glob('../input/cityscapes-image-pairs/cityscapes_data/train/*')
    valid_image_path = glob('../input/cityscapes-image-pairs/cityscapes_data/val/*')

    image_transforms = transforms.Compose([
#         transforms.ToPILImage(mode='RGB'),
        transforms.ToTensor(),
        transforms.Resize(256),
#         transforms.PILToTensor(),
#         transforms.ColorJitter(),
#         transforms.GaussianBlur((5,), (5, 15)),
#         transforms.Normalize((0.5,), (0.5,)),
    ])
    target_transforms = transforms.Compose([
#         transforms.ToPILImage(mode='RGB'),
#         transforms.Grayscale(),
#         transforms.PILToTensor(),
        transforms.ToTensor(),
#         transforms.Resize(256),
#         transforms.Normalize((0.5,), (0.5,)),
    ])
    valid_transforms = transforms.Compose([
        transforms.ToTensor(),
#         transforms.Resize(256),
#         transforms.Normalize((0.5,), (0.5,)),
#         transforms.ToPILImage(mode='RGB'),
        transforms.Resize(256),
#         transforms.PILToTensor(),
#         transforms.Normalize((0.5,), (0.5,)),
    ])

    train_cityscapes = Cityscapes(train_image_path, image_transforms, target_transforms)
    valid_cityscapes = Cityscapes(valid_image_path, valid_transforms, target_transforms)

    train_loader = DataLoader(train_cityscapes, batch_size=16, shuffle=True, drop_last=True)
    valid_loader = DataLoader(valid_cityscapes, batch_size=16, shuffle=True, drop_last=True)

    unet = UNet().to(current_device)
    ce_loss = nn.MSELoss().to(current_device)
    optimizer_adam = optim.Adam(unet.parameters(), lr=0.0001)
    train(train_loader, valid_loader, unet, optimizer_adam, ce_loss, epoch=50, device=current_device)
# Out:
# epoch 1 batch 1/185 loss = 1.2194
# epoch 1 batch 2/185 loss = 1.1514
# epoch 1 batch 3/185 loss = 1.1129
# epoch 1 batch 4/185 loss = 1.0736
# epoch 1 batch 5/185 loss = 1.0443
# epoch 1 batch 6/185 loss = 1.0304
# epoch 1 batch 7/185 loss = 1.0007
# epoch 1 batch 8/185 loss = 0.9995
# epoch 1 batch 9/185 loss = 0.9713
# epoch 1 batch 10/185 loss = 0.9735
# epoch 1 batch 11/185 loss = 0.9668
# epoch 1 batch 12/185 loss = 0.9730
# epoch 1 batch 13/185 loss = 0.9513
# epoch 1 batch 14/185 loss = 0.9430
# epoch 1 batch 15/185 loss = 0.9322
# epoch 1 batch 16/185 loss = 0.9389
# epoch 1 batch 17/185 loss = 0.9291
# epoch 1 batch 18/185 loss = 0.9359
# epoch 1 batch 19/185 loss = 0.9300
# epoch 1 batch 20/185 loss = 0.9191
# epoch 1 batch 21/185 loss = 0.9235
# epoch 1 batch 22/185 loss = 0.9169
# epoch 1 batch 23/185 loss = 0.9185
# epoch 1 batch 24/185 loss = 0.9037
# epoch 1 batch 25/185 loss = 0.8952
# epoch 1 batch 26/185 loss = 0.9016
# epoch 1 batch 27/185 loss = 0.9142
# epoch 1 batch 28/185 loss = 0.9001
# epoch 1 batch 29/185 loss = 0.8825
# epoch 1 batch 30/185 loss = 0.8959
# epoch 1 batch 31/185 loss = 0.8837
# epoch 1 batch 32/185 loss = 0.8950
# epoch 1 batch 33/185 loss = 0.8807
# epoch 1 batch 34/185 loss = 0.8863
# epoch 1 batch 35/185 loss = 0.8722
# epoch 1 batch 36/185 loss = 0.8921
# epoch 1 batch 37/185 loss = 0.8762
# epoch 1 batch 38/185 loss = 0.8651
# epoch 1 batch 39/185 loss = 0.8656
# epoch 1 batch 40/185 loss = 0.8521
# epoch 1 batch 41/185 loss = 0.8567
# epoch 1 batch 42/185 loss = 0.8798
# epoch 1 batch 43/185 loss = 0.8788
# epoch 1 batch 44/185 loss = 0.8836
# epoch 1 batch 45/185 loss = 0.8583
# epoch 1 batch 46/185 loss = 0.8919
# epoch 1 batch 47/185 loss = 0.8711
# epoch 1 batch 48/185 loss = 0.8513
# epoch 1 batch 49/185 loss = 0.8690
# epoch 1 batch 50/185 loss = 0.8573
# epoch 1 batch 51/185 loss = 0.8674
# epoch 1 batch 52/185 loss = 0.8964
# epoch 1 batch 53/185 loss = 0.8752
# epoch 1 batch 54/185 loss = 0.8680
# epoch 1 batch 55/185 loss = 0.8628
# epoch 1 batch 56/185 loss = 0.8719
# epoch 1 batch 57/185 loss = 0.8725
# epoch 1 batch 58/185 loss = 0.8568
# epoch 1 batch 59/185 loss = 0.8590
# epoch 1 batch 60/185 loss = 0.8408
# epoch 1 batch 61/185 loss = 0.8615
# epoch 1 batch 62/185 loss = 0.8629
# epoch 1 batch 63/185 loss = 0.8611
# epoch 1 batch 64/185 loss = 0.8656
# epoch 1 batch 65/185 loss = 0.8569
# epoch 1 batch 66/185 loss = 0.8416
# epoch 1 batch 67/185 loss = 0.8558
# epoch 1 batch 68/185 loss = 0.8501
# epoch 1 batch 69/185 loss = 0.8491
# epoch 1 batch 70/185 loss = 0.8414
# epoch 1 batch 71/185 loss = 0.8584
# epoch 1 batch 72/185 loss = 0.8474
# epoch 1 batch 73/185 loss = 0.8357
# epoch 1 batch 74/185 loss = 0.8502
# epoch 1 batch 75/185 loss = 0.8423
# epoch 1 batch 76/185 loss = 0.8531
# epoch 1 batch 77/185 loss = 0.8517
# epoch 1 batch 78/185 loss = 0.8485
# epoch 1 batch 79/185 loss = 0.8544
# epoch 1 batch 80/185 loss = 0.8411
# epoch 1 batch 81/185 loss = 0.8361
# epoch 1 batch 82/185 loss = 0.8298
# epoch 1 batch 83/185 loss = 0.8394
# epoch 1 batch 84/185 loss = 0.8440
# epoch 1 batch 85/185 loss = 0.8559
# epoch 1 batch 86/185 loss = 0.8359
# epoch 1 batch 87/185 loss = 0.8474
# epoch 1 batch 88/185 loss = 0.8437
# epoch 1 batch 89/185 loss = 0.8202
# epoch 1 batch 90/185 loss = 0.8383
# epoch 1 batch 91/185 loss = 0.8224
# epoch 1 batch 92/185 loss = 0.8517
# epoch 1 batch 93/185 loss = 0.8301
# epoch 1 batch 94/185 loss = 0.8310
# epoch 1 batch 95/185 loss = 0.8212
# epoch 1 batch 96/185 loss = 0.8305
# epoch 1 batch 97/185 loss = 0.8398
# epoch 1 batch 98/185 loss = 0.8295
# epoch 1 batch 99/185 loss = 0.8342
# epoch 1 batch 100/185 loss = 0.8277
# epoch 1 batch 101/185 loss = 0.8218
# epoch 1 batch 102/185 loss = 0.8344
# epoch 1 batch 103/185 loss = 0.8221
# epoch 1 batch 104/185 loss = 0.8357
# epoch 1 batch 105/185 loss = 0.8225
# epoch 1 batch 106/185 loss = 0.8350
# epoch 1 batch 107/185 loss = 0.8003
# epoch 1 batch 108/185 loss = 0.8164
# epoch 1 batch 109/185 loss = 0.8327
# epoch 1 batch 110/185 loss = 0.8304
# epoch 1 batch 111/185 loss = 0.8159
# epoch 1 batch 112/185 loss = 0.8323
# epoch 1 batch 113/185 loss = 0.8203
# epoch 1 batch 114/185 loss = 0.8151
# epoch 1 batch 115/185 loss = 0.8199
# epoch 1 batch 116/185 loss = 0.8053
# epoch 1 batch 117/185 loss = 0.8195
# epoch 1 batch 118/185 loss = 0.8201
# epoch 1 batch 119/185 loss = 0.8194
# epoch 1 batch 120/185 loss = 0.8090
# epoch 1 batch 121/185 loss = 0.8154
# epoch 1 batch 122/185 loss = 0.8408
# epoch 1 batch 123/185 loss = 0.8163
# epoch 1 batch 124/185 loss = 0.8200
# epoch 1 batch 125/185 loss = 0.8558
# epoch 1 batch 126/185 loss = 0.7831
# epoch 1 batch 127/185 loss = 0.7976
# epoch 1 batch 128/185 loss = 0.8422
# epoch 1 batch 129/185 loss = 0.8081
# epoch 1 batch 130/185 loss = 0.8463
# epoch 1 batch 131/185 loss = 0.8418
# epoch 1 batch 132/185 loss = 0.8127
# epoch 1 batch 133/185 loss = 0.8143
# epoch 1 batch 134/185 loss = 0.8268
# epoch 1 batch 135/185 loss = 0.8241
# epoch 1 batch 136/185 loss = 0.8117
# epoch 1 batch 137/185 loss = 0.8172
# epoch 1 batch 138/185 loss = 0.8207
# epoch 1 batch 139/185 loss = 0.8079
# epoch 1 batch 140/185 loss = 0.8185
# epoch 1 batch 141/185 loss = 0.8090
# epoch 1 batch 142/185 loss = 0.8271
# epoch 1 batch 143/185 loss = 0.8029
# epoch 1 batch 144/185 loss = 0.8218
# epoch 1 batch 145/185 loss = 0.8102
# epoch 1 batch 146/185 loss = 0.8122
# epoch 1 batch 147/185 loss = 0.7972
# epoch 1 batch 148/185 loss = 0.8019
# epoch 1 batch 149/185 loss = 0.8172
# epoch 1 batch 150/185 loss = 0.7911
# epoch 1 batch 151/185 loss = 0.8101
# epoch 1 batch 152/185 loss = 0.8119
# epoch 1 batch 153/185 loss = 0.8237
# epoch 1 batch 154/185 loss = 0.8129
# epoch 1 batch 155/185 loss = 0.8063
# epoch 1 batch 156/185 loss = 0.8114
# epoch 1 batch 157/185 loss = 0.8196
# epoch 1 batch 158/185 loss = 0.8197
# epoch 1 batch 159/185 loss = 0.8174
# epoch 1 batch 160/185 loss = 0.8188
# epoch 1 batch 161/185 loss = 0.8124
# epoch 1 batch 162/185 loss = 0.8055
# epoch 1 batch 163/185 loss = 0.8066
# epoch 1 batch 164/185 loss = 0.8122
# epoch 1 batch 165/185 loss = 0.7924
# epoch 1 batch 166/185 loss = 0.7990
# epoch 1 batch 167/185 loss = 0.8173
# epoch 1 batch 168/185 loss = 0.7966
# epoch 1 batch 169/185 loss = 0.7901
# epoch 1 batch 170/185 loss = 0.8074
# epoch 1 batch 171/185 loss = 0.7854
# epoch 1 batch 172/185 loss = 0.8020
# epoch 1 batch 173/185 loss = 0.7875
# epoch 1 batch 174/185 loss = 0.7875
# epoch 1 batch 175/185 loss = 0.8091
# epoch 1 batch 176/185 loss = 0.8068
# epoch 1 batch 177/185 loss = 0.7915
# epoch 1 batch 178/185 loss = 0.7831
# epoch 1 batch 179/185 loss = 0.7754
# epoch 1 batch 180/185 loss = 0.7954
# epoch 1 batch 181/185 loss = 0.7869
# epoch 1 batch 182/185 loss = 0.7860
# epoch 1 batch 183/185 loss = 0.7815
# epoch 1 batch 184/185 loss = 0.7904
# epoch 1 batch 185/185 loss = 0.7856
# epoch 1 train loss = 0.8536 valid loss = 0.8731
# epoch 2 batch 1/185 loss = 0.7940
# epoch 2 batch 2/185 loss = 0.7764
# epoch 2 batch 3/185 loss = 0.7866
# epoch 2 batch 4/185 loss = 0.7872
# epoch 2 batch 5/185 loss = 0.7959
# epoch 2 batch 6/185 loss = 0.7940
# epoch 2 batch 7/185 loss = 0.7827
# epoch 2 batch 8/185 loss = 0.7871
# epoch 2 batch 9/185 loss = 0.7684
# epoch 2 batch 10/185 loss = 0.7916
# epoch 2 batch 11/185 loss = 0.7805
# epoch 2 batch 12/185 loss = 0.7728
# epoch 2 batch 13/185 loss = 0.7823
# epoch 2 batch 14/185 loss = 0.7766
# epoch 2 batch 15/185 loss = 0.7778
# epoch 2 batch 16/185 loss = 0.8018
# epoch 2 batch 17/185 loss = 0.7728
# epoch 2 batch 18/185 loss = 0.7848
# epoch 2 batch 19/185 loss = 0.7757
# epoch 2 batch 20/185 loss = 0.7805
# epoch 2 batch 21/185 loss = 0.7895
# epoch 2 batch 22/185 loss = 0.7701
# epoch 2 batch 23/185 loss = 0.7987
# epoch 2 batch 24/185 loss = 0.8000
# epoch 2 batch 25/185 loss = 0.7977
# epoch 2 batch 26/185 loss = 0.7777
# epoch 2 batch 27/185 loss = 0.7864
# epoch 2 batch 28/185 loss = 0.7886
# epoch 2 batch 29/185 loss = 0.7889
# epoch 2 batch 30/185 loss = 0.7994
# epoch 2 batch 31/185 loss = 0.7696
# epoch 2 batch 32/185 loss = 0.7951
# epoch 2 batch 33/185 loss = 0.7764
# epoch 2 batch 34/185 loss = 0.7871
# epoch 2 batch 35/185 loss = 0.7920
# epoch 2 batch 36/185 loss = 0.7909
# epoch 2 batch 37/185 loss = 0.7689
# epoch 2 batch 38/185 loss = 0.7583
# epoch 2 batch 39/185 loss = 0.7811
# epoch 2 batch 40/185 loss = 0.7926
# epoch 2 batch 41/185 loss = 0.7923
# epoch 2 batch 42/185 loss = 0.7888
# epoch 2 batch 43/185 loss = 0.7828
# epoch 2 batch 44/185 loss = 0.7873
# epoch 2 batch 45/185 loss = 0.7756
# epoch 2 batch 46/185 loss = 0.7812
# epoch 2 batch 47/185 loss = 0.7784
# epoch 2 batch 48/185 loss = 0.7831
# epoch 2 batch 49/185 loss = 0.7696
# epoch 2 batch 50/185 loss = 0.7676
# epoch 2 batch 51/185 loss = 0.7800
# epoch 2 batch 52/185 loss = 0.7687
# epoch 2 batch 53/185 loss = 0.7814
# epoch 2 batch 54/185 loss = 0.7971
# epoch 2 batch 55/185 loss = 0.7645
# epoch 2 batch 56/185 loss = 0.7686
# epoch 2 batch 57/185 loss = 0.7832
# epoch 2 batch 58/185 loss = 0.7800
# epoch 2 batch 59/185 loss = 0.7703
# epoch 2 batch 60/185 loss = 0.7619
# epoch 2 batch 61/185 loss = 0.7746
# epoch 2 batch 62/185 loss = 0.7735
# epoch 2 batch 63/185 loss = 0.7883
# epoch 2 batch 64/185 loss = 0.7730
# epoch 2 batch 65/185 loss = 0.7634
# epoch 2 batch 66/185 loss = 0.7811
# epoch 2 batch 67/185 loss = 0.7864
# epoch 2 batch 68/185 loss = 0.7856
# epoch 2 batch 69/185 loss = 0.7763
# epoch 2 batch 70/185 loss = 0.7681
# epoch 2 batch 71/185 loss = 0.7792
# epoch 2 batch 72/185 loss = 0.7676
# epoch 2 batch 73/185 loss = 0.7617
# epoch 2 batch 74/185 loss = 0.7812
# epoch 2 batch 75/185 loss = 0.7734
# epoch 2 batch 76/185 loss = 0.7782
# epoch 2 batch 77/185 loss = 0.7654
# epoch 2 batch 78/185 loss = 0.7728
# epoch 2 batch 79/185 loss = 0.7589
# epoch 2 batch 80/185 loss = 0.7779
# epoch 2 batch 81/185 loss = 0.7637
# epoch 2 batch 82/185 loss = 0.7562
# epoch 2 batch 83/185 loss = 0.7449
# epoch 2 batch 84/185 loss = 0.7599
# epoch 2 batch 85/185 loss = 0.7477
# epoch 2 batch 86/185 loss = 0.7766
# epoch 2 batch 87/185 loss = 0.7698
# epoch 2 batch 88/185 loss = 0.7634
# epoch 2 batch 89/185 loss = 0.7655
# epoch 2 batch 90/185 loss = 0.7578
# epoch 2 batch 91/185 loss = 0.7771
# epoch 2 batch 92/185 loss = 0.7686
# epoch 2 batch 93/185 loss = 0.7669
# epoch 2 batch 94/185 loss = 0.7824
# epoch 2 batch 95/185 loss = 0.7663
# epoch 2 batch 96/185 loss = 0.7599
# epoch 2 batch 97/185 loss = 0.7751
# epoch 2 batch 98/185 loss = 0.7505
# epoch 2 batch 99/185 loss = 0.7681
# epoch 2 batch 100/185 loss = 0.7599
# epoch 2 batch 101/185 loss = 0.7588
# epoch 2 batch 102/185 loss = 0.7484
# epoch 2 batch 103/185 loss = 0.7602
# epoch 2 batch 104/185 loss = 0.7558
# epoch 2 batch 105/185 loss = 0.7594
# epoch 2 batch 106/185 loss = 0.7699
# epoch 2 batch 107/185 loss = 0.7562
# epoch 2 batch 108/185 loss = 0.7755
# epoch 2 batch 109/185 loss = 0.7594
# epoch 2 batch 110/185 loss = 0.7530
# epoch 2 batch 111/185 loss = 0.7710
# epoch 2 batch 112/185 loss = 0.7447
# epoch 2 batch 113/185 loss = 0.7529
# epoch 2 batch 114/185 loss = 0.7514
# epoch 2 batch 115/185 loss = 0.7755
# epoch 2 batch 116/185 loss = 0.7600
# epoch 2 batch 117/185 loss = 0.7603
# epoch 2 batch 118/185 loss = 0.7537
# epoch 2 batch 119/185 loss = 0.7519
# epoch 2 batch 120/185 loss = 0.7504
# epoch 2 batch 121/185 loss = 0.7664
# epoch 2 batch 122/185 loss = 0.7538
# epoch 2 batch 123/185 loss = 0.7613
# epoch 2 batch 124/185 loss = 0.7708
# epoch 2 batch 125/185 loss = 0.7430
# epoch 2 batch 126/185 loss = 0.7732
# epoch 2 batch 127/185 loss = 0.7796
# epoch 2 batch 128/185 loss = 0.7564
# epoch 2 batch 129/185 loss = 0.7528
# epoch 2 batch 130/185 loss = 0.7669
# epoch 2 batch 131/185 loss = 0.7537
# epoch 2 batch 132/185 loss = 0.7568
# epoch 2 batch 133/185 loss = 0.7539
# epoch 2 batch 134/185 loss = 0.7472
# epoch 2 batch 135/185 loss = 0.7390
# epoch 2 batch 136/185 loss = 0.7540
# epoch 2 batch 137/185 loss = 0.7643
# epoch 2 batch 138/185 loss = 0.7409
# epoch 2 batch 139/185 loss = 0.7501
# epoch 2 batch 140/185 loss = 0.7548
# epoch 2 batch 141/185 loss = 0.7558
# epoch 2 batch 142/185 loss = 0.7597
# epoch 2 batch 143/185 loss = 0.7422
# epoch 2 batch 144/185 loss = 0.7535
# epoch 2 batch 145/185 loss = 0.7681
# epoch 2 batch 146/185 loss = 0.7489
# epoch 2 batch 147/185 loss = 0.7675
# epoch 2 batch 148/185 loss = 0.7471
# epoch 2 batch 149/185 loss = 0.7372
# epoch 2 batch 150/185 loss = 0.7468
# epoch 2 batch 151/185 loss = 0.7760
# epoch 2 batch 152/185 loss = 0.7583
# epoch 2 batch 153/185 loss = 0.7492
# epoch 2 batch 154/185 loss = 0.7512
# epoch 2 batch 155/185 loss = 0.7485
# epoch 2 batch 156/185 loss = 0.7602
# epoch 2 batch 157/185 loss = 0.7377
# epoch 2 batch 158/185 loss = 0.7353
# epoch 2 batch 159/185 loss = 0.7549
# epoch 2 batch 160/185 loss = 0.7601
# epoch 2 batch 161/185 loss = 0.7415
# epoch 2 batch 162/185 loss = 0.7559
# epoch 2 batch 163/185 loss = 0.7124
# epoch 2 batch 164/185 loss = 0.7623
# epoch 2 batch 165/185 loss = 0.7576
# epoch 2 batch 166/185 loss = 0.7389
# epoch 2 batch 167/185 loss = 0.7550
# epoch 2 batch 168/185 loss = 0.7489
# epoch 2 batch 169/185 loss = 0.7297
# epoch 2 batch 170/185 loss = 0.7388
# epoch 2 batch 171/185 loss = 0.7342
# epoch 2 batch 172/185 loss = 0.7350
# epoch 2 batch 173/185 loss = 0.7485
# epoch 2 batch 174/185 loss = 0.7684
# epoch 2 batch 175/185 loss = 0.7474
# epoch 2 batch 176/185 loss = 0.7339
# epoch 2 batch 177/185 loss = 0.7524
# epoch 2 batch 178/185 loss = 0.7567
# epoch 2 batch 179/185 loss = 0.7452
# epoch 2 batch 180/185 loss = 0.7424
# epoch 2 batch 181/185 loss = 0.7511
# epoch 2 batch 182/185 loss = 0.7459
# epoch 2 batch 183/185 loss = 0.7339
# epoch 2 batch 184/185 loss = 0.7341
# epoch 2 batch 185/185 loss = 0.7505
# epoch 2 train loss = 0.7659 valid loss = 0.7472
# epoch 3 batch 1/185 loss = 0.7308
# epoch 3 batch 2/185 loss = 0.7255
# epoch 3 batch 3/185 loss = 0.7308
# epoch 3 batch 4/185 loss = 0.7254
# epoch 3 batch 5/185 loss = 0.7641
# epoch 3 batch 6/185 loss = 0.7446
# epoch 3 batch 7/185 loss = 0.7516
# epoch 3 batch 8/185 loss = 0.7284
# epoch 3 batch 9/185 loss = 0.7319
# epoch 3 batch 10/185 loss = 0.7315
# epoch 3 batch 11/185 loss = 0.7278
# epoch 3 batch 12/185 loss = 0.7354
# epoch 3 batch 13/185 loss = 0.7500
# epoch 3 batch 14/185 loss = 0.7246
# epoch 3 batch 15/185 loss = 0.7252
# epoch 3 batch 16/185 loss = 0.7408
# epoch 3 batch 17/185 loss = 0.7379
# epoch 3 batch 18/185 loss = 0.7398
# epoch 3 batch 19/185 loss = 0.7438
# epoch 3 batch 20/185 loss = 0.7339
# epoch 3 batch 21/185 loss = 0.7412
# epoch 3 batch 22/185 loss = 0.7138
# epoch 3 batch 23/185 loss = 0.7060
# epoch 3 batch 24/185 loss = 0.7422
# epoch 3 batch 25/185 loss = 0.7371
# epoch 3 batch 26/185 loss = 0.7338
# epoch 3 batch 27/185 loss = 0.7231
# epoch 3 batch 28/185 loss = 0.7184
# epoch 3 batch 29/185 loss = 0.7307
# epoch 3 batch 30/185 loss = 0.7259
# epoch 3 batch 31/185 loss = 0.7418
# epoch 3 batch 32/185 loss = 0.7392
# epoch 3 batch 33/185 loss = 0.7334
# epoch 3 batch 34/185 loss = 0.7470
# epoch 3 batch 35/185 loss = 0.7372
# epoch 3 batch 36/185 loss = 0.7406
# epoch 3 batch 37/185 loss = 0.7382
# epoch 3 batch 38/185 loss = 0.7205
# epoch 3 batch 39/185 loss = 0.7501
# epoch 3 batch 40/185 loss = 0.7295
# epoch 3 batch 41/185 loss = 0.7198
# epoch 3 batch 42/185 loss = 0.7252
# epoch 3 batch 43/185 loss = 0.7253
# epoch 3 batch 44/185 loss = 0.7359
# epoch 3 batch 45/185 loss = 0.7178
# epoch 3 batch 46/185 loss = 0.7204
# epoch 3 batch 47/185 loss = 0.7361
# epoch 3 batch 48/185 loss = 0.7395
# epoch 3 batch 49/185 loss = 0.7180
# epoch 3 batch 50/185 loss = 0.7313
# epoch 3 batch 51/185 loss = 0.7522
# epoch 3 batch 52/185 loss = 0.7126
# epoch 3 batch 53/185 loss = 0.7102
# epoch 3 batch 54/185 loss = 0.7242
# epoch 3 batch 55/185 loss = 0.7246
# epoch 3 batch 56/185 loss = 0.7331
# epoch 3 batch 57/185 loss = 0.7344
# epoch 3 batch 58/185 loss = 0.7267
# epoch 3 batch 59/185 loss = 0.7241
# epoch 3 batch 60/185 loss = 0.7224
# epoch 3 batch 61/185 loss = 0.7265
# epoch 3 batch 62/185 loss = 0.7504
# epoch 3 batch 63/185 loss = 0.7118
# epoch 3 batch 64/185 loss = 0.7448
# epoch 3 batch 65/185 loss = 0.7504
# epoch 3 batch 66/185 loss = 0.7232
# epoch 3 batch 67/185 loss = 0.7202
# epoch 3 batch 68/185 loss = 0.7393
# epoch 3 batch 69/185 loss = 0.7178
# epoch 3 batch 70/185 loss = 0.7367
# epoch 3 batch 71/185 loss = 0.7321
# epoch 3 batch 72/185 loss = 0.7157
# epoch 3 batch 73/185 loss = 0.7185
# epoch 3 batch 74/185 loss = 0.7337
# epoch 3 batch 75/185 loss = 0.7276
# epoch 3 batch 76/185 loss = 0.7221
# epoch 3 batch 77/185 loss = 0.7105
# epoch 3 batch 78/185 loss = 0.7283
# epoch 3 batch 79/185 loss = 0.7226
# epoch 3 batch 80/185 loss = 0.7273
# epoch 3 batch 81/185 loss = 0.7112
# epoch 3 batch 82/185 loss = 0.7172
# epoch 3 batch 83/185 loss = 0.7166
# epoch 3 batch 84/185 loss = 0.7067
# epoch 3 batch 85/185 loss = 0.7284
# epoch 3 batch 86/185 loss = 0.7230
# epoch 3 batch 87/185 loss = 0.7063
# epoch 3 batch 88/185 loss = 0.7062
# epoch 3 batch 89/185 loss = 0.7129
# epoch 3 batch 90/185 loss = 0.6993
# epoch 3 batch 91/185 loss = 0.7185
# epoch 3 batch 92/185 loss = 0.7088
# epoch 3 batch 93/185 loss = 0.7077
# epoch 3 batch 94/185 loss = 0.7109
# epoch 3 batch 95/185 loss = 0.7023
# epoch 3 batch 96/185 loss = 0.7193
# epoch 3 batch 97/185 loss = 0.7212
# epoch 3 batch 98/185 loss = 0.7181
# epoch 3 batch 99/185 loss = 0.7373
# epoch 3 batch 100/185 loss = 0.7171
# epoch 3 batch 101/185 loss = 0.7172
# epoch 3 batch 102/185 loss = 0.7211
# epoch 3 batch 103/185 loss = 0.7130
# epoch 3 batch 104/185 loss = 0.7229
# epoch 3 batch 105/185 loss = 0.7145
# epoch 3 batch 106/185 loss = 0.7100
# epoch 3 batch 107/185 loss = 0.7138
# epoch 3 batch 108/185 loss = 0.7294
# epoch 3 batch 109/185 loss = 0.7104
# epoch 3 batch 110/185 loss = 0.7104
# epoch 3 batch 111/185 loss = 0.7208
# epoch 3 batch 112/185 loss = 0.7058
# epoch 3 batch 113/185 loss = 0.7153
# epoch 3 batch 114/185 loss = 0.7281
# epoch 3 batch 115/185 loss = 0.6974
# epoch 3 batch 116/185 loss = 0.7128
# epoch 3 batch 117/185 loss = 0.7007
# epoch 3 batch 118/185 loss = 0.7194
# epoch 3 batch 119/185 loss = 0.7075
# epoch 3 batch 120/185 loss = 0.7070
# epoch 3 batch 121/185 loss = 0.7151
# epoch 3 batch 122/185 loss = 0.7092
# epoch 3 batch 123/185 loss = 0.7001
# epoch 3 batch 124/185 loss = 0.7122
# epoch 3 batch 125/185 loss = 0.7129
# epoch 3 batch 126/185 loss = 0.6978
# epoch 3 batch 127/185 loss = 0.7005
# epoch 3 batch 128/185 loss = 0.7114
# epoch 3 batch 129/185 loss = 0.6993
# epoch 3 batch 130/185 loss = 0.7099
# epoch 3 batch 131/185 loss = 0.6950
# epoch 3 batch 132/185 loss = 0.7102
# epoch 3 batch 133/185 loss = 0.7100
# epoch 3 batch 134/185 loss = 0.7152
# epoch 3 batch 135/185 loss = 0.6856
# epoch 3 batch 136/185 loss = 0.7158
# epoch 3 batch 137/185 loss = 0.6992
# epoch 3 batch 138/185 loss = 0.7003
# epoch 3 batch 139/185 loss = 0.7096
# epoch 3 batch 140/185 loss = 0.7127
# epoch 3 batch 141/185 loss = 0.7178
# epoch 3 batch 142/185 loss = 0.6991
# epoch 3 batch 143/185 loss = 0.6952
# epoch 3 batch 144/185 loss = 0.6876
# epoch 3 batch 145/185 loss = 0.7114
# epoch 3 batch 146/185 loss = 0.7065
# epoch 3 batch 147/185 loss = 0.6954
# epoch 3 batch 148/185 loss = 0.6994
# epoch 3 batch 149/185 loss = 0.7101
# epoch 3 batch 150/185 loss = 0.6951
# epoch 3 batch 151/185 loss = 0.7276
# epoch 3 batch 152/185 loss = 0.6964
# epoch 3 batch 153/185 loss = 0.6941
# epoch 3 batch 154/185 loss = 0.6939
# epoch 3 batch 155/185 loss = 0.7022
# epoch 3 batch 156/185 loss = 0.7011
# epoch 3 batch 157/185 loss = 0.7048
# epoch 3 batch 158/185 loss = 0.7103
# epoch 3 batch 159/185 loss = 0.7076
# epoch 3 batch 160/185 loss = 0.7099
# epoch 3 batch 161/185 loss = 0.6990
# epoch 3 batch 162/185 loss = 0.7023
# epoch 3 batch 163/185 loss = 0.7076
# epoch 3 batch 164/185 loss = 0.7128
# epoch 3 batch 165/185 loss = 0.6868
# epoch 3 batch 166/185 loss = 0.6983
# epoch 3 batch 167/185 loss = 0.6977
# epoch 3 batch 168/185 loss = 0.7067
# epoch 3 batch 169/185 loss = 0.6966
# epoch 3 batch 170/185 loss = 0.6989
# epoch 3 batch 171/185 loss = 0.6976
# epoch 3 batch 172/185 loss = 0.6985
# epoch 3 batch 173/185 loss = 0.6690
# epoch 3 batch 174/185 loss = 0.6914
# epoch 3 batch 175/185 loss = 0.6896
# epoch 3 batch 176/185 loss = 0.7071
# epoch 3 batch 177/185 loss = 0.6934
# epoch 3 batch 178/185 loss = 0.7007
# epoch 3 batch 179/185 loss = 0.7097
# epoch 3 batch 180/185 loss = 0.6924
# epoch 3 batch 181/185 loss = 0.6916
# epoch 3 batch 182/185 loss = 0.6991
# epoch 3 batch 183/185 loss = 0.7018
# epoch 3 batch 184/185 loss = 0.6955
# epoch 3 batch 185/185 loss = 0.6842
# epoch 3 train loss = 0.7170 valid loss = 0.6827
# epoch 4 batch 1/185 loss = 0.6838
# epoch 4 batch 2/185 loss = 0.6966
# epoch 4 batch 3/185 loss = 0.6858
# epoch 4 batch 4/185 loss = 0.6980
# epoch 4 batch 5/185 loss = 0.6842
# epoch 4 batch 6/185 loss = 0.6893
# epoch 4 batch 7/185 loss = 0.6898
# epoch 4 batch 8/185 loss = 0.6970
# epoch 4 batch 9/185 loss = 0.6778
# epoch 4 batch 10/185 loss = 0.6927
# epoch 4 batch 11/185 loss = 0.6845
# epoch 4 batch 12/185 loss = 0.7151
# epoch 4 batch 13/185 loss = 0.6976
# epoch 4 batch 14/185 loss = 0.6778
# epoch 4 batch 15/185 loss = 0.6867
# epoch 4 batch 16/185 loss = 0.6877
# epoch 4 batch 17/185 loss = 0.7047
# epoch 4 batch 18/185 loss = 0.6938
# epoch 4 batch 19/185 loss = 0.6947
# epoch 4 batch 20/185 loss = 0.6967
# epoch 4 batch 21/185 loss = 0.7074
# epoch 4 batch 22/185 loss = 0.6840
# epoch 4 batch 23/185 loss = 0.6812
# epoch 4 batch 24/185 loss = 0.6668
# epoch 4 batch 25/185 loss = 0.6650
# epoch 4 batch 26/185 loss = 0.6736
# epoch 4 batch 27/185 loss = 0.6941
# epoch 4 batch 28/185 loss = 0.6834
# epoch 4 batch 29/185 loss = 0.6858
# epoch 4 batch 30/185 loss = 0.6945
# epoch 4 batch 31/185 loss = 0.7073
# epoch 4 batch 32/185 loss = 0.6833
# epoch 4 batch 33/185 loss = 0.6891
# epoch 4 batch 34/185 loss = 0.6780
# epoch 4 batch 35/185 loss = 0.6955
# epoch 4 batch 36/185 loss = 0.6914
# epoch 4 batch 37/185 loss = 0.6806
# epoch 4 batch 38/185 loss = 0.6707
# epoch 4 batch 39/185 loss = 0.6831
# epoch 4 batch 40/185 loss = 0.6883
# epoch 4 batch 41/185 loss = 0.6820
# epoch 4 batch 42/185 loss = 0.6911
# epoch 4 batch 43/185 loss = 0.6845
# epoch 4 batch 44/185 loss = 0.6747
# epoch 4 batch 45/185 loss = 0.6824
# epoch 4 batch 46/185 loss = 0.6821
# epoch 4 batch 47/185 loss = 0.6694
# epoch 4 batch 48/185 loss = 0.6717
# epoch 4 batch 49/185 loss = 0.6879
# epoch 4 batch 50/185 loss = 0.6782
# epoch 4 batch 51/185 loss = 0.6818
# epoch 4 batch 52/185 loss = 0.6790
# epoch 4 batch 53/185 loss = 0.6732
# epoch 4 batch 54/185 loss = 0.7055
# epoch 4 batch 55/185 loss = 0.6830
# epoch 4 batch 56/185 loss = 0.6812
# epoch 4 batch 57/185 loss = 0.6908
# epoch 4 batch 58/185 loss = 0.6917
# epoch 4 batch 59/185 loss = 0.6908
# epoch 4 batch 60/185 loss = 0.6745
# epoch 4 batch 61/185 loss = 0.6820
# epoch 4 batch 62/185 loss = 0.6787
# epoch 4 batch 63/185 loss = 0.6849
# epoch 4 batch 64/185 loss = 0.6797
# epoch 4 batch 65/185 loss = 0.6648
# epoch 4 batch 66/185 loss = 0.6795
# epoch 4 batch 67/185 loss = 0.6862
# epoch 4 batch 68/185 loss = 0.6667
# epoch 4 batch 69/185 loss = 0.6693
# epoch 4 batch 70/185 loss = 0.6772
# epoch 4 batch 71/185 loss = 0.6776
# epoch 4 batch 72/185 loss = 0.6950
# epoch 4 batch 73/185 loss = 0.6779
# epoch 4 batch 74/185 loss = 0.6826
# epoch 4 batch 75/185 loss = 0.6696
# epoch 4 batch 76/185 loss = 0.6760
# epoch 4 batch 77/185 loss = 0.6686
# epoch 4 batch 78/185 loss = 0.6809
# epoch 4 batch 79/185 loss = 0.6845
# epoch 4 batch 80/185 loss = 0.6762
# epoch 4 batch 81/185 loss = 0.6656
# epoch 4 batch 82/185 loss = 0.6905
# epoch 4 batch 83/185 loss = 0.6876
# epoch 4 batch 84/185 loss = 0.6658
# epoch 4 batch 85/185 loss = 0.6720
# epoch 4 batch 86/185 loss = 0.6703
# epoch 4 batch 87/185 loss = 0.6727
# epoch 4 batch 88/185 loss = 0.6866
# epoch 4 batch 89/185 loss = 0.6834
# epoch 4 batch 90/185 loss = 0.6715
# epoch 4 batch 91/185 loss = 0.6755
# epoch 4 batch 92/185 loss = 0.6789
# epoch 4 batch 93/185 loss = 0.6787
# epoch 4 batch 94/185 loss = 0.6856
# epoch 4 batch 95/185 loss = 0.6926
# epoch 4 batch 96/185 loss = 0.6882
# epoch 4 batch 97/185 loss = 0.6710
# epoch 4 batch 98/185 loss = 0.6685
# epoch 4 batch 99/185 loss = 0.6687
# epoch 4 batch 100/185 loss = 0.6764
# epoch 4 batch 101/185 loss = 0.6637
# epoch 4 batch 102/185 loss = 0.6670
# epoch 4 batch 103/185 loss = 0.6738
# epoch 4 batch 104/185 loss = 0.6648
# epoch 4 batch 105/185 loss = 0.6804
# epoch 4 batch 106/185 loss = 0.6690
# epoch 4 batch 107/185 loss = 0.6772
# epoch 4 batch 108/185 loss = 0.6627
# epoch 4 batch 109/185 loss = 0.6647
# epoch 4 batch 110/185 loss = 0.6738
# epoch 4 batch 111/185 loss = 0.6663
# epoch 4 batch 112/185 loss = 0.6698
# epoch 4 batch 113/185 loss = 0.6671
# epoch 4 batch 114/185 loss = 0.6628
# epoch 4 batch 115/185 loss = 0.6784
# epoch 4 batch 116/185 loss = 0.6569
# epoch 4 batch 117/185 loss = 0.6624
# epoch 4 batch 118/185 loss = 0.6680
# epoch 4 batch 119/185 loss = 0.6455
# epoch 4 batch 120/185 loss = 0.6821
# epoch 4 batch 121/185 loss = 0.6658
# epoch 4 batch 122/185 loss = 0.6842
# epoch 4 batch 123/185 loss = 0.6724
# epoch 4 batch 124/185 loss = 0.6581
# epoch 4 batch 125/185 loss = 0.6849
# epoch 4 batch 126/185 loss = 0.6650
# epoch 4 batch 127/185 loss = 0.6626
# epoch 4 batch 128/185 loss = 0.6643
# epoch 4 batch 129/185 loss = 0.6540
# epoch 4 batch 130/185 loss = 0.6571
# epoch 4 batch 131/185 loss = 0.6715
# epoch 4 batch 132/185 loss = 0.6670
# epoch 4 batch 133/185 loss = 0.6752
# epoch 4 batch 134/185 loss = 0.6633
# epoch 4 batch 135/185 loss = 0.6918
# epoch 4 batch 136/185 loss = 0.6632
# epoch 4 batch 137/185 loss = 0.6497
# epoch 4 batch 138/185 loss = 0.6632
# epoch 4 batch 139/185 loss = 0.6659
# epoch 4 batch 140/185 loss = 0.6707
# epoch 4 batch 141/185 loss = 0.6602
# epoch 4 batch 142/185 loss = 0.6674
# epoch 4 batch 143/185 loss = 0.6658
# epoch 4 batch 144/185 loss = 0.6599
# epoch 4 batch 145/185 loss = 0.6609
# epoch 4 batch 146/185 loss = 0.6616
# epoch 4 batch 147/185 loss = 0.6724
# epoch 4 batch 148/185 loss = 0.6578
# epoch 4 batch 149/185 loss = 0.6661
# epoch 4 batch 150/185 loss = 0.6562
# epoch 4 batch 151/185 loss = 0.6581
# epoch 4 batch 152/185 loss = 0.6558
# epoch 4 batch 153/185 loss = 0.6745
# epoch 4 batch 154/185 loss = 0.6602
# epoch 4 batch 155/185 loss = 0.6571
# epoch 4 batch 156/185 loss = 0.6515
# epoch 4 batch 157/185 loss = 0.6537
# epoch 4 batch 158/185 loss = 0.6557
# epoch 4 batch 159/185 loss = 0.6554
# epoch 4 batch 160/185 loss = 0.6586
# epoch 4 batch 161/185 loss = 0.6631
# epoch 4 batch 162/185 loss = 0.6781
# epoch 4 batch 163/185 loss = 0.6534
# epoch 4 batch 164/185 loss = 0.6564
# epoch 4 batch 165/185 loss = 0.6586
# epoch 4 batch 166/185 loss = 0.6710
# epoch 4 batch 167/185 loss = 0.6588
# epoch 4 batch 168/185 loss = 0.6626
# epoch 4 batch 169/185 loss = 0.6392
# epoch 4 batch 170/185 loss = 0.6582
# epoch 4 batch 171/185 loss = 0.6843
# epoch 4 batch 172/185 loss = 0.6517
# epoch 4 batch 173/185 loss = 0.6448
# epoch 4 batch 174/185 loss = 0.6723
# epoch 4 batch 175/185 loss = 0.6482
# epoch 4 batch 176/185 loss = 0.6694
# epoch 4 batch 177/185 loss = 0.6532
# epoch 4 batch 178/185 loss = 0.6550
# epoch 4 batch 179/185 loss = 0.6566
# epoch 4 batch 180/185 loss = 0.6412
# epoch 4 batch 181/185 loss = 0.6613
# epoch 4 batch 182/185 loss = 0.6480
# epoch 4 batch 183/185 loss = 0.6640
# epoch 4 batch 184/185 loss = 0.6614
# epoch 4 batch 185/185 loss = 0.6627
# epoch 4 train loss = 0.6740 valid loss = 0.7137
# performance reducing: counter 1
# epoch 5 batch 1/185 loss = 0.6480
# epoch 5 batch 2/185 loss = 0.6490
# epoch 5 batch 3/185 loss = 0.6317
# epoch 5 batch 4/185 loss = 0.6589
# epoch 5 batch 5/185 loss = 0.6509
# epoch 5 batch 6/185 loss = 0.6524
# epoch 5 batch 7/185 loss = 0.6342
# epoch 5 batch 8/185 loss = 0.6356
# epoch 5 batch 9/185 loss = 0.6502
# epoch 5 batch 10/185 loss = 0.6588
# epoch 5 batch 11/185 loss = 0.6411
# epoch 5 batch 12/185 loss = 0.6445
# epoch 5 batch 13/185 loss = 0.6521
# epoch 5 batch 14/185 loss = 0.6722
# epoch 5 batch 15/185 loss = 0.6558
# epoch 5 batch 16/185 loss = 0.6463
# epoch 5 batch 17/185 loss = 0.6458
# epoch 5 batch 18/185 loss = 0.6367
# epoch 5 batch 19/185 loss = 0.6634
# epoch 5 batch 20/185 loss = 0.6579
# epoch 5 batch 21/185 loss = 0.6509
# epoch 5 batch 22/185 loss = 0.6428
# epoch 5 batch 23/185 loss = 0.6478
# epoch 5 batch 24/185 loss = 0.6444
# epoch 5 batch 25/185 loss = 0.6344
# epoch 5 batch 26/185 loss = 0.6568
# epoch 5 batch 27/185 loss = 0.6354
# epoch 5 batch 28/185 loss = 0.6391
# epoch 5 batch 29/185 loss = 0.6356
# epoch 5 batch 30/185 loss = 0.6380
# epoch 5 batch 31/185 loss = 0.6477
# epoch 5 batch 32/185 loss = 0.6302
# epoch 5 batch 33/185 loss = 0.6533
# epoch 5 batch 34/185 loss = 0.6398
# epoch 5 batch 35/185 loss = 0.6401
# epoch 5 batch 36/185 loss = 0.6411
# epoch 5 batch 37/185 loss = 0.6637
# epoch 5 batch 38/185 loss = 0.6598
# epoch 5 batch 39/185 loss = 0.6527
# epoch 5 batch 40/185 loss = 0.6433
# epoch 5 batch 41/185 loss = 0.6397
# epoch 5 batch 42/185 loss = 0.6356
# epoch 5 batch 43/185 loss = 0.6284
# epoch 5 batch 44/185 loss = 0.6239
# epoch 5 batch 45/185 loss = 0.6511
# epoch 5 batch 46/185 loss = 0.6369
# epoch 5 batch 47/185 loss = 0.6521
# epoch 5 batch 48/185 loss = 0.6470
# epoch 5 batch 49/185 loss = 0.6436
# epoch 5 batch 50/185 loss = 0.6634
# epoch 5 batch 51/185 loss = 0.6475
# epoch 5 batch 52/185 loss = 0.6383
# epoch 5 batch 53/185 loss = 0.6211
# epoch 5 batch 54/185 loss = 0.6427
# epoch 5 batch 55/185 loss = 0.6427
# epoch 5 batch 56/185 loss = 0.6315
# epoch 5 batch 57/185 loss = 0.6570
# epoch 5 batch 58/185 loss = 0.6281
# epoch 5 batch 59/185 loss = 0.6479
# epoch 5 batch 60/185 loss = 0.6458
# epoch 5 batch 61/185 loss = 0.6568
# epoch 5 batch 62/185 loss = 0.6399
# epoch 5 batch 63/185 loss = 0.6476
# epoch 5 batch 64/185 loss = 0.6539
# epoch 5 batch 65/185 loss = 0.6336
# epoch 5 batch 66/185 loss = 0.6447
# epoch 5 batch 67/185 loss = 0.6460
# epoch 5 batch 68/185 loss = 0.6585
# epoch 5 batch 69/185 loss = 0.6443
# epoch 5 batch 70/185 loss = 0.6543
# epoch 5 batch 71/185 loss = 0.6299
# epoch 5 batch 72/185 loss = 0.6367
# epoch 5 batch 73/185 loss = 0.6285
# epoch 5 batch 74/185 loss = 0.6368
# epoch 5 batch 75/185 loss = 0.6367
# epoch 5 batch 76/185 loss = 0.6184
# epoch 5 batch 77/185 loss = 0.6324
# epoch 5 batch 78/185 loss = 0.6433
# epoch 5 batch 79/185 loss = 0.6489
# epoch 5 batch 80/185 loss = 0.6356
# epoch 5 batch 81/185 loss = 0.6392
# epoch 5 batch 82/185 loss = 0.6257
# epoch 5 batch 83/185 loss = 0.6198
# epoch 5 batch 84/185 loss = 0.6360
# epoch 5 batch 85/185 loss = 0.6418
# epoch 5 batch 86/185 loss = 0.6428
# epoch 5 batch 87/185 loss = 0.6295
# epoch 5 batch 88/185 loss = 0.6500
# epoch 5 batch 89/185 loss = 0.6572
# epoch 5 batch 90/185 loss = 0.6259
# epoch 5 batch 91/185 loss = 0.6332
# epoch 5 batch 92/185 loss = 0.6425
# epoch 5 batch 93/185 loss = 0.6279
# epoch 5 batch 94/185 loss = 0.6559
# epoch 5 batch 95/185 loss = 0.6454
# epoch 5 batch 96/185 loss = 0.6348
# epoch 5 batch 97/185 loss = 0.6444
# epoch 5 batch 98/185 loss = 0.6289
# epoch 5 batch 99/185 loss = 0.6341
# epoch 5 batch 100/185 loss = 0.6424
# epoch 5 batch 101/185 loss = 0.6388
# epoch 5 batch 102/185 loss = 0.6361
# epoch 5 batch 103/185 loss = 0.6360
# epoch 5 batch 104/185 loss = 0.6229
# epoch 5 batch 105/185 loss = 0.6413
# epoch 5 batch 106/185 loss = 0.6345
# epoch 5 batch 107/185 loss = 0.6470
# epoch 5 batch 108/185 loss = 0.6263
# epoch 5 batch 109/185 loss = 0.6402
# epoch 5 batch 110/185 loss = 0.6389
# epoch 5 batch 111/185 loss = 0.6307
# epoch 5 batch 112/185 loss = 0.6370
# epoch 5 batch 113/185 loss = 0.6347
# epoch 5 batch 114/185 loss = 0.6337
# epoch 5 batch 115/185 loss = 0.6198
# epoch 5 batch 116/185 loss = 0.6351
# epoch 5 batch 117/185 loss = 0.6347
# epoch 5 batch 118/185 loss = 0.6202
# epoch 5 batch 119/185 loss = 0.6182
# epoch 5 batch 120/185 loss = 0.6305
# epoch 5 batch 121/185 loss = 0.6343
# epoch 5 batch 122/185 loss = 0.6358
# epoch 5 batch 123/185 loss = 0.6266
# epoch 5 batch 124/185 loss = 0.6320
# epoch 5 batch 125/185 loss = 0.6279
# epoch 5 batch 126/185 loss = 0.6358
# epoch 5 batch 127/185 loss = 0.6329
# epoch 5 batch 128/185 loss = 0.6255
# epoch 5 batch 129/185 loss = 0.6250
# epoch 5 batch 130/185 loss = 0.6393
# epoch 5 batch 131/185 loss = 0.6212
# epoch 5 batch 132/185 loss = 0.6237
# epoch 5 batch 133/185 loss = 0.6318
# epoch 5 batch 134/185 loss = 0.6164
# epoch 5 batch 135/185 loss = 0.6236
# epoch 5 batch 136/185 loss = 0.6215
# epoch 5 batch 137/185 loss = 0.6194
# epoch 5 batch 138/185 loss = 0.6125
# epoch 5 batch 139/185 loss = 0.6193
# epoch 5 batch 140/185 loss = 0.6220
# epoch 5 batch 141/185 loss = 0.6274
# epoch 5 batch 142/185 loss = 0.6184
# epoch 5 batch 143/185 loss = 0.6335
# epoch 5 batch 144/185 loss = 0.6241
# epoch 5 batch 145/185 loss = 0.6269
# epoch 5 batch 146/185 loss = 0.6336
# epoch 5 batch 147/185 loss = 0.6277
# epoch 5 batch 148/185 loss = 0.6253
# epoch 5 batch 149/185 loss = 0.6165
# epoch 5 batch 150/185 loss = 0.6252
# epoch 5 batch 151/185 loss = 0.6263
# epoch 5 batch 152/185 loss = 0.6217
# epoch 5 batch 153/185 loss = 0.6267
# epoch 5 batch 154/185 loss = 0.6340
# epoch 5 batch 155/185 loss = 0.6319
# epoch 5 batch 156/185 loss = 0.6212
# epoch 5 batch 157/185 loss = 0.6017
# epoch 5 batch 158/185 loss = 0.6274
# epoch 5 batch 159/185 loss = 0.6198
# epoch 5 batch 160/185 loss = 0.6365
# epoch 5 batch 161/185 loss = 0.6235
# epoch 5 batch 162/185 loss = 0.6190
# epoch 5 batch 163/185 loss = 0.6245
# epoch 5 batch 164/185 loss = 0.6116
# epoch 5 batch 165/185 loss = 0.6223
# epoch 5 batch 166/185 loss = 0.6204
# epoch 5 batch 167/185 loss = 0.6239
# epoch 5 batch 168/185 loss = 0.6183
# epoch 5 batch 169/185 loss = 0.6207
# epoch 5 batch 170/185 loss = 0.6197
# epoch 5 batch 171/185 loss = 0.6160
# epoch 5 batch 172/185 loss = 0.6353
# epoch 5 batch 173/185 loss = 0.6225
# epoch 5 batch 174/185 loss = 0.6109
# epoch 5 batch 175/185 loss = 0.6129
# epoch 5 batch 176/185 loss = 0.6254
# epoch 5 batch 177/185 loss = 0.6366
# epoch 5 batch 178/185 loss = 0.6234
# epoch 5 batch 179/185 loss = 0.6164
# epoch 5 batch 180/185 loss = 0.6405
# epoch 5 batch 181/185 loss = 0.6096
# epoch 5 batch 182/185 loss = 0.6104
# epoch 5 batch 183/185 loss = 0.6184
# epoch 5 batch 184/185 loss = 0.6052
# epoch 5 batch 185/185 loss = 0.6072
# epoch 5 train loss = 0.6350 valid loss = 0.6187
# epoch 6 batch 1/185 loss = 0.6256
# epoch 6 batch 2/185 loss = 0.6008
# epoch 6 batch 3/185 loss = 0.6150
# epoch 6 batch 4/185 loss = 0.6109
# epoch 6 batch 5/185 loss = 0.6151
# epoch 6 batch 6/185 loss = 0.6191
# epoch 6 batch 7/185 loss = 0.6171
# epoch 6 batch 8/185 loss = 0.6118
# epoch 6 batch 9/185 loss = 0.6314
# epoch 6 batch 10/185 loss = 0.6019
# epoch 6 batch 11/185 loss = 0.6108
# epoch 6 batch 12/185 loss = 0.6052
# epoch 6 batch 13/185 loss = 0.5965
# epoch 6 batch 14/185 loss = 0.6049
# epoch 6 batch 15/185 loss = 0.6222
# epoch 6 batch 16/185 loss = 0.6012
# epoch 6 batch 17/185 loss = 0.6166
# epoch 6 batch 18/185 loss = 0.6192
# epoch 6 batch 19/185 loss = 0.6141
# epoch 6 batch 20/185 loss = 0.6142
# epoch 6 batch 21/185 loss = 0.5997
# epoch 6 batch 22/185 loss = 0.6145
# epoch 6 batch 23/185 loss = 0.6192
# epoch 6 batch 24/185 loss = 0.6196
# epoch 6 batch 25/185 loss = 0.6163
# epoch 6 batch 26/185 loss = 0.5995
# epoch 6 batch 27/185 loss = 0.6061
# epoch 6 batch 28/185 loss = 0.6158
# epoch 6 batch 29/185 loss = 0.6038
# epoch 6 batch 30/185 loss = 0.5991
# epoch 6 batch 31/185 loss = 0.6128
# epoch 6 batch 32/185 loss = 0.6074
# epoch 6 batch 33/185 loss = 0.6033
# epoch 6 batch 34/185 loss = 0.6120
# epoch 6 batch 35/185 loss = 0.6193
# epoch 6 batch 36/185 loss = 0.5976
# epoch 6 batch 37/185 loss = 0.6123
# epoch 6 batch 38/185 loss = 0.6049
# epoch 6 batch 39/185 loss = 0.6061
# epoch 6 batch 40/185 loss = 0.6114
# epoch 6 batch 41/185 loss = 0.5891
# epoch 6 batch 42/185 loss = 0.6246
# epoch 6 batch 43/185 loss = 0.6183
# epoch 6 batch 44/185 loss = 0.6238
# epoch 6 batch 45/185 loss = 0.6130
# epoch 6 batch 46/185 loss = 0.6189
# epoch 6 batch 47/185 loss = 0.6010
# epoch 6 batch 48/185 loss = 0.6016
# epoch 6 batch 49/185 loss = 0.6050
# epoch 6 batch 50/185 loss = 0.6028
# epoch 6 batch 51/185 loss = 0.6184
# epoch 6 batch 52/185 loss = 0.6040
# epoch 6 batch 53/185 loss = 0.6008
# epoch 6 batch 54/185 loss = 0.6029
# epoch 6 batch 55/185 loss = 0.6065
# epoch 6 batch 56/185 loss = 0.6044
# epoch 6 batch 57/185 loss = 0.5982
# epoch 6 batch 58/185 loss = 0.5991
# epoch 6 batch 59/185 loss = 0.6059
# epoch 6 batch 60/185 loss = 0.6002
# epoch 6 batch 61/185 loss = 0.6083
# epoch 6 batch 62/185 loss = 0.5896
# epoch 6 batch 63/185 loss = 0.5897
# epoch 6 batch 64/185 loss = 0.6076
# epoch 6 batch 65/185 loss = 0.6032
# epoch 6 batch 66/185 loss = 0.6025
# epoch 6 batch 67/185 loss = 0.6110
# epoch 6 batch 68/185 loss = 0.5955
# epoch 6 batch 69/185 loss = 0.5889
# epoch 6 batch 70/185 loss = 0.5943
# epoch 6 batch 71/185 loss = 0.5985
# epoch 6 batch 72/185 loss = 0.5927
# epoch 6 batch 73/185 loss = 0.6046
# epoch 6 batch 74/185 loss = 0.6167
# epoch 6 batch 75/185 loss = 0.5964
# epoch 6 batch 76/185 loss = 0.6053
# epoch 6 batch 77/185 loss = 0.6029
# epoch 6 batch 78/185 loss = 0.6004
# epoch 6 batch 79/185 loss = 0.6048
# epoch 6 batch 80/185 loss = 0.5978
# epoch 6 batch 81/185 loss = 0.5979
# epoch 6 batch 82/185 loss = 0.6042
# epoch 6 batch 83/185 loss = 0.5930
# epoch 6 batch 84/185 loss = 0.6126
# epoch 6 batch 85/185 loss = 0.6021
# epoch 6 batch 86/185 loss = 0.5990
# epoch 6 batch 87/185 loss = 0.5936
# epoch 6 batch 88/185 loss = 0.6119
# epoch 6 batch 89/185 loss = 0.5929
# epoch 6 batch 90/185 loss = 0.5905
# epoch 6 batch 91/185 loss = 0.5860
# epoch 6 batch 92/185 loss = 0.6006
# epoch 6 batch 93/185 loss = 0.6058
# epoch 6 batch 94/185 loss = 0.6032
# epoch 6 batch 95/185 loss = 0.5887
# epoch 6 batch 96/185 loss = 0.5862
# epoch 6 batch 97/185 loss = 0.6039
# epoch 6 batch 98/185 loss = 0.5903
# epoch 6 batch 99/185 loss = 0.5982
# epoch 6 batch 100/185 loss = 0.5824
# epoch 6 batch 101/185 loss = 0.5949
# epoch 6 batch 102/185 loss = 0.6050
# epoch 6 batch 103/185 loss = 0.6053
# epoch 6 batch 104/185 loss = 0.5976
# epoch 6 batch 105/185 loss = 0.6001
# epoch 6 batch 106/185 loss = 0.6011
# epoch 6 batch 107/185 loss = 0.5959
# epoch 6 batch 108/185 loss = 0.5964
# epoch 6 batch 109/185 loss = 0.5954
# epoch 6 batch 110/185 loss = 0.6013
# epoch 6 batch 111/185 loss = 0.5981
# epoch 6 batch 112/185 loss = 0.6035
# epoch 6 batch 113/185 loss = 0.5965
# epoch 6 batch 114/185 loss = 0.5914
# epoch 6 batch 115/185 loss = 0.5840
# epoch 6 batch 116/185 loss = 0.5843
# epoch 6 batch 117/185 loss = 0.5711
# epoch 6 batch 118/185 loss = 0.5958
# epoch 6 batch 119/185 loss = 0.5832
# epoch 6 batch 120/185 loss = 0.5955
# epoch 6 batch 121/185 loss = 0.5856
# epoch 6 batch 122/185 loss = 0.5897
# epoch 6 batch 123/185 loss = 0.5837
# epoch 6 batch 124/185 loss = 0.5922
# epoch 6 batch 125/185 loss = 0.5949
# epoch 6 batch 126/185 loss = 0.5847
# epoch 6 batch 127/185 loss = 0.6003
# epoch 6 batch 128/185 loss = 0.5863
# epoch 6 batch 129/185 loss = 0.5951
# epoch 6 batch 130/185 loss = 0.5906
# epoch 6 batch 131/185 loss = 0.5861
# epoch 6 batch 132/185 loss = 0.5893
# epoch 6 batch 133/185 loss = 0.5845
# epoch 6 batch 134/185 loss = 0.5908
# epoch 6 batch 135/185 loss = 0.5821
# epoch 6 batch 136/185 loss = 0.5922
# epoch 6 batch 137/185 loss = 0.5892
# epoch 6 batch 138/185 loss = 0.5963
# epoch 6 batch 139/185 loss = 0.5954
# epoch 6 batch 140/185 loss = 0.6014
# epoch 6 batch 141/185 loss = 0.5867
# epoch 6 batch 142/185 loss = 0.6029
# epoch 6 batch 143/185 loss = 0.5907
# epoch 6 batch 144/185 loss = 0.5889
# epoch 6 batch 145/185 loss = 0.5928
# epoch 6 batch 146/185 loss = 0.5942
# epoch 6 batch 147/185 loss = 0.5782
# epoch 6 batch 148/185 loss = 0.5901
# epoch 6 batch 149/185 loss = 0.5926
# epoch 6 batch 150/185 loss = 0.5815
# epoch 6 batch 151/185 loss = 0.5792
# epoch 6 batch 152/185 loss = 0.5930
# epoch 6 batch 153/185 loss = 0.5918
# epoch 6 batch 154/185 loss = 0.5874
# epoch 6 batch 155/185 loss = 0.5929
# epoch 6 batch 156/185 loss = 0.5861
# epoch 6 batch 157/185 loss = 0.5800
# epoch 6 batch 158/185 loss = 0.6087
# epoch 6 batch 159/185 loss = 0.6033
# epoch 6 batch 160/185 loss = 0.5912
# epoch 6 batch 161/185 loss = 0.5851
# epoch 6 batch 162/185 loss = 0.5805
# epoch 6 batch 163/185 loss = 0.5856
# epoch 6 batch 164/185 loss = 0.5828
# epoch 6 batch 165/185 loss = 0.5762
# epoch 6 batch 166/185 loss = 0.5669
# epoch 6 batch 167/185 loss = 0.5803
# epoch 6 batch 168/185 loss = 0.5866
# epoch 6 batch 169/185 loss = 0.5805
# epoch 6 batch 170/185 loss = 0.5775
# epoch 6 batch 171/185 loss = 0.5764
# epoch 6 batch 172/185 loss = 0.5858
# epoch 6 batch 173/185 loss = 0.5781
# epoch 6 batch 174/185 loss = 0.6025
# epoch 6 batch 175/185 loss = 0.5848
# epoch 6 batch 176/185 loss = 0.5819
# epoch 6 batch 177/185 loss = 0.5953
# epoch 6 batch 178/185 loss = 0.5841
# epoch 6 batch 179/185 loss = 0.5785
# epoch 6 batch 180/185 loss = 0.5886
# epoch 6 batch 181/185 loss = 0.5766
# epoch 6 batch 182/185 loss = 0.5941
# epoch 6 batch 183/185 loss = 0.5857
# epoch 6 batch 184/185 loss = 0.5812
# epoch 6 batch 185/185 loss = 0.5780
# epoch 6 train loss = 0.5979 valid loss = 0.5648
# epoch 7 batch 1/185 loss = 0.5767
# epoch 7 batch 2/185 loss = 0.5764
# epoch 7 batch 3/185 loss = 0.5824
# epoch 7 batch 4/185 loss = 0.5768
# epoch 7 batch 5/185 loss = 0.5863
# epoch 7 batch 6/185 loss = 0.5857
# epoch 7 batch 7/185 loss = 0.5772
# epoch 7 batch 8/185 loss = 0.5909
# epoch 7 batch 9/185 loss = 0.5813
# epoch 7 batch 10/185 loss = 0.5759
# epoch 7 batch 11/185 loss = 0.5978
# epoch 7 batch 12/185 loss = 0.5605
# epoch 7 batch 13/185 loss = 0.5746
# epoch 7 batch 14/185 loss = 0.5726
# epoch 7 batch 15/185 loss = 0.5764
# epoch 7 batch 16/185 loss = 0.5786
# epoch 7 batch 17/185 loss = 0.5832
# epoch 7 batch 18/185 loss = 0.5686
# epoch 7 batch 19/185 loss = 0.5776
# epoch 7 batch 20/185 loss = 0.5705
# epoch 7 batch 21/185 loss = 0.5902
# epoch 7 batch 22/185 loss = 0.5648
# epoch 7 batch 23/185 loss = 0.5741
# epoch 7 batch 24/185 loss = 0.5734
# epoch 7 batch 25/185 loss = 0.5700
# epoch 7 batch 26/185 loss = 0.5798
# epoch 7 batch 27/185 loss = 0.5637
# epoch 7 batch 28/185 loss = 0.5795
# epoch 7 batch 29/185 loss = 0.5670
# epoch 7 batch 30/185 loss = 0.5814
# epoch 7 batch 31/185 loss = 0.5745
# epoch 7 batch 32/185 loss = 0.5706
# epoch 7 batch 33/185 loss = 0.5672
# epoch 7 batch 34/185 loss = 0.5863
# epoch 7 batch 35/185 loss = 0.5860
# epoch 7 batch 36/185 loss = 0.5764
# epoch 7 batch 37/185 loss = 0.5796
# epoch 7 batch 38/185 loss = 0.5758
# epoch 7 batch 39/185 loss = 0.5776
# epoch 7 batch 40/185 loss = 0.5778
# epoch 7 batch 41/185 loss = 0.5799
# epoch 7 batch 42/185 loss = 0.5788
# epoch 7 batch 43/185 loss = 0.5856
# epoch 7 batch 44/185 loss = 0.5682
# epoch 7 batch 45/185 loss = 0.5711
# epoch 7 batch 46/185 loss = 0.5624
# epoch 7 batch 47/185 loss = 0.5562
# epoch 7 batch 48/185 loss = 0.5749
# epoch 7 batch 49/185 loss = 0.5796
# epoch 7 batch 50/185 loss = 0.5635
# epoch 7 batch 51/185 loss = 0.5608
# epoch 7 batch 52/185 loss = 0.5684
# epoch 7 batch 53/185 loss = 0.5693
# epoch 7 batch 54/185 loss = 0.5665
# epoch 7 batch 55/185 loss = 0.5683
# epoch 7 batch 56/185 loss = 0.5728
# epoch 7 batch 57/185 loss = 0.5650
# epoch 7 batch 58/185 loss = 0.5695
# epoch 7 batch 59/185 loss = 0.5595
# epoch 7 batch 60/185 loss = 0.5616
# epoch 7 batch 61/185 loss = 0.5737
# epoch 7 batch 62/185 loss = 0.5840
# epoch 7 batch 63/185 loss = 0.5592
# epoch 7 batch 64/185 loss = 0.5710
# epoch 7 batch 65/185 loss = 0.5765
# epoch 7 batch 66/185 loss = 0.5834
# epoch 7 batch 67/185 loss = 0.5749
# epoch 7 batch 68/185 loss = 0.5646
# epoch 7 batch 69/185 loss = 0.5650
# epoch 7 batch 70/185 loss = 0.5632
# epoch 7 batch 71/185 loss = 0.5616
# epoch 7 batch 72/185 loss = 0.5820
# epoch 7 batch 73/185 loss = 0.5533
# epoch 7 batch 74/185 loss = 0.5671
# epoch 7 batch 75/185 loss = 0.5668
# epoch 7 batch 76/185 loss = 0.5654
# epoch 7 batch 77/185 loss = 0.5854
# epoch 7 batch 78/185 loss = 0.5709
# epoch 7 batch 79/185 loss = 0.5646
# epoch 7 batch 80/185 loss = 0.5625
# epoch 7 batch 81/185 loss = 0.5564
# epoch 7 batch 82/185 loss = 0.5661
# epoch 7 batch 83/185 loss = 0.5761
# epoch 7 batch 84/185 loss = 0.5698
# epoch 7 batch 85/185 loss = 0.5748
# epoch 7 batch 86/185 loss = 0.5781
# epoch 7 batch 87/185 loss = 0.5689
# epoch 7 batch 88/185 loss = 0.5553
# epoch 7 batch 89/185 loss = 0.5609
# epoch 7 batch 90/185 loss = 0.5690
# epoch 7 batch 91/185 loss = 0.5549
# epoch 7 batch 92/185 loss = 0.5762
# epoch 7 batch 93/185 loss = 0.5624
# epoch 7 batch 94/185 loss = 0.5743
# epoch 7 batch 95/185 loss = 0.5563
# epoch 7 batch 96/185 loss = 0.5588
# epoch 7 batch 97/185 loss = 0.5737
# epoch 7 batch 98/185 loss = 0.5719
# epoch 7 batch 99/185 loss = 0.5611
# epoch 7 batch 100/185 loss = 0.5512
# epoch 7 batch 101/185 loss = 0.5439
# epoch 7 batch 102/185 loss = 0.5538
# epoch 7 batch 103/185 loss = 0.5666
# epoch 7 batch 104/185 loss = 0.5601
# epoch 7 batch 105/185 loss = 0.5653
# epoch 7 batch 106/185 loss = 0.5527
# epoch 7 batch 107/185 loss = 0.5571
# epoch 7 batch 108/185 loss = 0.5581
# epoch 7 batch 109/185 loss = 0.5650
# epoch 7 batch 110/185 loss = 0.5606
# epoch 7 batch 111/185 loss = 0.5566
# epoch 7 batch 112/185 loss = 0.5584
# epoch 7 batch 113/185 loss = 0.5570
# epoch 7 batch 114/185 loss = 0.5553
# epoch 7 batch 115/185 loss = 0.5682
# epoch 7 batch 116/185 loss = 0.5558
# epoch 7 batch 117/185 loss = 0.5527
# epoch 7 batch 118/185 loss = 0.5585
# epoch 7 batch 119/185 loss = 0.5560
# epoch 7 batch 120/185 loss = 0.5489
# epoch 7 batch 121/185 loss = 0.5488
# epoch 7 batch 122/185 loss = 0.5608
# epoch 7 batch 123/185 loss = 0.5587
# epoch 7 batch 124/185 loss = 0.5579
# epoch 7 batch 125/185 loss = 0.5522
# epoch 7 batch 126/185 loss = 0.5555
# epoch 7 batch 127/185 loss = 0.5672
# epoch 7 batch 128/185 loss = 0.5547
# epoch 7 batch 129/185 loss = 0.5469
# epoch 7 batch 130/185 loss = 0.5519
# epoch 7 batch 131/185 loss = 0.5932
# epoch 7 batch 132/185 loss = 0.5598
# epoch 7 batch 133/185 loss = 0.5511
# epoch 7 batch 134/185 loss = 0.5519
# epoch 7 batch 135/185 loss = 0.5468
# epoch 7 batch 136/185 loss = 0.5719
# epoch 7 batch 137/185 loss = 0.5468
# epoch 7 batch 138/185 loss = 0.5456
# epoch 7 batch 139/185 loss = 0.5600
# epoch 7 batch 140/185 loss = 0.5517
# epoch 7 batch 141/185 loss = 0.5606
# epoch 7 batch 142/185 loss = 0.5474
# epoch 7 batch 143/185 loss = 0.5557
# epoch 7 batch 144/185 loss = 0.5514
# epoch 7 batch 145/185 loss = 0.5551
# epoch 7 batch 146/185 loss = 0.5472
# epoch 7 batch 147/185 loss = 0.5584
# epoch 7 batch 148/185 loss = 0.5461
# epoch 7 batch 149/185 loss = 0.5451
# epoch 7 batch 150/185 loss = 0.5607
# epoch 7 batch 151/185 loss = 0.5548
# epoch 7 batch 152/185 loss = 0.5502
# epoch 7 batch 153/185 loss = 0.5411
# epoch 7 batch 154/185 loss = 0.5358
# epoch 7 batch 155/185 loss = 0.5517
# epoch 7 batch 156/185 loss = 0.5443
# epoch 7 batch 157/185 loss = 0.5550
# epoch 7 batch 158/185 loss = 0.5413
# epoch 7 batch 159/185 loss = 0.5411
# epoch 7 batch 160/185 loss = 0.5403
# epoch 7 batch 161/185 loss = 0.5464
# epoch 7 batch 162/185 loss = 0.5467
# epoch 7 batch 163/185 loss = 0.5421
# epoch 7 batch 164/185 loss = 0.5377
# epoch 7 batch 165/185 loss = 0.5512
# epoch 7 batch 166/185 loss = 0.5421
# epoch 7 batch 167/185 loss = 0.5523
# epoch 7 batch 168/185 loss = 0.5474
# epoch 7 batch 169/185 loss = 0.5410
# epoch 7 batch 170/185 loss = 0.5410
# epoch 7 batch 171/185 loss = 0.5495
# epoch 7 batch 172/185 loss = 0.5502
# epoch 7 batch 173/185 loss = 0.5465
# epoch 7 batch 174/185 loss = 0.5585
# epoch 7 batch 175/185 loss = 0.5397
# epoch 7 batch 176/185 loss = 0.5464
# epoch 7 batch 177/185 loss = 0.5506
# epoch 7 batch 178/185 loss = 0.5577
# epoch 7 batch 179/185 loss = 0.5596
# epoch 7 batch 180/185 loss = 0.5560
# epoch 7 batch 181/185 loss = 0.5485
# epoch 7 batch 182/185 loss = 0.5554
# epoch 7 batch 183/185 loss = 0.5354
# epoch 7 batch 184/185 loss = 0.5450
# epoch 7 batch 185/185 loss = 0.5501
# epoch 7 train loss = 0.5629 valid loss = 0.5482
# epoch 8 batch 1/185 loss = 0.5362
# epoch 8 batch 2/185 loss = 0.5447
# epoch 8 batch 3/185 loss = 0.5371
# epoch 8 batch 4/185 loss = 0.5508
# epoch 8 batch 5/185 loss = 0.5436
# epoch 8 batch 6/185 loss = 0.5471
# epoch 8 batch 7/185 loss = 0.5434
# epoch 8 batch 8/185 loss = 0.5483
# epoch 8 batch 9/185 loss = 0.5295
# epoch 8 batch 10/185 loss = 0.5449
# epoch 8 batch 11/185 loss = 0.5311
# epoch 8 batch 12/185 loss = 0.5477
# epoch 8 batch 13/185 loss = 0.5417
# epoch 8 batch 14/185 loss = 0.5275
# epoch 8 batch 15/185 loss = 0.5374
# epoch 8 batch 16/185 loss = 0.5618
# epoch 8 batch 17/185 loss = 0.5421
# epoch 8 batch 18/185 loss = 0.5518
# epoch 8 batch 19/185 loss = 0.5437
# epoch 8 batch 20/185 loss = 0.5379
# epoch 8 batch 21/185 loss = 0.5365
# epoch 8 batch 22/185 loss = 0.5389
# epoch 8 batch 23/185 loss = 0.5498
# epoch 8 batch 24/185 loss = 0.5383
# epoch 8 batch 25/185 loss = 0.5536
# epoch 8 batch 26/185 loss = 0.5358
# epoch 8 batch 27/185 loss = 0.5581
# epoch 8 batch 28/185 loss = 0.5557
# epoch 8 batch 29/185 loss = 0.5427
# epoch 8 batch 30/185 loss = 0.5555
# epoch 8 batch 31/185 loss = 0.5331
# epoch 8 batch 32/185 loss = 0.5419
# epoch 8 batch 33/185 loss = 0.5496
# epoch 8 batch 34/185 loss = 0.5359
# epoch 8 batch 35/185 loss = 0.5394
# epoch 8 batch 36/185 loss = 0.5342
# epoch 8 batch 37/185 loss = 0.5266
# epoch 8 batch 38/185 loss = 0.5405
# epoch 8 batch 39/185 loss = 0.5251
# epoch 8 batch 40/185 loss = 0.5308
# epoch 8 batch 41/185 loss = 0.5424
# epoch 8 batch 42/185 loss = 0.5356
# epoch 8 batch 43/185 loss = 0.5404
# epoch 8 batch 44/185 loss = 0.5326
# epoch 8 batch 45/185 loss = 0.5460
# epoch 8 batch 46/185 loss = 0.5401
# epoch 8 batch 47/185 loss = 0.5304
# epoch 8 batch 48/185 loss = 0.5347
# epoch 8 batch 49/185 loss = 0.5383
# epoch 8 batch 50/185 loss = 0.5369
# ...
# epoch 48 batch 122/185 loss = 0.0096
# epoch 48 batch 123/185 loss = 0.0090
# epoch 48 batch 124/185 loss = 0.0103
# epoch 48 batch 125/185 loss = 0.0113
# epoch 48 batch 126/185 loss = 0.0108
# epoch 48 batch 127/185 loss = 0.0109
# epoch 48 batch 128/185 loss = 0.0099
# epoch 48 batch 129/185 loss = 0.0093
# epoch 48 batch 130/185 loss = 0.0095
# epoch 48 batch 131/185 loss = 0.0093
# epoch 48 batch 132/185 loss = 0.0110
# epoch 48 batch 133/185 loss = 0.0100
# epoch 48 batch 134/185 loss = 0.0106
# epoch 48 batch 135/185 loss = 0.0090
# epoch 48 batch 136/185 loss = 0.0103
# epoch 48 batch 137/185 loss = 0.0099
# epoch 48 batch 138/185 loss = 0.0088
# epoch 48 batch 139/185 loss = 0.0085
# epoch 48 batch 140/185 loss = 0.0119
# epoch 48 batch 141/185 loss = 0.0105
# epoch 48 batch 142/185 loss = 0.0125
# epoch 48 batch 143/185 loss = 0.0101
# epoch 48 batch 144/185 loss = 0.0095
# epoch 48 batch 145/185 loss = 0.0100
# epoch 48 batch 146/185 loss = 0.0097
# epoch 48 batch 147/185 loss = 0.0096
# epoch 48 batch 148/185 loss = 0.0083
# epoch 48 batch 149/185 loss = 0.0100
# epoch 48 batch 150/185 loss = 0.0086
# epoch 48 batch 151/185 loss = 0.0091
# epoch 48 batch 152/185 loss = 0.0100
# epoch 48 batch 153/185 loss = 0.0096
# epoch 48 batch 154/185 loss = 0.0091
# epoch 48 batch 155/185 loss = 0.0093
# epoch 48 batch 156/185 loss = 0.0103
# epoch 48 batch 157/185 loss = 0.0089
# epoch 48 batch 158/185 loss = 0.0115
# epoch 48 batch 159/185 loss = 0.0090
# epoch 48 batch 160/185 loss = 0.0079
# epoch 48 batch 161/185 loss = 0.0101
# epoch 48 batch 162/185 loss = 0.0091
# epoch 48 batch 163/185 loss = 0.0101
# epoch 48 batch 164/185 loss = 0.0085
# epoch 48 batch 165/185 loss = 0.0093
# epoch 48 batch 166/185 loss = 0.0099
# epoch 48 batch 167/185 loss = 0.0105
# epoch 48 batch 168/185 loss = 0.0115
# epoch 48 batch 169/185 loss = 0.0130
# epoch 48 batch 170/185 loss = 0.0092
# epoch 48 batch 171/185 loss = 0.0087
# epoch 48 batch 172/185 loss = 0.0106
# epoch 48 batch 173/185 loss = 0.0100
# epoch 48 batch 174/185 loss = 0.0105
# epoch 48 batch 175/185 loss = 0.0094
# epoch 48 batch 176/185 loss = 0.0107
# epoch 48 batch 177/185 loss = 0.0101
# epoch 48 batch 178/185 loss = 0.0095
# epoch 48 batch 179/185 loss = 0.0093
# epoch 48 batch 180/185 loss = 0.0087
# epoch 48 batch 181/185 loss = 0.0094
# epoch 48 batch 182/185 loss = 0.0088
# epoch 48 batch 183/185 loss = 0.0098
# epoch 48 batch 184/185 loss = 0.0115
# epoch 48 batch 185/185 loss = 0.0107
# epoch 48 train loss = 0.0104 valid loss = 0.0195
# epoch 49 batch 1/185 loss = 0.0095
# epoch 49 batch 2/185 loss = 0.0089
# epoch 49 batch 3/185 loss = 0.0089
# epoch 49 batch 4/185 loss = 0.0089
# epoch 49 batch 5/185 loss = 0.0094
# epoch 49 batch 6/185 loss = 0.0089
# epoch 49 batch 7/185 loss = 0.0094
# epoch 49 batch 8/185 loss = 0.0100
# epoch 49 batch 9/185 loss = 0.0089
# epoch 49 batch 10/185 loss = 0.0101
# epoch 49 batch 11/185 loss = 0.0102
# epoch 49 batch 12/185 loss = 0.0103
# epoch 49 batch 13/185 loss = 0.0097
# epoch 49 batch 14/185 loss = 0.0082
# epoch 49 batch 15/185 loss = 0.0092
# epoch 49 batch 16/185 loss = 0.0079
# epoch 49 batch 17/185 loss = 0.0078
# epoch 49 batch 18/185 loss = 0.0082
# epoch 49 batch 19/185 loss = 0.0089
# epoch 49 batch 20/185 loss = 0.0104
# epoch 49 batch 21/185 loss = 0.0099
# epoch 49 batch 22/185 loss = 0.0083
# epoch 49 batch 23/185 loss = 0.0083
# epoch 49 batch 24/185 loss = 0.0076
# epoch 49 batch 25/185 loss = 0.0102
# epoch 49 batch 26/185 loss = 0.0104
# epoch 49 batch 27/185 loss = 0.0074
# epoch 49 batch 28/185 loss = 0.0103
# epoch 49 batch 29/185 loss = 0.0101
# epoch 49 batch 30/185 loss = 0.0096
# epoch 49 batch 31/185 loss = 0.0091
# epoch 49 batch 32/185 loss = 0.0090
# epoch 49 batch 33/185 loss = 0.0089
# epoch 49 batch 34/185 loss = 0.0084
# epoch 49 batch 35/185 loss = 0.0094
# epoch 49 batch 36/185 loss = 0.0093
# epoch 49 batch 37/185 loss = 0.0092
# epoch 49 batch 38/185 loss = 0.0099
# epoch 49 batch 39/185 loss = 0.0086
# epoch 49 batch 40/185 loss = 0.0075
# epoch 49 batch 41/185 loss = 0.0069
# epoch 49 batch 42/185 loss = 0.0090
# epoch 49 batch 43/185 loss = 0.0106
# epoch 49 batch 44/185 loss = 0.0081
# epoch 49 batch 45/185 loss = 0.0107
# epoch 49 batch 46/185 loss = 0.0089
# epoch 49 batch 47/185 loss = 0.0077
# epoch 49 batch 48/185 loss = 0.0086
# epoch 49 batch 49/185 loss = 0.0096
# epoch 49 batch 50/185 loss = 0.0083
# epoch 49 batch 51/185 loss = 0.0091
# epoch 49 batch 52/185 loss = 0.0091
# epoch 49 batch 53/185 loss = 0.0082
# epoch 49 batch 54/185 loss = 0.0093
# epoch 49 batch 55/185 loss = 0.0099
# epoch 49 batch 56/185 loss = 0.0095
# epoch 49 batch 57/185 loss = 0.0080
# epoch 49 batch 58/185 loss = 0.0103
# epoch 49 batch 59/185 loss = 0.0072
# epoch 49 batch 60/185 loss = 0.0086
# epoch 49 batch 61/185 loss = 0.0084
# epoch 49 batch 62/185 loss = 0.0078
# epoch 49 batch 63/185 loss = 0.0083
# epoch 49 batch 64/185 loss = 0.0069
# epoch 49 batch 65/185 loss = 0.0074
# epoch 49 batch 66/185 loss = 0.0089
# epoch 49 batch 67/185 loss = 0.0089
# epoch 49 batch 68/185 loss = 0.0070
# epoch 49 batch 69/185 loss = 0.0098
# epoch 49 batch 70/185 loss = 0.0085
# epoch 49 batch 71/185 loss = 0.0086
# epoch 49 batch 72/185 loss = 0.0089
# epoch 49 batch 73/185 loss = 0.0094
# epoch 49 batch 74/185 loss = 0.0083
# epoch 49 batch 75/185 loss = 0.0088
# epoch 49 batch 76/185 loss = 0.0092
# epoch 49 batch 77/185 loss = 0.0092
# epoch 49 batch 78/185 loss = 0.0087
# epoch 49 batch 79/185 loss = 0.0087
# epoch 49 batch 80/185 loss = 0.0075
# epoch 49 batch 81/185 loss = 0.0097
# epoch 49 batch 82/185 loss = 0.0075
# epoch 49 batch 83/185 loss = 0.0077
# epoch 49 batch 84/185 loss = 0.0064
# epoch 49 batch 85/185 loss = 0.0079
# epoch 49 batch 86/185 loss = 0.0062
# epoch 49 batch 87/185 loss = 0.0085
# epoch 49 batch 88/185 loss = 0.0090
# epoch 49 batch 89/185 loss = 0.0073
# epoch 49 batch 90/185 loss = 0.0085
# epoch 49 batch 91/185 loss = 0.0084
# epoch 49 batch 92/185 loss = 0.0069
# epoch 49 batch 93/185 loss = 0.0121
# epoch 49 batch 94/185 loss = 0.0088
# epoch 49 batch 95/185 loss = 0.0085
# epoch 49 batch 96/185 loss = 0.0093
# epoch 49 batch 97/185 loss = 0.0072
# epoch 49 batch 98/185 loss = 0.0074
# epoch 49 batch 99/185 loss = 0.0094
# epoch 49 batch 100/185 loss = 0.0105
# epoch 49 batch 101/185 loss = 0.0088
# epoch 49 batch 102/185 loss = 0.0073
# epoch 49 batch 103/185 loss = 0.0074
# epoch 49 batch 104/185 loss = 0.0079
# epoch 49 batch 105/185 loss = 0.0088
# epoch 49 batch 106/185 loss = 0.0089
# epoch 49 batch 107/185 loss = 0.0075
# epoch 49 batch 108/185 loss = 0.0083
# epoch 49 batch 109/185 loss = 0.0072
# epoch 49 batch 110/185 loss = 0.0077
# epoch 49 batch 111/185 loss = 0.0082
# epoch 49 batch 112/185 loss = 0.0085
# epoch 49 batch 113/185 loss = 0.0077
# epoch 49 batch 114/185 loss = 0.0082
# epoch 49 batch 115/185 loss = 0.0084
# epoch 49 batch 116/185 loss = 0.0075
# epoch 49 batch 117/185 loss = 0.0093
# epoch 49 batch 118/185 loss = 0.0085
# epoch 49 batch 119/185 loss = 0.0083
# epoch 49 batch 120/185 loss = 0.0082
# epoch 49 batch 121/185 loss = 0.0053
# epoch 49 batch 122/185 loss = 0.0081
# epoch 49 batch 123/185 loss = 0.0083
# epoch 49 batch 124/185 loss = 0.0087
# epoch 49 batch 125/185 loss = 0.0069
# epoch 49 batch 126/185 loss = 0.0093
# epoch 49 batch 127/185 loss = 0.0075
# epoch 49 batch 128/185 loss = 0.0069
# epoch 49 batch 129/185 loss = 0.0083
# epoch 49 batch 130/185 loss = 0.0083
# epoch 49 batch 131/185 loss = 0.0084
# epoch 49 batch 132/185 loss = 0.0084
# epoch 49 batch 133/185 loss = 0.0085
# epoch 49 batch 134/185 loss = 0.0058
# epoch 49 batch 135/185 loss = 0.0081
# epoch 49 batch 136/185 loss = 0.0081
# epoch 49 batch 137/185 loss = 0.0086
# epoch 49 batch 138/185 loss = 0.0071
# epoch 49 batch 139/185 loss = 0.0086
# epoch 49 batch 140/185 loss = 0.0081
# epoch 49 batch 141/185 loss = 0.0087
# epoch 49 batch 142/185 loss = 0.0087
# epoch 49 batch 143/185 loss = 0.0093
# epoch 49 batch 144/185 loss = 0.0076
# epoch 49 batch 145/185 loss = 0.0069
# epoch 49 batch 146/185 loss = 0.0096
# epoch 49 batch 147/185 loss = 0.0099
# epoch 49 batch 148/185 loss = 0.0073
# epoch 49 batch 149/185 loss = 0.0084
# epoch 49 batch 150/185 loss = 0.0085
# epoch 49 batch 151/185 loss = 0.0070
# epoch 49 batch 152/185 loss = 0.0088
# epoch 49 batch 153/185 loss = 0.0081
# epoch 49 batch 154/185 loss = 0.0095
# epoch 49 batch 155/185 loss = 0.0077
# epoch 49 batch 156/185 loss = 0.0074
# epoch 49 batch 157/185 loss = 0.0072
# epoch 49 batch 158/185 loss = 0.0080
# epoch 49 batch 159/185 loss = 0.0083
# epoch 49 batch 160/185 loss = 0.0083
# epoch 49 batch 161/185 loss = 0.0060
# epoch 49 batch 162/185 loss = 0.0099
# epoch 49 batch 163/185 loss = 0.0087
# epoch 49 batch 164/185 loss = 0.0084
# epoch 49 batch 165/185 loss = 0.0076
# epoch 49 batch 166/185 loss = 0.0073
# epoch 49 batch 167/185 loss = 0.0072
# epoch 49 batch 168/185 loss = 0.0077
# epoch 49 batch 169/185 loss = 0.0071
# epoch 49 batch 170/185 loss = 0.0062
# epoch 49 batch 171/185 loss = 0.0086
# epoch 49 batch 172/185 loss = 0.0081
# epoch 49 batch 173/185 loss = 0.0074
# epoch 49 batch 174/185 loss = 0.0081
# epoch 49 batch 175/185 loss = 0.0085
# epoch 49 batch 176/185 loss = 0.0068
# epoch 49 batch 177/185 loss = 0.0096
# epoch 49 batch 178/185 loss = 0.0083
# epoch 49 batch 179/185 loss = 0.0088
# epoch 49 batch 180/185 loss = 0.0066
# epoch 49 batch 181/185 loss = 0.0082
# epoch 49 batch 182/185 loss = 0.0081
# epoch 49 batch 183/185 loss = 0.0079
# epoch 49 batch 184/185 loss = 0.0079
# epoch 49 batch 185/185 loss = 0.0084
# epoch 49 train loss = 0.0084 valid loss = 0.0177
# epoch 50 batch 1/185 loss = 0.0069
# epoch 50 batch 2/185 loss = 0.0077
# epoch 50 batch 3/185 loss = 0.0066
# epoch 50 batch 4/185 loss = 0.0068
# epoch 50 batch 5/185 loss = 0.0070
# epoch 50 batch 6/185 loss = 0.0083
# epoch 50 batch 7/185 loss = 0.0072
# epoch 50 batch 8/185 loss = 0.0079
# epoch 50 batch 9/185 loss = 0.0071
# epoch 50 batch 10/185 loss = 0.0086
# epoch 50 batch 11/185 loss = 0.0072
# epoch 50 batch 12/185 loss = 0.0073
# epoch 50 batch 13/185 loss = 0.0080
# epoch 50 batch 14/185 loss = 0.0074
# epoch 50 batch 15/185 loss = 0.0073
# epoch 50 batch 16/185 loss = 0.0070
# epoch 50 batch 17/185 loss = 0.0068
# epoch 50 batch 18/185 loss = 0.0070
# epoch 50 batch 19/185 loss = 0.0077
# epoch 50 batch 20/185 loss = 0.0075
# epoch 50 batch 21/185 loss = 0.0078
# epoch 50 batch 22/185 loss = 0.0078
# epoch 50 batch 23/185 loss = 0.0062
# epoch 50 batch 24/185 loss = 0.0068
# epoch 50 batch 25/185 loss = 0.0080
# epoch 50 batch 26/185 loss = 0.0086
# epoch 50 batch 27/185 loss = 0.0064
# epoch 50 batch 28/185 loss = 0.0084
# epoch 50 batch 29/185 loss = 0.0062
# epoch 50 batch 30/185 loss = 0.0060
# epoch 50 batch 31/185 loss = 0.0071
# epoch 50 batch 32/185 loss = 0.0078
# epoch 50 batch 33/185 loss = 0.0083
# epoch 50 batch 34/185 loss = 0.0077
# epoch 50 batch 35/185 loss = 0.0100
# epoch 50 batch 36/185 loss = 0.0072
# epoch 50 batch 37/185 loss = 0.0073
# epoch 50 batch 38/185 loss = 0.0067
# epoch 50 batch 39/185 loss = 0.0062
# epoch 50 batch 40/185 loss = 0.0069
# epoch 50 batch 41/185 loss = 0.0089
# epoch 50 batch 42/185 loss = 0.0070
# epoch 50 batch 43/185 loss = 0.0073
# epoch 50 batch 44/185 loss = 0.0068
# epoch 50 batch 45/185 loss = 0.0064
# epoch 50 batch 46/185 loss = 0.0072
# epoch 50 batch 47/185 loss = 0.0086
# epoch 50 batch 48/185 loss = 0.0084
# epoch 50 batch 49/185 loss = 0.0065
# epoch 50 batch 50/185 loss = 0.0076
# epoch 50 batch 51/185 loss = 0.0075
# epoch 50 batch 52/185 loss = 0.0079
# epoch 50 batch 53/185 loss = 0.0086
# epoch 50 batch 54/185 loss = 0.0077
# epoch 50 batch 55/185 loss = 0.0078
# epoch 50 batch 56/185 loss = 0.0058
# epoch 50 batch 57/185 loss = 0.0078
# epoch 50 batch 58/185 loss = 0.0075
# epoch 50 batch 59/185 loss = 0.0082
# epoch 50 batch 60/185 loss = 0.0064
# epoch 50 batch 61/185 loss = 0.0072
# epoch 50 batch 62/185 loss = 0.0069
# epoch 50 batch 63/185 loss = 0.0070
# epoch 50 batch 64/185 loss = 0.0072
# epoch 50 batch 65/185 loss = 0.0070
# epoch 50 batch 66/185 loss = 0.0067
# epoch 50 batch 67/185 loss = 0.0069
# epoch 50 batch 68/185 loss = 0.0061
# epoch 50 batch 69/185 loss = 0.0058
# epoch 50 batch 70/185 loss = 0.0076
# epoch 50 batch 71/185 loss = 0.0068
# epoch 50 batch 72/185 loss = 0.0057
# epoch 50 batch 73/185 loss = 0.0076
# epoch 50 batch 74/185 loss = 0.0077
# epoch 50 batch 75/185 loss = 0.0066
# epoch 50 batch 76/185 loss = 0.0078
# epoch 50 batch 77/185 loss = 0.0067
# epoch 50 batch 78/185 loss = 0.0077
# epoch 50 batch 79/185 loss = 0.0057
# epoch 50 batch 80/185 loss = 0.0067
# epoch 50 batch 81/185 loss = 0.0069
# epoch 50 batch 82/185 loss = 0.0060
# epoch 50 batch 83/185 loss = 0.0064
# epoch 50 batch 84/185 loss = 0.0069
# epoch 50 batch 85/185 loss = 0.0068
# epoch 50 batch 86/185 loss = 0.0068
# epoch 50 batch 87/185 loss = 0.0070
# epoch 50 batch 88/185 loss = 0.0076
# epoch 50 batch 89/185 loss = 0.0074
# epoch 50 batch 90/185 loss = 0.0083
# epoch 50 batch 91/185 loss = 0.0088
# epoch 50 batch 92/185 loss = 0.0065
# epoch 50 batch 93/185 loss = 0.0065
# epoch 50 batch 94/185 loss = 0.0067
# epoch 50 batch 95/185 loss = 0.0064
# epoch 50 batch 96/185 loss = 0.0086
# epoch 50 batch 97/185 loss = 0.0055
# epoch 50 batch 98/185 loss = 0.0066
# epoch 50 batch 99/185 loss = 0.0069
# epoch 50 batch 100/185 loss = 0.0069
# epoch 50 batch 101/185 loss = 0.0060
# epoch 50 batch 102/185 loss = 0.0067
# epoch 50 batch 103/185 loss = 0.0075
# epoch 50 batch 104/185 loss = 0.0066
# epoch 50 batch 105/185 loss = 0.0064
# epoch 50 batch 106/185 loss = 0.0066
# epoch 50 batch 107/185 loss = 0.0074
# epoch 50 batch 108/185 loss = 0.0075
# epoch 50 batch 109/185 loss = 0.0069
# epoch 50 batch 110/185 loss = 0.0073
# epoch 50 batch 111/185 loss = 0.0075
# epoch 50 batch 112/185 loss = 0.0081
# epoch 50 batch 113/185 loss = 0.0068
# epoch 50 batch 114/185 loss = 0.0073
# epoch 50 batch 115/185 loss = 0.0078
# epoch 50 batch 116/185 loss = 0.0059
# epoch 50 batch 117/185 loss = 0.0070
# epoch 50 batch 118/185 loss = 0.0053
# epoch 50 batch 119/185 loss = 0.0067
# epoch 50 batch 120/185 loss = 0.0070
# epoch 50 batch 121/185 loss = 0.0067
# epoch 50 batch 122/185 loss = 0.0075
# epoch 50 batch 123/185 loss = 0.0065
# epoch 50 batch 124/185 loss = 0.0065
# epoch 50 batch 125/185 loss = 0.0077
# epoch 50 batch 126/185 loss = 0.0079
# epoch 50 batch 127/185 loss = 0.0073
# epoch 50 batch 128/185 loss = 0.0051
# epoch 50 batch 129/185 loss = 0.0073
# epoch 50 batch 130/185 loss = 0.0070
# epoch 50 batch 131/185 loss = 0.0063
# epoch 50 batch 132/185 loss = 0.0063
# epoch 50 batch 133/185 loss = 0.0067
# epoch 50 batch 134/185 loss = 0.0069
# epoch 50 batch 135/185 loss = 0.0063
# epoch 50 batch 136/185 loss = 0.0071
# epoch 50 batch 137/185 loss = 0.0075
# epoch 50 batch 138/185 loss = 0.0056
# epoch 50 batch 139/185 loss = 0.0067
# epoch 50 batch 140/185 loss = 0.0068
# epoch 50 batch 141/185 loss = 0.0062
# epoch 50 batch 142/185 loss = 0.0061
# epoch 50 batch 143/185 loss = 0.0075
# epoch 50 batch 144/185 loss = 0.0066
# epoch 50 batch 145/185 loss = 0.0051
# epoch 50 batch 146/185 loss = 0.0071
# epoch 50 batch 147/185 loss = 0.0071
# epoch 50 batch 148/185 loss = 0.0070
# epoch 50 batch 149/185 loss = 0.0069
# epoch 50 batch 150/185 loss = 0.0062
# epoch 50 batch 151/185 loss = 0.0069
# epoch 50 batch 152/185 loss = 0.0065
# epoch 50 batch 153/185 loss = 0.0091
# epoch 50 batch 154/185 loss = 0.0071
# epoch 50 batch 155/185 loss = 0.0067
# epoch 50 batch 156/185 loss = 0.0063
# epoch 50 batch 157/185 loss = 0.0075
# epoch 50 batch 158/185 loss = 0.0056
# epoch 50 batch 159/185 loss = 0.0068
# epoch 50 batch 160/185 loss = 0.0056
# epoch 50 batch 161/185 loss = 0.0069
# epoch 50 batch 162/185 loss = 0.0064
# epoch 50 batch 163/185 loss = 0.0074
# epoch 50 batch 164/185 loss = 0.0066
# epoch 50 batch 165/185 loss = 0.0071
# epoch 50 batch 166/185 loss = 0.0066
# epoch 50 batch 167/185 loss = 0.0060
# epoch 50 batch 168/185 loss = 0.0061
# epoch 50 batch 169/185 loss = 0.0077
# epoch 50 batch 170/185 loss = 0.0056
# epoch 50 batch 171/185 loss = 0.0057
# epoch 50 batch 172/185 loss = 0.0058
# epoch 50 batch 173/185 loss = 0.0052
# epoch 50 batch 174/185 loss = 0.0071
# epoch 50 batch 175/185 loss = 0.0071
# epoch 50 batch 176/185 loss = 0.0059
# epoch 50 batch 177/185 loss = 0.0079
# epoch 50 batch 178/185 loss = 0.0064
# epoch 50 batch 179/185 loss = 0.0065
# epoch 50 batch 180/185 loss = 0.0068
# epoch 50 batch 181/185 loss = 0.0068
# epoch 50 batch 182/185 loss = 0.0044
# epoch 50 batch 183/185 loss = 0.0067
# epoch 50 batch 184/185 loss = 0.0065
# epoch 50 batch 185/185 loss = 0.0072
# epoch 50 train loss = 0.0070 valid loss = 0.0159
